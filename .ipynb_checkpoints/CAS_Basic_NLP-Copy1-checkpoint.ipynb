# %% [markdown]
# ## Introduction
#
# This notebook illustrates some basic document handling using [Spacy] (https://spacy.io/). Spacy is fast, and powerful, but not completely trivial to understand. There are though lots of useful resources, and the documentation is excellent.
#
# **The first block of our code simply sets things up - most important here is the language model that we use.**

# %%
import spacy #Our NLP tools
from collections import Counter #We will use this to do simple counts of terms

#Load a German language model to do NLP - the models we use will influence our results a lot
nlp = spacy.load('de_core_news_md')

# %% [markdown]
# Now we load a default list of stop words and print them out.
#
# Look through the list of stop words, and consider what issues they might cause if we are interested in spatial relationships?

# %%
# This block loads our stop words 
stopwords = nlp.Defaults.stop_words

print(len(stopwords))
print(stopwords)
# Out:
# 543
# {'gern', 'daneben', 'einigen', 'satt', 'wurde', 'sollen', 'war', 'zehnten', 'sich', 'jenen', 'solches', 'dass', 'demgemäss', 'und', 'zu', 'alle', 'heißt', 'sieben', 'großen', 'bin', 'heisst', 'siebtes', 'statt', 'zweites', 'manchen', 'müssen', 'besten', 'achtes', 'allerdings', 'unser', 'eine', 'darauf', 'heute', 'jeden', 'viele', 'fünfte', 'zweite', 'denen', 'außer', 'mir', 'konnte', 'wer', 'dagegen', 'die', 'durften', 'dafür', 'allein', 'nahm', 'gekonnt', 'jemand', 'eigenen', 'sechstes', 'kommen', 'nein', 'immer', 'ag', 'gerade', 'daraus', 'mochte', 'groß', 'alles', 'geht', 'wir', 'neben', 'gehen', 'muss', 'achter', 'bei', 'jedermanns', 'achten', 'sechste', 'drin', 'nie', 'solchem', 'geworden', 'siebenten', 'dessen', 'soll', 'rund', 'jemandem', 'seid', 'wäre', 'wenigstens', 'warum', 'daselbst', 'einer', 'mit', 'könnt', 'erster', 'endlich', 'viertes', 'geschweige', 'vielem', 'vielen', 'elf', 'musst', 'dort', 'wem', 'jeder', 'drittes', 'wenn', 'niemandem', 'drei', 'sollte', 'überhaupt', 'vierter', 'nichts', 'davor', 'denn', 'dank', 'ihm', 'ende', 'auch', 'nur', 'werde', 'ganzes', 'wessen', 'schon', 'großer', 'es', 'tage', 'lange', 'neue', 'keinem', 'á', 'an', 'meinen', 'jedoch', 'jenem', 'doch', 'acht', 'zehnter', 'ihnen', 'willst', 'wird', 'grosser', 'dritten', 'gemacht', 'ins', 'zweiten', 'richtig', 'jedermann', 'en', 'vor', 'gute', 'wurden', 'besonders', 'demselben', 'erst', 'derselben', 'meiner', 'daran', 'während', 'zehntes', 'man', 'weiteres', 'jemanden', 'ihren', 'wohl', 'mögen', 'danach', 'derselbe', 'damit', 'dem', 'einen', 'nach', 'hast', 'andere', 'desselben', 'dieser', 'macht', 'a', 'einiges', 'seien', 'viel', 'jede', 'worden', 'eines', 'gesagt', 'sagte', 'dazu', 'tat', 'andern', 'ausser', 'gab', 'mussten', 'trotzdem', 'darfst', 'einige', 'solche', 'indem', 'vergangenen', 'besser', 'lang', 'zweiter', 'lieber', 'teil', 'große', 'seine', 'neunter', 'vielleicht', 'tagen', 'wollten', 'einmaleins', 'hoch', 'gegen', 'darum', 'weil', 'zehn', 'ganze', 'fünf', 'leider', 'diejenigen', 'seines', 'unserer', 'denselben', 'leicht', 'natürlich', 'sein', 'hätte', 'sei', 'eben', 'mag', 'gleich', 'neunte', 'eigenes', 'der', 'beispiel', 'um', 'wollt', 'hier', 'dann', 'weiter', 'als', 'deine', 'jahr', 'ach', 'dieselbe', 'wegen', 'jedem', 'siebter', 'siebenter', 'gewollt', 'konnten', 'demzufolge', 'welchen', 'gewesen', 'wie', 'jene', 'vier', 'vierten', 'meinem', 'dürfen', 'ausserdem', 'können', 'nun', 'uns', 'werden', 'vierte', 'durch', 'schlecht', 'wieder', 'aber', 'wart', 'her', 'deshalb', 'dadurch', 'kein', 'dieses', 'welche', 'deren', 'wenige', 'dritte', 'kaum', 'weniger', 'sechs', 'waren', 'das', 'dazwischen', 'bekannt', 'siebte', 'daher', 'zur', 'zugleich', 'zunächst', 'zurück', 'dahin', 'dürft', 'in', 'manche', 'seinen', 'welcher', 'jahre', 'kam', 'keine', 'habe', 'gibt', 'den', 'anderem', 'erste', 'niemand', 'hatte', 'meine', 'währenddessen', 'hin', 'seinem', 'vom', 'wollte', 'später', 'kommt', 'hinter', 'gut', 'magst', 'über', 'dies', 'jenes', 'fünfter', 'dabei', 'siebentes', 'guter', 'währenddem', 'gar', 'rechter', 'seit', 'sollten', 'beiden', 'einander', 'derjenigen', 'los', 'müsst', 'seitdem', 'gemocht', 'diejenige', 'ganz', 'keiner', 'kleiner', 'grossen', 'ganzen', 'daß', 'ihr', 'zehnte', 'sah', 'jener', 'dermassen', 'ich', 'mich', 'zwanzig', 'gutes', 'fünftes', 'darunter', 'ihre', 'dritter', 'wenig', 'allgemeinen', 'mein', 'übrigens', 'meines', 'neuntes', 'habt', 'bist', 'kleinen', 'deswegen', 'oben', 'was', 'ebenso', 'ja', 'tag', 'manches', 'tel', 'davon', 'kleine', 'entweder', 'eigene', 'manchem', 'zuerst', 'jetzt', 'ab', 'hat', 'sagt', 'wen', 'neuen', 'welchem', 'offen', 'bereits', 'irgend', 'morgen', 'siebten', 'oft', 'wann', 'zwar', 'würden', 'ganzer', 'mochten', 'sonst', 'zusammen', 'diesem', 'bisher', 'ehrlich', 'sowie', 'außerdem', 'je', 'niemanden', 'oder', 'welches', 'siebente', 'einiger', 'allem', 'diesen', 'werdet', 'dich', 'damals', 'durfte', 'kannst', 'weniges', 'gemusst', 'ging', 'hätten', 'zum', 'nachdem',  ...

# %% [markdown]
# Our first block shows how Spacy can read and process a single sentence. We look here at some different outputs, in particular:
#
# - Simple tokens: how Spacy breaks up the document into terms
# - Lemmas: processing of the tokens reducing them to canonical forms
# - Parts of speech: labelling each token with a part of speech
# - Stop words: finding tokens that are included in our stopword list
#
# Look at the results, and compare the differences between tokens and lemmas. Look at the part of speech tags - do they make sense? How many stop words do we find in the text?

# %%
#First we demonstrate how the NLP works for a single example document
#text = "Von einer den 7. und 8. Juli glücklich ausgeführten Besteigung des Wetterhorns über den Gauli-Gletscher und durch das Urbaeh-Thal auf der Grimsel angelangt, sah sich Hr. A.Hoffmann daselbst während drei Tagen durch Unwetter festgebannt und musste auf sein Finsteraarhorn - Besteigungs-projekt, bereits auf dem Oberaarjoch angekommen, wegen einfallenden Nebels und Schneefalls verzichten, froh, bei dunkler Nacht mit heiler Haut den Rückzug nach dem Spitale bewerkstelligen zu können."

with open('C:\\Users\\rsp\\Dropbox\\geo871_corpora\\textAndBerg1000\\SAC-Jahrbuch_1866_mul#18.txt', 'r', encoding='utf-8') as file:
    text = file.read().replace('\n', ' ')

doc = nlp(text) #Load and process a document using Spacy


print(f"{'Token':<20}\t{'Lemma':<20}\t{'POS':<6}\t{'Stop':<5}\n")
for token in doc:
    print(f"{token.text:<20}\t{token.lemma_:<20}\t{token.pos_:<6}\t{token.is_stop}")
# Out:
# Token               	Lemma               	POS   	Stop
#
# Grosse              	Grosse              	ADJ   	True
# Grindelwald-Viescherhorn	Grindelwald-Viescherhorn	NOUN  	False
# .                   	.                   	PUNCT 	False
# lA                  	lA                  	PROPN 	False
# iß                  	essen               	VERB  	False
# -                   	-                   	PUNCT 	False
#                     	                    	SPACE 	False
# Von                 	Von                 	ADP   	True
# Pfarrer             	Pfarrer             	NOUN  	False
# Gerwer              	Gerwer              	PROPN 	False
# in                  	in                  	ADP   	True
# Grindelwald         	Grindelwald         	PROPN 	False
# .                   	.                   	PUNCT 	False
# Der                 	der                 	DET   	True
# wässerige           	wässerig            	ADJ   	False
# August              	August              	NOUN  	False
# dieses              	dies                	DET   	True
# Jahres              	Jahr                	NOUN  	False
# hatte               	haben               	AUX   	True
# auch                	auch                	ADV   	True
# mir                 	sich                	PRON  	True
# ,                   	,                   	PUNCT 	False
# wie                 	wie                 	ADP   	True
# manchem             	manch               	DET   	True
# Anderen             	Andere              	NOUN  	True
# ,                   	,                   	PUNCT 	False
# die                 	der                 	PRON  	True
# Freude              	Freude              	NOUN  	False
# verdorben           	verderben           	VERB  	False
# .                   	.                   	PUNCT 	False
# Ich                 	Ich                 	PRON  	True
# durfte              	dürfen              	AUX   	True
# nicht               	nicht               	PART  	True
# hoffen              	hoffen              	VERB  	False
# ,                   	,                   	PUNCT 	False
# im                  	im                  	ADP   	True
# September           	September           	NOUN  	False
# viel                	viel                	PRON  	True
# nachholen           	nachholen           	VERB  	False
# zu                  	zu                  	PART  	True
# können              	können              	AUX   	True
# ,                   	,                   	PUNCT 	False
# weil                	weil                	SCONJ 	True
# die                 	der                 	DET   	True
# Bettagszeit         	Bettagszeit         	NOUN  	False
# mich                	sich                	PRON  	True
# an                  	an                  	ADP   	True
# meine               	meinen              	DET   	True
# Gemeinde            	Gemeinde            	NOUN  	False
# fesselte            	fesseln             	VERB  	False
# .                   	.                   	PUNCT 	False
# Ich                 	Ich                 	PRON  	True
# schaute             	schauen             	VERB  	False
# ,                   	,                   	PUNCT 	False
# aufrichtig          	aufrichtig          	ADV   	False
# gestanden           	stehen              	VERB  	False
# ,                   	,                   	PUNCT 	False
# nur                 	nur                 	ADV   	True
# halb                	halb                	ADV   	False
# vergnügt            	vergnügen           	ADV   	False
# in                  	in                  	ADP   	True
# die                 	der                 	DET   	True
# schönen             	schön               	ADJ   	False
# Herbsttage          	Herbsttage          	NOUN  	False
# hinein              	hinein              	ADV   	False
# .                   	.                   	PUNCT 	False
# Aber                	aber                	CCONJ 	True
# was                 	was                 	PRON  	True
# war                 	sein                	AUX   	True
# zu                  	zu                  	ADP   	True
# thunS'ist           	thunS'ist           	NOUN  	False
# es                  	ich                 	PRON  	True
# Lyde                	Lyde                	PROPN 	False
# ,                   	,                   	PUNCT 	False
# schick              	schicken            	X     	False
# di                  	di                  	X     	False
# dry                 	dry                 	X     	False
# .                   	.                   	PUNCT 	False
# "                   	"                   	PUNCT 	False
# So                  	so                  	ADV   	True
# sass                	sass                	VERB  	False
# ich                 	ich                 	PRON  	True
# am                  	am                  	ADP   	True
# Sonntag             	Sonntag             	NOUN  	False
# Abend               	Abend               	ADV   	False
# vor                 	vor                 	ADP   	True
# Bettag              	Bettag              	NOUN  	False
# auf                 	auf                 	ADP   	True
# unserem             	mein                	DET   	False
# „                   	„                   	PUNCT 	False
# Gletscherbänkli     	Gletscherbänkli     	NOUN  	False
# "                   	"                   	PUNCT 	False
# und                 	und                 	CCONJ 	True
# schickte            	schicken            	VERB  	False
# friedliche          	friedliche          	ADJ   	False
# Seufzer             	Seufzer             	NOUN  	False
# hinüber             	hinüber             	ADV   	False
# nach                	nach                	ADP   	True
# dem                 	der                 	DET   	True
# unteren             	unter               	ADJ   	False
# Gletscher           	Gletscher           	NOUN  	False
# und                 	und                 	CCONJ 	True
# dem                 	der                 	DET   	True
# schönen             	schön               	ADJ   	False
# Viescherkranze      	Viescherkranze      	NOUN  	False
# ,                   	,                   	PUNCT 	False
# nach                	nach                	ADP   	True
# dem                 	der                 	DET   	True
# Mettenberge         	Mettenberge         	NOUN  	False
# ,                   	,                   	PUNCT 	False
# dem                 	der                 	DET   	True
# Wetterhorn          	Wetterhorn          	NOUN  	False
# ,                   	,                   	PUNCT 	False
# dem                 	der                 	DET   	True
# Eiger               	Eiger               	NOUN  	False
# ,                   	,                   	PUNCT 	False
# den                 	der                 	DET   	True
# alten               	alt                 	ADJ   	False
# guten               	gut                 	ADJ   	False
# Bekannten           	bekennen            	NOUN  	False
# .                   	.                   	PUNCT 	False
# Der                 	der                 	DET   	True
# ganze               	ganze               	ADJ   	True
# Duft                	Duft                	NOUN  	False
# eines               	ein                 	DET   	True
# milden              	mild                	ADJ   	False
# herrlichen          	herrlich            	ADJ   	False
# Seçtemberabends     	Seçtemberabends     	NOUN  	False
# lag                 	liegen              	VERB  	False
# auf                 	auf                 	ADP   	True
# dem                 	der                 	DET   	True
# unvergleichlichen   	unvergleichlich     	ADJ   	False
# Bilde               	Bild                	NOUN  	False
# .                   	.                   	PUNCT 	False
# Fröhlich            	Fröhlich            	ADV   	False
# und                 	und                 	CCONJ 	True
# frei                	frei                	ADV   	False
# schritten           	schritten           	NOUN  	False
# die                 	der                 	DET   	True
# ankommenden         	ankommend           	ADJ   	False
# Reisenden           	Reisende            	NOUN  	False
# ihren               	mein                	DET   	True
# Weg                 	Weg                 	NOUN  	False
# dahin               	dahin               	ADV   	True
# ,                   	,                   	PUNCT 	False
# ohne                	ohne                	ADP   	True
# Sorge               	Sorge               	NOUN  	False
# ihre                	mein                	DET   	True
# Pläne               	Plan                	NOUN  	False
# ausführend          	ausführen           	ADV   	False
# ,                   	,                   	PUNCT 	False
# und                 	und                 	CCONJ 	True
# der                 	der                 	DET   	True
# junge               	junge               	ADJ   	False
# Pastor              	Pastor              	NOUN  	False
# seufzte             	seufzen             	VERB  	False
# :                   	:                   	PUNCT 	False
# „                   	„                   	PUNCT 	False
# Ach                 	Ach                 	INTJ  	True
# !                   	!                   	PUNCT 	False
# dass                	dass                	SCONJ 	True
# ich                 	ich                 	PRON  	True
# gefangen            	fangen              	VERB  	False
# bin                 	sein                	AUX   	True
# !                   	!                   	PUNCT 	False
# "                   	"                   	PUNCT 	False
# Auf                 	Auf                 	ADP   	True
# einmal              	einmal              	ADV   	True
# springt             	springen            	VERB  	False
# so                  	so                  	ADV   	True
# ein                 	einen               	DET   	True
# Tourist             	Tourist             	NOUN  	False
# über                	über                	ADP   	True
# die                 	der                 	DET   	True
# Matte               	Matte               	NOUN  	False
# herauf              	herauf              	ADP   	False
# mich                	sich                	PRON  	True
# zu                  	zu                  	ADP   	True
# :                   	:                   	PUNCT 	False
#                     	                    	SPACE 	False
# Herr                	Herr                	NOUN  	False
# Dr.                 	Dr.                 	NOUN  	False
# Weber               	Weber               	PROPN 	False
# aus                 	aus                 	ADP   	True
# London              	London              	PROPN 	False
# ,                   	,                   	PUNCT 	False
# dessen              	der                 	DET   	True
# Bekanntschaft       	Bekanntschaft       	NOUN  	False
# ich                 	ich                 	PRON  	True
# vor                 	vor                 	ADP   	True
# einem               	einer               	DET   	True
# Jahre               	Jahr                	NOUN  	True
# zu                  	zu                  	PART  	True
# machen              	machen              	VERB  	True
# das                 	der                 	DET   	True
# Vergnügen           	Vergnügen           	NOUN  	False
# gehabt              	haben               	VERB  	True
# .                   	.                   	PUNCT 	False
# Noch                	Noch                	ADV   	True
# ahnte               	ahnen               	VERB  	False
# ich                 	ich                 	PRON  	True
# nicht               	nicht               	PART  	True
# ,                   	,                   	PUNCT 	False
# dass                	dass                	SCONJ 	True
# er                  	ich                 	PRON  	True
# den                 	der                 	DET   	True
# Bann                	Bann                	NOUN  	False
# von                 	von                 	ADP   	True
# mir                 	sich                	PRON  	True
# zu                  	zu                  	PART  	True
# lösen               	lösen               	VERB  	False
# gekommen            	kommen              	VERB  	False
# sei                 	sein                	AUX   	True
# .                   	.                   	PUNCT 	False
# Nach                	Nach                	ADP   	True
# freundlicher        	freundlich          	ADJ   	False
# gegenseitiger       	gegenseitig         	ADJ   	False
# Begrüssung          	Begrüssung          	NOUN  	False
# fragte              	fragen              	VERB  	False
# er                  	ich                 	PRON  	True
# um                  	um                  	ADP   	True
# Rath                	Rath                	PROPN 	False
# ,                   	,                   	PUNCT 	False
# was                 	was                 	PRON  	True
# er                  	ich                 	PRON  	True
# doch                	doch                	ADV   	True
# machen              	machen              	VERB  	True
# könnte              	können              	AUX   	True
# .                   	.                   	PUNCT 	False
# Da                  	da                  	SCONJ 	True
# er                  	ich                 	PRON  	True
# zum                 	zum                 	ADP   	True
# Wetterhorn          	Wetterhorn          	NOUN  	False
# ,                   	,                   	PUNCT 	False
# das                 	der                 	PRON  	True
# ihn                 	ich                 	PRON  	True
# vor                 	vor                 	ADP   	True
# einem               	einer               	DET   	True
# Jahre               	Jahr                	NOUN  	True
# gar                 	gar                 	ADV   	True
# schmählich          	schmählich          	ADV   	False
# und                 	und                 	CCONJ 	True
# schmutzig           	schmutzig           	ADV   	False
# aufgenommen         	aufnehmen           	VERB  	False
# hatte               	haben               	AUX   	True
# ,                   	,                   	PUNCT 	False
# keine               	kein                	DET   	True
# Zuneigung           	Zuneigung           	NOUN  	False
# mehr                	mehr                	ADV   	True
# verspürte           	verspüren           	VERB  	False
# ,                   	,                   	PUNCT 	False
# so                  	so                  	ADV   	True
# rieth               	rieth               	PROPN 	False
# ich                 	ich                 	PRON  	True
# in                  	in                  	ADP   	True
# grösser             	grösser             	ADJ   	False
# Resignation         	Resignation         	NOUN  	False
# zum                 	zum                 	ADP   	True
# grossen             	grossen             	ADJ   	True
# Viescherhorn        	Viescherhorn        	NOUN  	False
# .                   	.                   	PUNCT 	False
# „                   	„                   	PUNCT 	False
# Gut                 	Gut                 	ADV   	True
# ,                   	,                   	PUNCT 	False
# abgemacht           	abmachen            	VERB  	False
# !                   	!                   	PUNCT 	False
# Und                 	und                 	CCONJ 	True
# Sie                 	ich                 	PRON  	True
# kommen              	kommen              	VERB  	True
# doch                	doch                	ADV   	True
# mitLeider           	mitLeider           	NOUN  	False
# nein                	nein                	PART  	True
# !                   	!                   	PUNCT 	False
# Ich                 	Ich                 	PRON  	True
# kann                	können              	AUX   	True
# fast                	fast                	ADV   	False
# nicht               	nicht               	PART  	True
# und                 	und                 	CCONJ 	True
# thät                	thät                	ADV   	False
# 's                  	's                  	PRON  	False
# doch                	doch                	ADV   	True
# so                  	so                  	ADV   	True
# gern                	gern                	ADV   	True
# .                   	.                   	PUNCT 	False
# "                   	"                   	PUNCT 	False
# Herr                	Herr                	NOUN  	False
# Weber               	Weber               	PROPN 	False
# mochte              	mögen               	VERB  	True
# aus                 	aus                 	ADP   	True
# meinem              	mein                	DET   	True
# Tone                	Ton                 	NOUN  	False
# herausgefühlt       	herausgefühlt       	VERB  	False
# haben               	haben               	AUX   	True
# ,                   	,                   	PUNCT 	False
# wie                 	wie                 	ADV   	True
# schwer              	schwer              	ADV   	False
# mir                 	sich                	PRON  	True
# das                 	der                 	DET   	True
# Nein                	Nein                	NOUN  	True
# wurde               	werden              	AUX   	True
# ,                   	,                   	PUNCT 	False
# er                  	ich                 	PRON  	True
# fand                	finden              	VERB  	False
# darum               	darum               	ADV   	True
# bald                	bald                	ADV   	True
# das                 	der                 	DET   	True
# rechte              	rechte              	ADJ   	True
# Wort                	Wort                	NOUN  	False
# .                   	.                   	PUNCT 	False
# „                   	„                   	PUNCT 	False
# Das                 	der                 	PRON  	True
# thut                	thut                	VERB  	False
# mir                 	sich                	PRON  	True
# leid                	leid                	ADV   	False
# ,                   	,                   	PUNCT 	False
# sagte               	sagen               	VERB  	True
# er                  	ich                 	PRON  	True
# ,                   	,                   	PUNCT 	False
# allein              	allein              	ADV   	True
# mag                 	mögen               	AUX   	True
# ich                 	ich                 	PRON  	True
# 's                  	's                  	PRON  	False
# auch                	auch                	ADV   	True
# nicht               	nicht               	PART  	True
# machen              	machen              	VERB  	True
# ;                   	;                   	PUNCT 	False
# dann                	dann                	ADV   	True
# bin                 	sein                	AUX   	True
# ich                 	ich                 	PRON  	True
# vergeblich          	vergeblich          	ADV   	False
# nach                	nach                	ADP   	True
# Çirindelwald        	Çirindelwald        	NOUN  	False
# gekommen            	kommen              	VERB  	False
# .                   	.                   	PUNCT 	False
# Ja                  	Ja                  	PART  	True
# ,                   	,                   	PUNCT 	False
# der                 	der                 	DET   	True
# Tausend             	Tausend             	NOUN  	False
# !                   	!                   	PUNCT 	False
# So                  	so                  	ADV   	True
# ist                 	sein                	AUX   	True
# 's                  	's                  	PRON  	False
# doch                	doch                	ADV   	True
# nicht               	nicht               	PART  	True
# gemeint             	meinen              	VERB  	False
# ,                   	,                   	PUNCT 	False
# Herr                	Herr                	NOUN  	False
# Doctor              	Doctor              	NOUN  	False
# ;                   	;                   	PUNCT 	False
# das                 	der                 	PRON  	True
# möchte              	mögen               	AUX   	True
# ich                 	ich                 	PRON  	True
# nicht               	nicht               	PART  	True
# ,                   	,                   	PUNCT 	False
# ich                 	ich                 	PRON  	True
# geh'mit.4           	geh'mit.4           	ADV   	False
# *                   	*                   	PUNCT 	False
# Fertig              	Fertig              	ADV   	False
# war                 	sein                	AUX   	True
# 's                  	's                  	PRON  	False
# ;                   	;                   	PUNCT 	False
# gerüstet            	rüsten              	VERB  	False
# wurden              	werden              	AUX   	True
# Decken              	Decke               	NOUN  	False
# und                 	und                 	CCONJ 	True
# Proviant            	Proviant            	NOUN  	False
# im                  	im                  	ADP   	True
# Pfarr-              	Pfarr-              	X     	False
# und                 	und                 	CCONJ 	True
# Wirthshause         	Wirthshause         	NOUN  	False
# .                   	.                   	PUNCT 	False
# Meine               	Meine               	DET   	True
# gute                	gut                 	ADJ   	True
# Frau                	Frau                	NOUN  	False
# erschrack           	erschrack           	VERB  	False
# nicht               	nicht               	PART  	True
# sehr                	sehr                	ADV   	True
# ;                   	;                   	PUNCT 	False
# seit                	seit                	ADP   	True
# Schreckhorn         	Schreckhorn         	NOUN  	False
# undEiger            	undEiger            	ADV   	False
# überwunden          	überwinden          	VERB  	False
# sind                	sein                	AUX   	True
# ,                   	,                   	PUNCT 	False
# schrecken           	schrecken           	VERB  	False
# die                 	der                 	DET   	True
# anderen             	ander               	ADJ   	True
# Grindelwaldner      	Grindelwaldner      	NOUN  	False
# nicht               	nicht               	PART  	True
# mehr                	mehr                	ADV   	True
# .                   	.                   	PUNCT 	False
# Unsere              	mein                	DET   	True
# "                   	"                   	PUNCT 	False
# liebe               	lieb                	ADJ   	False
# Noth                	Noth                	NOUN  	False
# hatten              	haben               	AUX   	True
# wir                 	ich                 	PRON  	True
# ,                   	,                   	PUNCT 	False
# tüchtige            	tüchtige            	ADJ   	False
# Führer              	Führer              	NOUN  	False
# zu                  	zu                  	PART  	True
# finden              	finden              	VERB  	False
# ;                   	;                   	PUNCT 	False
# fast                	fast                	ADV   	False
# Alle                	all                 	PRON  	True
# waren               	sein                	AUX   	True
# fort                	fort                	ADV   	False
# oder                	oder                	CCONJ 	True
# engagirt            	engagirt            	VERB  	False
# .                   	.                   	PUNCT 	False
# Peter               	Peter               	PROPN 	False
# Rubi                	Rubi                	PROPN 	False
# ,                   	,                   	PUNCT 	False
# den                 	der                 	PRON  	True
# wir                 	ich                 	PRON  	True
# als                 	als                 	ADP   	True
# Führer              	Führer              	NOUN  	False
# ersten              	erst                	ADJ   	True
# Ranges              	Rang                	NOUN  	False
# empfehlen           	empfehlen           	VERB  	False
# können              	können              	AUX   	True
# ,                   	,                   	PUNCT 	False
# wurde               	werden              	AUX   	True
# glücklich           	glücklich           	ADV   	False
# noch                	noch                	ADV   	True
# erwischt            	erwischen           	VERB  	False
# und                 	und                 	CCONJ 	True
# war                 	sein                	AUX   	True
# gern                	gern                	ADV   	True
# bereit              	bereiten            	ADV   	False
# ;                   	;                   	PUNCT 	False
# etwas               	etwas               	DET   	True
# Complimente         	Complimente         	NOUN  	False
# machte              	machen              	VERB  	True
# Peter               	Peter               	PROPN 	False
# Inäbnit             	Inäbnit             	PROPN 	False
# aus                 	aus                 	ADP   	True
# purer               	pur                 	ADJ   	False
# Eifersucht          	Eifersucht          	NOUN  	False
# ,                   	,                   	PUNCT 	False
# weil                	weil                	SCONJ 	True
# vor                 	vor                 	ADP   	True
# ihm                 	ich                 	PRON  	True
# Peter               	Peter               	PROPN 	False
# Michel              	Michel              	PROPN 	False
# war                 	sein                	AUX   	True
# angefragt           	anfragen            	VERB  	False
# worden              	werden              	AUX   	True
# .                   	.                   	PUNCT 	False
# Doch                	doch                	CCONJ 	True
# kam                 	kommen              	VERB  	True
# 's                  	's                  	PRON  	False
# auch                	auch                	ADV   	True
# mit                 	mit                 	ADP   	True
# ihm                 	ich                 	PRON  	True
# in                  	in                  	ADP   	True
# 's                  	's                  	PRON  	False
# Reine               	rein                	NOUN  	False
# .                   	.                   	PUNCT 	False
# Keiner              	kein                	PRON  	True
# von                 	von                 	ADP   	True
# Beiden              	beid                	NOUN  	True
# hatte               	haben               	AUX   	True
# das                 	der                 	DET   	True
# grosse              	grosse              	ADJ   	True
# Viescherhorn        	Viescherhorn        	NOUN  	False
# noch                	noch                	ADV   	True
# bestiegen           	besteigen           	VERB  	False
# .                   	.                   	PUNCT 	False
# Als                 	als                 	ADP   	True
# Träger              	Träger              	NOUN  	False
# war                 	sein                	AUX   	True
# Peter               	Peter               	PROPN 	False
# Baumann             	Baumann             	PROPN 	False
# engagirt            	engagirt            	VERB  	False
# ,                   	,                   	PUNCT 	False
# ein                 	einen               	DET   	True
# unschuldig          	unschuldig          	ADV   	False
# Blut                	Blut                	NOUN  	False
# ;                   	;                   	PUNCT 	False
# doch                	doch                	ADV   	True
# hatte               	haben               	AUX   	True
# er                  	ich                 	PRON  	True
# als                 	als                 	ADP   	True
# Träger              	Träger              	NOUN  	False
# sehon               	sehon               	NOUN  	False
# gute                	gut                 	ADJ   	True
# Dienste             	Dienst              	NOUN  	False
# geleistet           	leisten             	VERB  	False
# m                   	m                   	ADP   	False
# Gaggi-gletscher     	Gaggi-gletscher     	ADV   	False
# .                   	.                   	PUNCT 	False
# Beschlossen         	Beschlossen         	VERB  	False
# wurde               	werden              	AUX   	True
# ,                   	,                   	PUNCT 	False
# Montags             	Montag              	ADV   	False
# die                 	der                 	DET   	True
# neu                 	neu                 	ADV   	False
# errichtete          	errichten           	ADJ   	False
# Hütte               	Hütte               	NOUN  	False
# hinter              	hinter              	ADP   	True
# dem                 	der                 	DET   	True
# Mönch               	Mönch               	NOUN  	False
# einzuweihen         	einweihen           	VERB  	False
# ,                   	,                   	PUNCT 	False
# dort                	dort                	ADV   	True
# Quartier            	Quartier            	NOUN  	False
# zu                  	zu                  	PART  	True
# nehmen              	nehmen              	VERB  	False
# und                 	und                 	CCONJ 	True
# Dienstags           	Dienstag            	NOUN  	False
# ,                   	,                   	PUNCT 	False
# den                 	der                 	DET   	True
# 12.                 	12.                 	ADJ   	False
# September           	September           	NOUN  	False
# ,                   	,                   	PUNCT 	False
# das                 	der                 	DET   	True
# Viescherhorn        	Viescherhorn        	NOUN  	False
# selbst              	selbst              	ADV   	True
# von                 	von                 	ADP   	True
# da                  	da                  	ADV   	True
# aus                 	aus                 	ADV   	True
# anzugreifen         	angreifen           	VERB  	False
# .                   	.                   	PUNCT 	False
# Zu                  	zu                  	PART  	True
# eilen               	eilen               	VERB  	False
# hatten              	haben               	AUX   	True
# wir                 	ich                 	PRON  	True
# deshalb             	deshalb             	ADV   	True
# nicht               	nicht               	PART  	True
# ,                   	,                   	PUNCT 	False
# und                 	und                 	CCONJ 	True
# so                  	so                  	ADV   	True
# wurde               	werden              	AUX   	True
# erst                	erst                	ADV   	True
# um                  	um                  	ADP   	True
# 7*/2                	7*/2                	ADJ   	False
# Uhr                 	Uhr                 	NOUN  	True
# des                 	der                 	DET   	True
# nächsten            	nächst              	ADJ   	False
# Morgens             	Morgen              	NOUN  	False
# auf-                	auf-                	PRON  	False
# gebrochen           	brechen             	VERB  	False
# .                   	.                   	PUNCT 	False
# Wohl                	Wohl                	ADV   	True
# versehen            	versehen            	VERB  	False
# mit                 	mit                 	ADP   	True
# allem               	alle                	PRON  	True
# Nöthigen            	Nöthigen            	NOUN  	False
# ,                   	,                   	PUNCT 	False
# schlenderten        	schlendern          	VERB  	False
# wir                 	ich                 	PRON  	True
# con                 	con                 	PROPN 	False
# amore               	amore               	X     	False
# in                  	in                  	ADP   	True
# l1^                 	l1^                 	PROPN 	False
# Stunden             	Stunde              	NOUN  	False
# nach                	nach                	ADP   	True
# dem                 	der                 	DET   	True
# „                   	„                   	PUNCT 	False
# Bärenegg            	Bärenegg            	NOUN  	False
# "                   	"                   	PUNCT 	False
# am                  	am                  	ADP   	True
# Eismeere            	Eismeere            	NOUN  	False
# .                   	.                   	PUNCT 	False
# Mit                 	Mit                 	ADP   	True
# eben                	eben                	ADV   	True
# so                  	so                  	ADV   	True
# viel                	viel                	DET   	True
# Musse               	Muß                 	NOUN  	False
# wurde               	werden              	AUX   	True
# hier                	hier                	ADV   	True
# ein                 	einen               	DET   	True
# Imbiss              	Imbiss              	NOUN  	False
# genommen            	nehmen              	VERB  	False
# und                 	und                 	CCONJ 	True
# als                 	als                 	ADP   	True
# zweiter             	zweit               	ADJ   	True
# Träger              	Träger              	NOUN  	False
# auf                 	auf                 	ADP   	True
# den                 	der                 	DET   	True
# Triften             	Triften             	NOUN  	False
# am                  	am                  	ADP   	True
# Eismeere            	Eismeere            	NOUN  	False
# der                 	der                 	DET   	True
# Schafhirt           	Schafhirt           	NOUN  	False
# Christ              	Christ              	PROPN 	False
# .                   	.                   	PUNCT 	False
# Meyer               	Meyer               	PROPN 	False
# engagirt            	engagirt            	VERB  	False
# .                   	.                   	PUNCT 	False
# Mit                 	Mit                 	ADP   	True
# ihm                 	ich                 	PRON  	True
# hatten              	haben               	AUX   	True
# wir                 	ich                 	PRON  	True
# in                  	in                  	ADP   	True
# der                 	der                 	DET   	True
# Folge               	Folge               	NOUN  	False
# alle                	all                 	DET   	True
# Ursache             	Ursache             	NOUN  	False
# ,                   	,                   	PUNCT 	False
# sehr                	sehr                	ADV   	True
# zufrieden           	zufrieden           	ADV   	False
# zu                  	zu                  	PART  	True
# sein                	mein                	AUX   	True
# ;                   	;                   	PUNCT 	False
# er                  	ich                 	PRON  	True
# ist                 	sein                	AUX   	True
# ein                 	einen               	DET   	True
# guter               	gut                 	ADJ   	True
# Gänger              	Gänger              	NOUN  	False
# in                  	in                  	ADP   	True
# Fels                	Fels                	NOUN  	False
# und                 	und                 	CCONJ 	True
# Eis                 	Eis                 	NOUN  	False
# ,                   	,                   	PUNCT 	False
# sein                	mein                	DET   	True
# Blick               	Blick               	NOUN  	False
# ist                 	sein                	AUX   	True
# gewandt             	wenden              	ADV   	False
# und                 	und                 	CCONJ 	True
# richtig             	richtig             	ADV   	True
# ,                   	,                   	PUNCT 	False
# dabei               	dabei               	ADV   	True
# ist                 	sein                	AUX   	True
# er                  	ich                 	PRON  	True
# stark               	stark               	ADV   	False
# ,                   	,                   	PUNCT 	False
# er                  	ich                 	PRON  	True
# würde               	werden              	AUX   	True
# auch                	auch                	ADV   	True
# als                 	als                 	ADP   	True
# Führer              	Führer              	NOUN  	False
# bei                 	bei                 	ADP   	True
# einiger             	einig               	DET   	True
# Uebung              	Uebung              	NOUN  	False
# ganz                	ganz                	ADV   	True
# gute                	gut                 	ADJ   	True
# Dienste             	Dienst              	NOUN  	False
# leisten             	leisten             	VERB  	False
# .                   	.                   	PUNCT 	False
# Unsere              	mein                	DET   	True
# Bagage              	Bagage              	NOUN  	False
# ,                   	,                   	PUNCT 	False
# wovon               	wovon               	SCONJ 	False
# die                 	der                 	DET   	True
# wollenen            	wollenen            	ADJ   	False
# Decken              	Decke               	NOUN  	False
# das                 	der                 	DET   	True
# Hauptgewicht        	Hauptgewicht        	NOUN  	False
# und                 	und                 	CCONJ 	True
# -Volumen            	-Volumen            	NOUN  	False
# ausmachten          	ausmachen           	VERB  	False
# ,                   	,                   	PUNCT 	False
# wurde               	werden              	AUX   	True
# auf                 	auf                 	ADP   	True
# die                 	der                 	DET   	True
# vier                	vier                	NUM   	True
# Mann                	Mann                	NOUN  	False
# nach                	nach                	ADP   	True
# Gebühr              	Gebühr              	NOUN  	False
# vertheilt           	vertheilt           	VERB  	False
# und                 	und                 	CCONJ 	True
# um                  	um                  	ADP   	True
# lO1/^               	lO1/^               	NOUN  	False
# Uhr                 	Uhr                 	NOUN  	True
# unter               	unter               	ADP   	True
# gehörigen           	gehörig             	ADJ   	False
# Glückwünschen       	Glückwünschen       	NOUN  	False
# der                 	der                 	DET   	True
# Wirthsleute         	Wirthsleute         	NOUN  	False
# und                 	und                 	CCONJ 	True
# anwesenden          	anwesend            	ADJ   	False
# Gäste               	Gast                	NOUN  	False
# abmarschirt         	abmarschirt         	VERB  	False
# .                   	.                   	PUNCT 	False
# Quer                	Quer                	ADV   	False
# das                 	der                 	DET   	True
# Eismeer             	Eismeer             	PROPN 	False
# überschreitend      	überschreiten       	ADV   	False
# strebten            	streben             	VERB  	False
# wir                 	ich                 	PRON  	True
# dem                 	der                 	DET   	True
# „                   	„                   	PUNCT 	False
# Kalli               	Kalli               	PROPN 	False
# "                   	"                   	PUNCT 	False
# zu                  	zu                  	ADP   	True
# ,                   	,                   	PUNCT 	False
# alter               	altern              	ADJ   	False
# Lawinenschnee       	Lawinenschnee       	NOUN  	False
# breitete            	breiten             	VERB  	False
# sich                	sich                	PRON  	True
# hier                	hier                	ADV   	True
# prächtig            	prächtig            	ADV   	False
# vom                 	vom                 	ADP   	True
# Gletscher           	Gletscher           	NOUN  	False
# zur                 	zur                 	ADP   	True
# grünen              	grün                	ADJ   	False
# Trift               	Trift               	NOUN  	False
# .                   	.                   	PUNCT 	False
# Steil               	Steil               	ADV   	False
# ansteigend          	ansteigen           	ADV   	False
# wanden              	winden              	VERB  	False
# wir                 	ich                 	PRON  	True
# uns                 	sich                	PRON  	True
# durch               	durch               	ADP   	True
# das                 	der                 	DET   	True
# „                   	„                   	PUNCT 	False
# untere              	untere              	ADJ   	False
# Kalli               	Kalli               	PROPN 	False
# "                   	"                   	PUNCT 	False
# über                	über                	ADP   	True
# dichtes             	dicht               	ADJ   	False
# Gesträuch           	Gesträuch           	NOUN  	False
# von                 	von                 	ADP   	True
# Alpenrosen          	Alpenrose           	NOUN  	False
# hinan               	hinan               	ADV   	False
# ;                   	;                   	PUNCT 	False
# einige              	einig               	DET   	True
# Ziegen              	Ziege               	NOUN  	False
# meckerten           	meckern             	VERB  	False
# ihr                 	mein                	DET   	True
# gewohntes           	gewohnt             	ADJ   	False
# Woher               	Woher               	NOUN  	False
# ?                   	?                   	PUNCT 	False
# Wohin               	Wohin               	ADV   	False
# ?                   	?                   	PUNCT 	False
# und                 	und                 	CCONJ 	True
# was                 	was                 	PRON  	True
# sie                 	ich                 	PRON  	True
# sonst               	sonst               	ADV   	True
# immer               	immer               	ADV   	True
# zu                  	zu                  	PART  	True
# fragen              	fragen              	VERB  	False
# haben               	haben               	AUX   	True
# .                   	.                   	PUNCT 	False
# Der                 	der                 	DET   	True
# sogenannte          	sogenannt           	ADJ   	False
# „                   	„                   	PUNCT 	False
# Kallitritt          	Kallitritt          	NOUN  	False
# "                   	"                   	PUNCT 	False
# ,                   	,                   	PUNCT 	False
# ein                 	einen               	DET   	True
# Felsabsatz          	Felsabsatz          	NOUN  	False
# und                 	und                 	CCONJ 	True
# Felsband            	Felsband            	NOUN  	False
# ,                   	,                   	PUNCT 	False
# scheidet            	scheiden            	VERB  	False
# das                 	der                 	DET   	True
# untere              	untere              	ADJ   	False
# vom                 	vom                 	ADP   	True
# „                   	„                   	PUNCT 	False
# oberen              	ober                	ADJ   	False
# Kalli               	Kalli               	PROPN 	False
# "                   	"                   	PUNCT 	False
# ,                   	,                   	PUNCT 	False
# wo                  	wo                  	SCONJ 	True
# das                 	der                 	DET   	True
# Ansteigen           	Ansteigen           	NOUN  	False
# nicht               	nicht               	PART  	True
# weniger             	wenig               	ADV   	True
# steil               	steil               	ADV   	False
# ,                   	,                   	PUNCT 	False
# die                 	der                 	DET   	True
# Weide               	Weide               	NOUN  	False
# spärlicher          	spärlich            	ADV   	False
# ist                 	sein                	AUX   	True
# .                   	.                   	PUNCT 	False
# Um                  	um                  	ADP   	True
# 12                  	12                  	NUM   	False
# Uhr                 	Uhr                 	NOUN  	True
# 50                  	50                  	NUM   	False
# M.                  	M.                  	PROPN 	False
# nach                	nach                	ADP   	True
# einem               	einer               	DET   	True
# kurzen              	kurz                	ADJ   	False
# Halt                	Halt                	NOUN  	False
# wurde               	werden              	AUX   	True
# der                 	der                 	DET   	True
# „                   	„                   	PUNCT 	False
# Grindelwalder       	Grindelwalder       	ADJ   	False
# Vieschergletscher   	Vieschergletscher   	NOUN  	False
# "                   	"                   	PUNCT 	False
# betreten            	betreten            	VERB  	False
# ,                   	,                   	PUNCT 	False
# der                 	der                 	PRON  	True
# von                 	von                 	ADP   	True
# der                 	der                 	DET   	True
# Höhe                	Höhe                	NOUN  	False
# des                 	der                 	DET   	True
# Mönchsjoches        	Mönchsjoches        	NOUN  	False
# und                 	und                 	CCONJ 	True
# Vieschergrates      	Vieschergrates      	NOUN  	False
# sich                	sich                	PRON  	True
# hinunter            	hinunter            	ADV   	False
# zieht               	ziehen              	VERB  	False
# in                  	in                  	ADP   	True
# 's                  	's                  	PRON  	False
# Eismeer             	Eismeer             	PROPN 	False
# .                   	.                   	PUNCT 	False
# Arg                 	Arg                 	ADV   	False
# verschrundet        	verschrundet        	VERB  	False
# ist                 	sein                	AUX   	True
# dieser              	dies                	DET   	True
# gewaltige           	gewaltig            	ADJ   	False
# ,                   	,                   	PUNCT 	False
# steil               	steil               	ADV   	False
# abfallende          	abfallend           	ADJ   	False
# Gletscherhang       	Gletscherhang       	NOUN  	False
# ;                   	;                   	PUNCT 	False
# nicht               	nicht               	PART  	True
# immer               	immer               	ADV   	True
# ist                 	sein                	AUX   	True
# daher               	daher               	ADV   	True
# die                 	der                 	DET   	True
# Ueber-              	Ueber-              	PROPN 	False
# schreitung          	schreitung          	NOUN  	False
# des                 	der                 	DET   	True
# Joches              	Joches              	NOUN  	False
# leicht              	leicht              	ADV   	True
# ;                   	;                   	PUNCT 	False
# es                  	ich                 	PRON  	True
# fordert             	fordern             	VERB  	False
# gehörige            	gehörig             	ADJ   	False
# Terrainkenntniss    	Terrainkenntniss    	NOUN  	False
# und                 	und                 	CCONJ 	True
# Geistesgegenwart    	Geistesgegenwart    	NOUN  	False
# ,                   	,                   	PUNCT 	False
# ächte               	ächten              	ADJ   	False
# Gletschermannen     	Gletschermannen     	NOUN  	False
# ,                   	,                   	PUNCT 	False
# um                  	um                  	SCONJ 	True
# z.B.                	z.B.                	NOUN  	False
# bei                 	bei                 	ADP   	True
# nebligem            	neblig              	ADJ   	False
# Wetter              	Wetter              	NOUN  	False
# auch                	auch                	ADV   	True
# glücklich           	glücklich           	ADV   	False
# durch               	durch               	ADP   	True
# dieses              	dies                	DET   	True
# Labyrinth           	Labyrinth           	NOUN  	False
# unregelmässiger     	unregelmässiger     	ADV   	False
# und                 	und                 	CCONJ 	True
# oft                 	oft                 	ADV   	True
# prachtvoller        	prachtvoll          	ADJ   	False
# Schrunde            	Schrunde            	NOUN  	False
# hindurch            	hindurch            	ADV   	False
# zu                  	zu                  	ADP   	True
# lootsen             	lootsen             	NOUN  	False
# .                   	.                   	PUNCT 	False
# Freund              	Freund              	NOUN  	False
# Fellenberg          	Fellenberg          	PROPN 	False
# weiss               	weiss               	PROPN 	False
# davon               	davon               	ADV   	True
# zu                  	zu                  	PART  	True
# erzählen            	erzählen            	VERB  	False
# .                   	.                   	PUNCT 	False
# Von                 	Von                 	ADP   	True
# den                 	der                 	DET   	True
# drei                	drei                	NUM   	True
# begangenen          	begangen            	ADJ   	False
# Gletscherpässen     	Gletscherpässen     	NOUN  	False
# Grindelwald's       	Grindelwald's       	PROPN 	False
# ,                   	,                   	PUNCT 	False
# dem                 	der                 	DET   	True
# Lauteraarjoch       	Lauteraarjoch       	NOUN  	False
# ,                   	,                   	PUNCT 	False
# der                 	der                 	DET   	True
# Strahleck           	Strahleck           	NOUN  	False
# und                 	und                 	CCONJ 	True
# dem                 	der                 	DET   	True
# Mönchjoch           	Mönchjoch           	NOUN  	False
# ,                   	,                   	PUNCT 	False
# ist                 	sein                	AUX   	True
# der                 	der                 	DET   	True
# letztere            	letzter             	ADJ   	False
# unstreitig          	unstreitig          	ADV   	False
# der                 	der                 	DET   	True
# ...
# verlangt            	verlangen           	VERB  	False
# ihr                 	mein                	DET   	True
# Recht               	Recht               	NOUN  	True
# und                 	und                 	CCONJ 	True
# freut               	freuen              	VERB  	False
# sich                	sich                	PRON  	True
# des                 	der                 	DET   	True
# Erlangten           	Erlangte            	NOUN  	False
# ,                   	,                   	PUNCT 	False
# wie                 	wie                 	SCONJ 	True
# Geist               	Geist               	NOUN  	False
# und                 	und                 	CCONJ 	True
# Gemüth              	Gemüth              	NOUN  	False
# sich                	sich                	PRON  	True
# freut               	freuen              	VERB  	False
# der                 	der                 	DET   	True
# Herrlichkeiten      	Herrlichkeit        	NOUN  	False
# der                 	der                 	DET   	True
# grossen             	grossen             	ADJ   	True
# schönen             	schön               	ADJ   	False
# Gotteswelt          	Gotteswelt          	NOUN  	False
# ,                   	,                   	PUNCT 	False
# von                 	von                 	ADP   	True
# der                 	der                 	PRON  	True
# wir                 	ich                 	PRON  	True
# wieder              	wieder              	ADV   	True
# einen               	ein                 	DET   	True
# so                  	so                  	ADV   	True
# interessanten       	interessant         	ADJ   	False
# Theil               	Theil               	NOUN  	False
# gesehen             	sehen               	VERB  	False
# .                   	.                   	PUNCT 	False
# Vergleiches         	Vergleich           	VERB  	False
# wir                 	ich                 	PRON  	True
# die                 	der                 	DET   	True
# Aussicht            	Aussicht            	NOUN  	False
# vom                 	vom                 	ADP   	True
# Viescherhorn        	Viescherhorn        	NOUN  	False
# mit                 	mit                 	ADP   	True
# der                 	der                 	DET   	True
# von                 	von                 	ADP   	True
# den                 	der                 	DET   	True
# übrigen             	übrig               	ADJ   	False
# Grindelwaldner      	Grindelwaldner      	ADJ   	False
# Grossen             	Grossen             	NOUN  	True
# ,                   	,                   	PUNCT 	False
# so                  	so                  	ADV   	True
# steht               	stehen              	VERB  	False
# unstreitig          	unstreitig          	ADV   	False
# der                 	der                 	DET   	True
# Eiger               	Eiger               	NOUN  	False
# und                 	und                 	CCONJ 	True
# auch                	auch                	ADV   	True
# das                 	der                 	DET   	True
# Wetterhorn          	Wetterhorn          	NOUN  	False
# bei                 	bei                 	ADP   	True
# weitem              	weit                	ADJ   	False
# voran               	voran               	ADP   	False
# hinsichtlich        	hinsichtlich        	ADP   	False
# des                 	der                 	DET   	True
# malerischen         	malerisch           	ADJ   	False
# Gesammteffectes     	Gesammteffectes     	NOUN  	False
# ,                   	,                   	PUNCT 	False
# besonders           	besonders           	ADV   	True
# des                 	der                 	DET   	True
# Blickes             	Blickes             	NOUN  	False
# nach                	nach                	ADP   	True
# Norden              	Norden              	NOUN  	False
# ;                   	;                   	PUNCT 	False
# das                 	der                 	PRON  	True
# muss                	muss                	AUX   	True
# auch                	auch                	ADV   	True
# dann                	dann                	ADV   	True
# der                 	der                 	DET   	True
# Fall                	Fall                	NOUN  	False
# sein                	mein                	AUX   	True
# ,                   	,                   	PUNCT 	False
# wenn                	wenn                	SCONJ 	True
# 19                  	19                  	NUM   	False
# *                   	*                   	NOUN  	False
# das                 	der                 	DET   	True
# Wetter              	Wetter              	NOUN  	False
# ganz                	ganz                	ADV   	True
# heiter              	heitern             	ADV   	False
# ,                   	,                   	PUNCT 	False
# der                 	der                 	DET   	True
# Ausblick            	Ausblick            	NOUN  	False
# vom                 	vom                 	ADP   	True
# Viescherhorn        	Viescherhorn        	NOUN  	False
# ganz                	ganz                	ADV   	True
# frei                	frei                	ADV   	False
# wäre                	sein                	AUX   	True
# ;                   	;                   	PUNCT 	False
# es                  	ich                 	PRON  	True
# steht               	stehen              	VERB  	False
# dem                 	der                 	DET   	True
# Schreekhorn         	Schreekhorn         	NOUN  	False
# entschieden         	entscheiden         	ADV   	False
# nach                	nach                	ADP   	True
# (                   	(                   	PUNCT 	False
# vielleicht          	vielleicht          	ADV   	True
# sogar               	sogar               	ADV   	False
# auch                	auch                	ADV   	True
# den                 	der                 	DET   	True
# anderen             	ander               	ADJ   	True
# )                   	)                   	PUNCT 	False
# hinsichtlich        	hinsichtlich        	ADP   	False
# des                 	der                 	DET   	True
# weiten              	weit                	ADJ   	False
# Alpenpanoramas      	Alpenpanoramas      	NOUN  	False
# ;                   	;                   	PUNCT 	False
# sein                	mein                	DET   	True
# grösser             	grösser             	ADV   	False
# ,                   	,                   	PUNCT 	False
# ja                  	ja                  	ADV   	True
# einziger            	einzig              	ADJ   	False
# Vorzug              	Vorzug              	NOUN  	False
# vor                 	vor                 	ADP   	True
# allen               	alle                	PRON  	True
# ist                 	sein                	AUX   	True
# aber                	aber                	ADV   	True
# das                 	der                 	DET   	True
# Kolossale           	kolossal            	NOUN  	False
# der                 	der                 	DET   	True
# Gletscherumgebung   	Gletscherumgebung   	NOUN  	False
# im                  	im                  	ADP   	True
# Vordergrunde        	Vordergrunde        	NOUN  	False
# ;                   	;                   	PUNCT 	False
# in                  	in                  	ADP   	True
# diesem              	dies                	DET   	True
# Punkte              	Punkt               	NOUN  	False
# kommt               	kommen              	VERB  	True
# keiner              	kein                	PRON  	True
# der                 	der                 	DET   	True
# anderen             	ander               	PRON  	True
# dem                 	der                 	DET   	True
# grossen             	grossen             	ADJ   	True
# Viescherhorne       	Viescherhorne       	NOUN  	False
# gleich              	gleichen            	ADV   	True
# ,                   	,                   	PUNCT 	False
# auch                	auch                	ADV   	True
# der                 	der                 	DET   	True
# Eiger               	Eiger               	NOUN  	False
# nicht               	nicht               	PART  	True
# ,                   	,                   	PUNCT 	False
# weil                	weil                	SCONJ 	True
# sein                	mein                	DET   	True
# Nachbar             	Nachbar             	NOUN  	False
# Mönch               	Mönch               	NOUN  	False
# des                 	der                 	DET   	True
# Schönen             	Schöne              	NOUN  	False
# zu                  	zu                  	ADP   	True
# viel                	viel                	PRON  	True
# verdeckt            	verdecken           	VERB  	False
# .                   	.                   	PUNCT 	False
# Auf                 	Auf                 	ADP   	True
# Bärenegg            	Bärenegg            	NOUN  	False
# vernahmen           	vernehmen           	VERB  	False
# wir                 	ich                 	PRON  	True
# leider              	leider              	ADV   	True
# ,                   	,                   	PUNCT 	False
# dass                	dass                	SCONJ 	True
# Herr                	Herr                	NOUN  	False
# Carl                	Carl                	PROPN 	False
# Baedeker            	Baedeker            	PROPN 	False
# aus                 	aus                 	ADP   	True
# Coblenz             	Coblenz             	PROPN 	False
# unser               	sich                	DET   	True
# geharrt             	harren              	NOUN  	False
# habe                	habe                	AUX   	True
# und                 	und                 	CCONJ 	True
# kaum                	kaum                	ADV   	True
# eine                	einen               	DET   	True
# Stunde              	Stunde              	NOUN  	False
# vor                 	vor                 	ADP   	True
# unserer             	mein                	DET   	True
# Ankunft             	Ankunft             	NOUN  	False
# nach                	nach                	ADP   	True
# der                 	der                 	DET   	True
# Strahleck           	Strahleck           	PROPN 	False
# abmarschirt         	abmarschirt         	PROPN 	False
# sei                 	sein                	AUX   	True
# .                   	.                   	PUNCT 	False
# Im                  	Im                  	ADP   	True
# Thale               	Thale               	NOUN  	False
# von                 	von                 	ADP   	True
# Grindelwald         	Grindelwald         	PROPN 	False
# aber                	aber                	ADV   	True
# langten             	langen              	VERB  	False
# wir                 	ich                 	PRON  	True
# gerade              	gerade              	ADV   	True
# noch                	noch                	ADV   	True
# rechtzeitig         	rechtzeitig         	ADV   	False
# an                  	an                  	ADP   	True
# ,                   	,                   	PUNCT 	False
# um                  	um                  	SCONJ 	True
# unserem             	mein                	DET   	False
# nunmehrigen         	nunmehrigen         	ADJ   	False
# Ehrenmitgliede      	Ehrenmitgliede      	NOUN  	False
# ,                   	,                   	PUNCT 	False
# Frl.                	Frl.                	NOUN  	False
# E.                  	E.                  	PROPN 	False
# Brunner             	Brunner             	PROPN 	False
# von                 	von                 	ADP   	True
# Bern                	Bern                	PROPN 	False
# ,                   	,                   	PUNCT 	False
# die                 	der                 	DET   	True
# authentische        	authentisch         	ADJ   	False
# Versicherung        	Versicherung        	NOUN  	False
# bringen             	bringen             	VERB  	False
# zu                  	zu                  	PART  	True
# können              	können              	AUX   	True
# von                 	von                 	ADP   	True
# der                 	der                 	DET   	True
# guten               	gut                 	ADJ   	False
# Beschaffenheit      	Beschaffenheit      	NOUN  	False
# der                 	der                 	DET   	True
# Gletscher           	Gletscher           	NOUN  	False
# .                   	.                   	PUNCT 	False
# Sie                 	ich                 	PRON  	True
# zog                 	ziehen              	VERB  	False
# denn                	denn                	ADV   	True
# auch                	auch                	ADV   	True
# mit                 	mit                 	ADP   	True
# ihrem               	mein                	DET   	True
# Bruder              	Bruder              	NOUN  	False
# muthig              	muthig              	ADV   	False
# aus                 	aus                 	ADP   	True
# ,                   	,                   	PUNCT 	False
# um                  	um                  	SCONJ 	True
# hinter              	hinter              	ADP   	True
# einander            	einander            	PRON  	True
# die                 	der                 	DET   	True
# Strahleck           	Strahleck           	NOUN  	False
# ,                   	,                   	PUNCT 	False
# den                 	der                 	DET   	True
# Galenstock          	Galenstock          	NOUN  	False
# und                 	und                 	CCONJ 	True
# das                 	der                 	DET   	True
# Finsteraarhorn      	Finsteraarhorn      	NOUN  	False
# zu                  	zu                  	PART  	True
# besteigen           	besteigen           	VERB  	False
# .                   	.                   	PUNCT 	False
# Wie                 	Wie                 	ADV   	True
# gerne               	gerne               	ADV   	False
# möchte              	mögen               	AUX   	True
# ich                 	ich                 	PRON  	True
# zu                  	zu                  	ADP   	True
# mir                 	sich                	PRON  	True
# sagen               	sagen               	VERB  	False
# :                   	:                   	PUNCT 	False
# „                   	„                   	PUNCT 	False
# Mach's              	Mach's              	VERB  	False
# na                  	na                  	INTJ  	True
# !                   	!                   	PUNCT 	False
# u                   	u                   	PROPN 	False
#                     	                    	SPACE 	False
# PS                  	PS                  	PROPN 	False
# .                   	.                   	PUNCT 	False
# Das                 	der                 	DET   	True
# Thal                	Thal                	NOUN  	False
# hatte               	haben               	AUX   	True
# sich                	sich                	PRON  	True
# am                  	am                  	ADP   	True
# Tage                	Tag                 	NOUN  	True
# unserer             	mein                	DET   	True
# Besteigung          	Besteigung          	NOUN  	False
# vollständiger       	vollständig         	ADJ   	False
# Windstille          	Windstille          	NOUN  	False
# zu                  	zu                  	PART  	True
# erfreuen            	erfreuen            	VERB  	False
# gehabt              	haben               	AUX   	True
# ;                   	;                   	PUNCT 	False
# doch                	doch                	CCONJ 	True
# war                 	sein                	AUX   	True
# der                 	der                 	DET   	True
# Himmel              	Himmel              	NOUN  	False
# bedeckt             	bedecken            	ADV   	False
# gewesen             	sein                	AUX   	True
# ,                   	,                   	PUNCT 	False
# so                  	so                  	ADV   	True
# dass                	dass                	SCONJ 	True
# das                 	der                 	DET   	True
# Viescherhorn        	Viescherhorn        	NOUN  	False
# nur                 	nur                 	ADV   	True
# ,                   	,                   	PUNCT 	False
# Abends              	Abends              	ADV   	False
# auf                 	auf                 	ADP   	True
# einen               	ein                 	DET   	True
# Augenblick          	Augenblick          	NOUN  	False
# sichtbar            	sichtbar            	ADV   	False
# war                 	sein                	AUX   	True
# .                   	.                   	PUNCT 	False

# %% [markdown]
# Let's look and see what nouns were in our document - we can simply iterate through the tokens, keeping those identified as nouns.
#
# Do these all make sense? Where do you see issues?

# %%
nouns = (token for token in doc if token.pos_ == 'NOUN')

for noun in nouns:
    print(f"{noun}")
# Out:
# Grindelwald-Viescherhorn
# Pfarrer
# August
# Jahres
# Anderen
# Freude
# September
# Bettagszeit
# Gemeinde
# Herbsttage
# thunS'ist
# Sonntag
# Bettag
# Gletscherbänkli
# Seufzer
# Gletscher
# Viescherkranze
# Mettenberge
# Wetterhorn
# Eiger
# Bekannten
# Duft
# Seçtemberabends
# Bilde
# schritten
# Reisenden
# Weg
# Sorge
# Pläne
# Pastor
# Tourist
# Matte
# Herr
# Dr.
# Bekanntschaft
# Jahre
# Vergnügen
# Bann
# Begrüssung
# Wetterhorn
# Jahre
# Zuneigung
# Resignation
# Viescherhorn
# mitLeider
# Herr
# Tone
# Nein
# Wort
# Çirindelwald
# Tausend
# Herr
# Doctor
# Decken
# Proviant
# Wirthshause
# Frau
# Schreckhorn
# Grindelwaldner
# Noth
# Führer
# Führer
# Ranges
# Complimente
# Eifersucht
# Reine
# Beiden
# Viescherhorn
# Träger
# Blut
# Träger
# sehon
# Dienste
# Hütte
# Mönch
# Quartier
# Dienstags
# September
# Viescherhorn
# Uhr
# Morgens
# Nöthigen
# Stunden
# Bärenegg
# Eismeere
# Musse
# Imbiss
# Träger
# Triften
# Alpenpanoramas
# Vorzug
# Kolossale
# Gletscherumgebung
# Vordergrunde
# Punkte
# Viescherhorne
# Eiger
# Nachbar
# Mönch
# Schönen
# Bärenegg
# Herr
# geharrt
# Stunde
# Ankunft
# Thale
# Ehrenmitgliede
# Frl.
# Versicherung
# Beschaffenheit
# Gletscher
# Bruder
# Strahleck
# Galenstock
# Finsteraarhorn
# Thal
# Tage
# Besteigung
# Windstille
# Himmel
# Viescherhorn
# Augenblick

# %% [markdown]
# We can also use Spacy to perform Named Entity Recognition (NER). Spacy identifies NERs and labels them, for example as LOC (location), ORG (organisation) or PER (person). It's important to understand that NER (like other elements of NLP) is not perfect.

# %%
#Pretty output of the NER results
spacy.displacy.render(doc, style="ent")

# Iterate through the named entities found, and their types. 
print(f"{'Token':<20}\t{'Type':<3}\n")
for ent in doc.ents:
    print(f"{ent.text:<20}\t{ent.label_:<3}")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grosse Grindelwald-Viescherhorn.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  lA iß -  Von Pfarrer
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gerwer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grindelwald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Der wässerige August dieses Jahres hatte auch mir, wie manchem Anderen, die Freude verdorben. Ich durfte nicht hoffen, im September viel nachholen zu können, weil die
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bettagszeit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  mich an meine Gemeinde fesselte. Ich schaute, aufrichtig gestanden, nur halb vergnügt in die schönen Herbsttage hinein. Aber was war zu thunS'ist es Lyde, schick di dry. &quot; So sass ich am Sonntag Abend vor Bettag auf unserem „ Gletscherbänkli &quot; und schickte friedliche Seufzer hinüber nach dem unteren Gletscher und dem schönen Viescherkranze, nach dem Mettenberge, dem Wetterhorn, dem Eiger, den alten guten Bekannten. Der ganze Duft eines milden herrlichen
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seçtemberabends
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  lag auf dem unvergleichlichen Bilde. Fröhlich und frei schritten die ankommenden Reisenden ihren Weg dahin, ohne Sorge ihre Pläne ausführend, und der junge Pastor seufzte: „
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ach !
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dass ich gefangen bin !&quot; Auf einmal springt so ein Tourist über die Matte herauf mich zu:  Herr Dr. Weber aus
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , dessen Bekanntschaft ich vor einem Jahre zu machen das Vergnügen gehabt. Noch ahnte ich nicht, dass er den Bann von mir zu lösen gekommen sei. Nach freundlicher gegenseitiger Begrüssung fragte er um
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , was er doch machen könnte. Da er zum Wetterhorn, das ihn vor einem Jahre gar schmählich und schmutzig aufgenommen hatte, keine Zuneigung mehr verspürte, so
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rieth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ich in grösser Resignation zum grossen Viescherhorn. „ Gut, abgemacht ! Und Sie kommen doch
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mitLeider
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  nein ! Ich kann fast nicht und
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thät 's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  doch so gern. &quot; Herr Weber mochte aus meinem Tone herausgefühlt haben, wie schwer mir das Nein wurde, er fand darum bald das rechte Wort. „ Das thut mir leid, sagte er, allein mag ich 's auch nicht machen; dann bin ich vergeblich nach
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Çirindelwald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  gekommen.Ja, der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tausend !
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  So ist 's doch nicht gemeint, Herr Doctor; das möchte ich nicht, ich geh'mit.4* Fertig war 's; gerüstet wurden Decken und Proviant im Pfarr- und Wirthshause. Meine gute Frau erschrack nicht sehr; seit
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schreckhorn undEiger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  überwunden sind, schrecken die anderen Grindelwaldner nicht mehr. Unsere &quot; liebe Noth hatten wir, tüchtige Führer zu finden; fast Alle waren fort oder engagirt.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Rubi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , den wir als Führer ersten Ranges empfehlen können, wurde glücklich noch erwischt und war gern bereit; etwas
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Complimente
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  machte
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Inäbnit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  aus purer Eifersucht, weil vor ihm
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Michel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  war angefragt worden. Doch kam 's auch mit ihm in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     's Reine.
#     <span style="font-size: 0.
# Token               	Type
#
# Grosse Grindelwald-Viescherhorn.	MISC
# Gerwer              	PER
# Grindelwald         	LOC
# Bettagszeit         	MISC
# Seçtemberabends     	LOC
# Ach !               	ORG
# London              	LOC
# Rath                	LOC
# rieth               	PER
# mitLeider           	MISC
# thät 's             	ORG
# Çirindelwald        	LOC
# Tausend !           	ORG
# Schreckhorn undEiger	PER
# Peter Rubi          	PER
# Complimente         	PER
# Peter Inäbnit       	PER
# Peter Michel        	PER
# 's Reine.           	MISC
# Viescherhorn        	LOC
# Peter Baumann       	PER
# Viescherhorn        	LOC
# Bärenegg            	LOC
# Meyer               	PER
# Wirthsleute         	MISC
# Eismeer             	LOC
# Kalli               	PER
# grünen Trift        	LOC
# Alpenrosen          	LOC
# Kallitritt          	MISC
# Vieschergletscher   	MISC
# Mönchsjoches        	LOC
# Vieschergrates      	LOC
# 's Eismeer.         	LOC
# Joches              	MISC
# Fellenberg          	PER
# Lauteraarjoch, der Strahleck	LOC
# Mönchjoch           	LOC
# lohnendste, grossartigste	MISC
# Gletscherumgebung   	MISC
# Passhöhe.           	LOC
# Grünhörnern schwingt	ORG
# Eismeer.            	LOC
# Septemberbise       	MISC
# Schrunde.           	LOC
# Gletscherchaos      	PER
# Bergli              	PER
# gutmüthiger         	LOC
# Ulr.                	PER
# Zeit                	MISC
# JungfrauEben nit, Herr Doctor; der Trugberg	MISC
# Trugberges          	LOC
# Ewig-Schneefeld     	LOC
# Trugberg            	LOC
# Jungfrau            	PER
# Grünhörner          	LOC
# Ewig-Schneefeld     	LOC
# Mönchjoch           	PER
# Ewig-Schneefeldes   	LOC
# gtttgewählter       	PER
# Thür.               	MISC
# Gott                	MISC
# das Jahr des Heils  	MISC
# Rom                 	LOC
# Rüstig              	MISC
# Gletscherseilen     	MISC
# Besorgniss          	PER
# Mönchszelle         	LOC
# ..Alflvîti          	PER
# -f-                 	MISC
# Herrn Weber         	PER
# fidel               	PER
# Rubi                	PER
# Hutte               	LOC
# Mondes              	LOC
# Nebelflor           	MISC
# Gux                 	LOC
# hartoder            	LOC
# Gott                	PER
# Ritsch, Ratsch      	MISC
# Mond                	LOC
# Bresche             	MISC
# Flügelmänner, Rubi  	MISC
# Meyer               	MISC
# Ritsch              	PER
# Ratsch              	MISC
# Boreas.             	PER
# Weingeistmaschine   	ORG
# Ewig-Schneefeld     	LOC
# abmarschirt.        	PER
# Jungfraujoch herein 	LOC
# Grossen Viescherhorn	LOC
# Schneefeld          	LOC
# Hütten              	LOC
# Grindelwald         	LOC
# Thale               	LOC
# Mönchjoch           	PER
# respec-tabel        	MISC
# Mönchjoch           	LOC
# Schnee-und          	PER
# Felsrippe           	LOC
# 's Erste            	ORG
# Bergschrund         	LOC
# Lawinenschnee       	LOC
# 8chiefriger         	MISC
# Inäbnit             	PER
# Spisspeter          	PER
# Grünhörner          	LOC
# Gebirgsreichthum    	LOC
# Wallis              	LOC
# möcht'ich           	LOC
# lassen.             	MISC
# Zeit                	MISC
# Nebelgeister        	MISC
# Rüstig              	MISC
# Steigen             	LOC
# Ehehälfte           	MISC
# Lüfte               	LOC
# Viescher-           	LOC
# Almer               	PER
# Jungfrau            	LOC
# Almer               	PER
# George              	PER
# Chr. Almer's,       	PER
# Herrn Tucket's      	PER
# Tannli              	MISC
# Mettenbergs         	LOC
# Coloss              	LOC
# Eiger               	LOC
# Mettenberg          	LOC
# Grüne               	ORG
# wTir                	MISC
# Gebirgsgruppen      	LOC
# 's Eismeer          	LOC
# Walliser            	LOC
# Kleinen Viescherhorn	LOC
# Ochs                	LOC
# gewaltigen Gletscherkamm	LOC
# derimFinsteraarhorn 	ORG
# Mettenberg.         	LOC
# Grünhörnern         	MISC
# Grindelwald         	LOC
# Viescherhorn        	MISC
# Walliser Grünhörner.	LOC
# Vieschergletscher   	MISC
# Grosse Viescherhorn 	LOC
# Orakelsprüche       	LOC
# Orakelsprüche       	LOC
# Schauer             	LOC
# Umgiebt             	LOC
# Bücherstaub         	PER
# Gebein.             	PER
# Flieh               	PER
# Erkennest           	PER
# Und wenn Natur dich 	MISC
# Gotteserkenntniss   	LOC
# heimathlichen       	MISC
# Thal                	LOC
# Eismeer             	LOC
# Gesammtbild         	ORG
# Nebel               	LOC
# Bärenegg            	LOC
# Mettenberges        	LOC
# Nebel               	LOC
# Felsenkopf          	LOC
# Steinmannli         	LOC
# Stack               	PER
# Engländer           	LOC
# Unerstiegenheit     	MISC
# Grindelwaldner.     	MISC
# Walliser            	LOC
# Meister, E. v. Fellenberg	MISC
# Grates              	LOC
# Joches              	MISC
# Finsteraarhorn      	LOC
# WaHiser             	LOC
# Zeitenschoosse. "   	MISC
# Vieschergrates      	LOC
# Grünhörner          	LOC
# N.                  	LOC
# rGrosse             	MISC
# Grünhorn            	LOC
# E. v. Fellentterg   	PER
# Vize-Fellenberg begrüssen.	MISC
# Dde                 	PER
# Viescherhorn.       	LOC
# Trugberge           	LOC
# Ewig-Schneefeldes   	ORG
# Reservoirs          	LOC
# Lötschenlücke       	LOC
# Breithorn           	LOC
# der'Jungfrau        	LOC
# Viescherhorn        	LOC
# Grünhörnern, den    	LOC
# Trugberg            	LOC
# Ewig-Schneefeld     	LOC
# Trugberg            	LOC
# Jungfrau            	LOC
# Hauptkerl           	LOC
# Balmhorn            	LOC
# Ein reicher Himmel Stern	MISC
# gewaltigen, kalten Ernstes	MISC
# Grüne               	ORG
# Gletscherwildniss   	PER
# Walliser Alpen      	LOC
# Montblanc           	LOC
# Aletschhorn         	LOC
# Wal- User           	ORG
# Finsteraarhorn      	LOC
# Rubi                	PER
# Bergschrund         	LOC
# Rosenlauigletscher. 	LOC
# Rubi                	PER
# Ewig-Schneefeld.    	MISC
# Rath                	PER
# Mönchsherberge      	LOC
# Hotel du Moine      	LOC
# Eismeer             	LOC
# Bergli              	PER
# Eigerhöhle.         	MISC
# Qui vivra           	MISC
# Spisspeter.         	PER
# Mönchjoch           	PER
# Bergli              	PER
# Eigerhöhle          	LOC
# Gneisswand          	LOC
# Bergli              	LOC
# Charybdis           	LOC
# Club.i g            	LOC
# Windlieht           	LOC
# gemuthmasst         	ORG
# Mondes              	LOC
# Führern             	LOC
# Kirsch              	LOC
# Herr Weber          	PER
# Aosta               	LOC
# Orangen             	LOC
# Viescherhorn        	LOC
# frugalem Mahle      	PER
# Mondes Sichel       	MISC
# silberne Säbel      	MISC
# Eigerhöhle          	LOC
# Die Nacht           	MISC
# Niemandes Freund**  	MISC
# Gefrühstückt        	PER
# Durst               	MISC
# Quellwassers.       	MISC
# Açutzov             	PER
# Eismeer             	LOC
# sehöneiVKranz       	MISC
# Roth                	PER
# Alpen               	LOC
# Tag                 	MISC
# Gegrüsst            	MISC
# Erlangten, wie Geist	MISC
# Viescherhorn        	LOC
# Viescherhorn        	LOC
# Schreekhorn         	LOC
# Bärenegg            	LOC
# Carl Baedeker       	PER
# Coblenz             	LOC
# Strahleck abmarschirt	LOC
# Grindelwald         	LOC
# Ehrenmitgliede, Frl. E. Brunner von Bern	MISC
# Galenstock          	LOC
# Finsteraarhorn      	LOC
# Thal                	LOC
# Viescherhorn        	MISC

# %%
from collections import Counter
terms = [token.text for token in doc]
ranked_terms = Counter(terms).most_common()

print(f"{'Term':<20}\t{'Count':<3}\n")
for term, count in ranked_terms:
    print(f"{term:<20}\t{count:<3}")
# Out:
# Term                	Count
#
# ,                   	518
# .                   	210
# und                 	199
# der                 	176
# die                 	150
# das                 	112
# ;                   	101
# wir                 	96
# uns                 	94
# zu                  	80
# in                  	77
# den                 	64
# sich                	61
# dem                 	60
# von                 	60
# nicht               	56
# ein                 	54
# des                 	50
# war                 	48
# „                   	44
# "                   	43
# mit                 	39
# auch                	36
# so                  	35
# ist                 	33
# 's                  	32
# auf                 	31
# aber                	29
# es                  	26
# vor                 	25
# als                 	25
# im                  	24
# nach                	24
# wurde               	24
# eine                	24
# an                  	23
# um                  	22
# über                	21
# noch                	21
# hatten              	20
#                     	19
# nur                 	19
# ich                 	19
# !                   	19
# dass                	19
# :                   	18
# er                  	18
# zum                 	18
# durch               	18
# aus                 	17
# doch                	17
# dann                	17
# einer               	17
# —                   	17
# am                  	16
# dieser              	16
# wieder              	16
# wie                 	15
# Viescherhorn        	15
# Uhr                 	15
# einem               	14
# da                  	14
# ganz                	14
# sie                 	14
# wird                	14
# M.                  	13
# Theil               	13
# bis                 	13
# Spitze              	13
# Der                 	12
# hatte               	12
# mehr                	12
# bald                	12
# waren               	12
# einen               	12
# dieses              	11
# sehr                	11
# ihm                 	11
# bei                 	11
# immer               	11
# für                 	11
# grossen             	10
# Das                 	10
# hier                	10
# sein                	10
# unter               	10
# vom                 	10
# ?                   	10
# Schnee              	10
# Grat                	10
# mir                 	9
# ihre                	9
# ihn                 	9
# Führer              	9
# oder                	9
# zur                 	9
# Mönchjoch           	9
# sichtbar            	9
# unser               	9
# wäre                	9
# fast                	8
# etwas               	8
# unserer             	8
# weg                 	8
# Fuss                	8
# nun                 	8
# seine               	8
# wenn                	8
# Grosse              	7
# schönen             	7
# Gletscher           	7
# Herr                	7
# haben               	7
# Mönch               	7
# selbst              	7
# Fels                	7
# Blick               	7
# Eismeer             	7
# ihr                 	7
# zieht               	7
# unsere              	7
# Namen               	7
# rechts              	7
# hin                 	7
# werden              	7
# denn                	7
# steilen             	7
# gerade              	7
# Nebel               	7
# viel                	6
# weil                	6
# was                 	6
# So                  	6
# Weg                 	6
# ohne                	6
# Nach                	6
# Und                 	6
# sind                	6
# anderen             	6
# grosse              	6
# dort                	6
# alle                	6
# Wir                 	6
# diese               	6
# Ewig-Schneefeld     	6
# Kette               	6
# Grünhörner          	6
# Seite               	6
# also                	6
# Felsen              	6
# Dach                	6
# zwei                	6
# wohl                	6
# ward                	6
# Wie                 	6
# Gipfel              	6
# zwischen            	6
# Grindelwald         	5
# können              	5
# Aber                	5
# eines               	5
# Auf                 	5
# einmal              	5
# dessen              	5
# machen              	5
# sei                 	5
# *                   	5
# Decken              	5
# Rubi                	5
# Inäbnit             	5
# Doch                	5
# hinter              	5
# erst                	5
# eben                	5
# wo                  	5
# weniger             	5
# steil               	5
# Um                  	5
# Schrunde            	5
# letzten             	5
# Bergli              	5
# man                 	5
# fanden              	5
# links               	5
# lange               	5
# Tag                 	5
# diesen              	5
# etwa                	5
# Die                 	5
# kaum                	5
# Dann                	5
# Kälte               	5
# Norden              	5
# schon               	5
# Ein                 	5
# hinaus              	5
# -                   	4
# Von                 	4
# Wetterhorn          	4
# Eiger               	4
# guten               	4
# ganze               	4
# frei                	4
# ihren               	4
# dahin               	4
# Weber               	4
# gar                 	4
# grösser             	4
# Doctor              	4
# wurden              	4
# gute                	4
# fort                	4
# Peter               	4
# ersten              	4
# Bärenegg            	4
# genommen            	4
# würde               	4
# vier                	4
# Kalli               	4
# Höhe                	4
# hinunter            	4
# Wetter              	4
# hindurch            	4
# Strahleck           	4
# unstreitig          	4
# besonders           	4
# weiteren            	4
# Blicke              	4
# erhebt              	4
# aufs                	4
# ging                	4
# Seil                	4
# deutlich            	4
# Spuren              	4
# kleinen             	4
# Flasche             	4
# Stunde              	4
# betraten            	4
# obersten            	4
# Zeit                	4
# erreichten          	4
# Trugberg            	4
# diesem              	4
# gleich              	4
# ebenfalls           	4
# Jungfrau            	4
# freilich            	4
# In                  	4
# ab                  	4
# Gemüth              	4
# Alpen               	4
# Ersteigung          	4
# bildet              	4
# seiner              	4
# sehen               	4
# Hand                	4
# gewesen             	4
# Herrn               	4
# gut                 	4
# recht               	4
# ruhig               	4
# hat                 	4
# endlich             	4
# jetzt               	4
# Grossen             	4
# ganzen              	4
# zerrissenen         	4
# diess               	4
# voran               	4
# damit               	4
# unseren             	4
# Vieschergrat        	4
# Walliser            	4
# gewaltigen          	4
# 1                   	4
# Geist               	4
# kalten              	4
# Grünhornkette       	4
# Eigerhöhle          	4
# Es                  	4
# Ich                 	3
# mich                	3
# unserem             	3
# hinüber             	3
# Jahre               	3
# könnte              	3
# Da                  	3
# keine               	3
# Sie                 	3
# gern                	3
# mag                 	3
# möchte              	3
# Grindelwaldner      	3
# Unsere              	3
# engagirt            	3
# glücklich           	3
# machte              	3
# worden              	3
# kam                 	3
# Träger              	3
# nächsten            	3
# dabei               	3
# einiger             	3
# abmarschirt         	3
# untere              	3
# einige              	3
# Grindelwalder       	3
# Vieschergletscher   	3
# Vieschergrates      	3
# daher               	3
# Joches              	3
# Freund              	3
# weiss               	3
# drei                	3
# hinsichtlich        	3
# Aussicht            	3
# Passhöhe            	3
# Grünhörnern         	3
# wenig               	3
# befestigt           	3
# darin               	3
# hervor              	3
# her                 	3
# Nacht               	3
# Nordwind            	3
# leider              	3
# seinem              	3
# Schneefeld          	3
# kühn                	3
# wilder              	3
# Anblick             	3
# erreichen           	3
# müssen              	3
# überschreiten       	3
# Thür                	3
# Haus                	3
# Laden               	3
# Gott                	3
# Jahr                	3
# quer                	3
# nahe                	3
# Sonne               	3
# o                   	3
# 4                   	3
# °                   	3
# Alles               	3
# freundlich          	3
# Füsse               	3
# neben               	3
# genug               	3
# geworden            	3
# herein              	3
# sahen               	3
# Mondes              	3
# lang                	3
# Man                 	3
# Nicht               	3
# pfiff               	3
# genossen            	3
# beiden              	3
# dar                 	3
# scharf              	3
# ansteigenden        	3
# obgleich            	3
# Schwierigkeiten     	3
# Gefahr              	3
# Eine                	3
# zog                 	3
# gegen               	3
# Bogen               	3
# direkt              	3
# weiter              	3
# Recht               	3
# rasch               	3
# zwar                	3
# vielen              	3
# möglich             	3
# Stück               	3
# 10                  	3
# Firnhang            	3
# Himmel              	3
# Auge                	3
# Umgebung            	3
# sagen               	3
# liess               	3
# lassen              	3
# mussten             	3
# alles               	3
# höchste             	3
# Gruppe              	3
# Steinmannli         	3
# kleines             	3
# Fläschchen          	3
# musste              	3
# Sommer              	3
# Bild                	3
# Viescherfirn        	3
# Alpenwelt           	3
# ihrem               	3
# du                  	3
# Partien             	3
# Augenblick          	3
# Besteigung          	3
# )                   	3
# kommt               	3
# E.                  	3
# Finsteraarhorn      	3
# 5                   	3
# Durst               	3
# Birne               	3
# Pfarrer             	2
# August              	2
# Jahres              	2
# Anderen             	2
# Freude              	2
# September           	2
# hinein              	2
# Seufzer             	2
# alten               	2
# milden              	2
# herrlichen          	2
# lag                 	2
# Bilde               	2
# schritten           	2
# Pläne               	2
# Ach                 	2
# bin                 	2
# gehabt              	2
# Noch                	2
# gekommen            	2
# freundlicher        	2
# Rath                	2
# mochte              	2
# darum               	2
# thut                	2
# Ja                  	2
# Proviant            	2
# Schreckhorn         	2
# tüchtige            	2
# Alle                	2
# empfehlen           	2
# Keiner              	2
# Als                 	2
# Baumann             	2
# Dienste             	2
# Hütte               	2
# nehmen              	2
# anzugreifen         	2
# eilen               	2
# Wohl                	2
# allem               	2
# Stunden             	2
# Eismeere            	2
# Mit                 	2
# Meyer               	2
# Folge               	2
# Eis                 	2
# gewandt             	2
# richtig             	2
# stark               	2
# überschreitend      	2
# Lawinenschnee       	2
# grünen              	2
# wanden              	2
# sonst               	2
# Kallitritt          	2
# Felsband            	2
# oberen              	2
# Ansteigen           	2
# 12                  	2
# Halt                	2
# betreten            	2
# leicht              	2
# z.B.                	2
# oft                 	2
# Fellenberg          	2
# Gletscherumgebung   	2
# Aufsteigen          	2
# schöner             	2
# Wand                	2
# Rechten             	2
# Kalkwand            	2
# Eigers              	2
# tiefer              	2
# vorwärts            	2
# weite               	2
# Leben               	2
# Mitten              	2
# Kamm                	2
# Kletterei           	2
# An                  	2
# Steine              	2
# Engländer           	2
# Führung             	2
# erhebend            	2
# heftiger            	2
# näher               	2
# 6                   	2
# stand               	2
# Ehre                	2
# weithin             	2
# Neigung             	2
# Rechts              	2
# massiv              	2
# geht                	2
# Reihe               	2
# wirklich            	2
# Charakter           	2
# Majestät            	2
# lässt               	2
# Punkte              	2
# Gletscherwelt       	2
# gelüstete           	2
# Bise                	2
# drüben              	2
# wenden              	2
# rüstig              	2
# Ewig-Schneefeldes   	2
# Gasthof             	2
# hart                	2
# Schweizer           	2
# genau               	2
# Herberge            	2
# Mönchs              	2
# Station             	2
# Viescherhorns       	2
# Drei                	2
# kein                	2
# Dachlatten          	2
# Arbeit              	2
# Führern             	2
# Vollendung          	2
# Rüstig              	2
# Werk                	2
# gelegt              	2
# darüber             	2
# konnten             	2
# legten              	2
# einander            	2
# bedeckt             	2
# Entfernung          	2
# konnte              	2
# thun                	2
# Wärme               	2
# keinen              	2
# Nachdem             	2
# brennenden          	2
# Weingeistmaschine   	2
# Bouillon            	2
# zeigte              	2
# dennoch             	2
# R.                  	2
# heftige             	2
# übrigens            	2
# nämlich             	2
# Hutte               	2
# resp                	2
# helfen              	2
# gewahr              	2
# heulte              	2
# bedenklich          	2
# Fugen               	2
# Sterne              	2
# hie                 	2
# jagte               	2
# wild                	2
# ihnen               	2
# bringen             	2
# wahrscheinlich      	2
# Heer                	2
# Schlaf              	2
# Ritsch              	2
# Ratsch              	2
# liegen              	2
# Bresche             	2
# angezogen           	2
# wann                	2
# abermals            	2
# Bald                	2
# Dämmerung           	2
# Sturm               	2
# entschlossen        	2
# abzuwarten          	2
# Strahlen            	2
# nöthigte            	2
# halber              	2
# Abends              	2
# nichts              	2
# während             	2
# Den                 	2
# Glieder             	2
# Punkt               	2
# Ungestüm            	2
# Linie               	2
# stellte             	2
# Thale               	2
# Nordseite           	2
# gesehen             	2
# Standpunkt          	2
# Hörn                	2
# breit               	2
# zunächst            	2
# Felsrippe           	2
# folgend             	2
# müsste              	2
# erreicht            	2
# trauten             	2
# vielleicht          	2
# dritte              	2
# solche              	2
# Rippe               	2
# zweiten             	2
# Endlich             	2
# bot                 	2
# liegenden           	2
# unten               	2
# schwierig           	2
# rückten             	2
# Auch                	2
# standen             	2
# Bergschrund         	2
# Couloir             	2
# Gneiss              	2
# Beschaffenheit      	2
# Ding                	2
# bedeutend           	2
# betragen            	2
# Mittagssonne        	2
# Spisspeter          	2
# Vorsicht            	2
# lachte              	2
# Umgebungen          	2
# Nähe                	2
# Nord                	2
# j                   	2
# finstere            	2
# Ziel                	2
# wollen              	2
# ja                  	2
# Rückzug             	2
# wollte              	2
# wollten             	2
# keiner              	2
# leichter            	2
# liegende            	2
# oberste             	2
# 4048                	2
# ü.                  	2
# Tannli              	2
# Almer               	2
# festgebunden        	2
# verschlossen        	2
# Tucket's            	2
# 1864                	2
# erstiegen           	2
# Ersteiger           	2
# Herren              	2
# daran               	2
# obere               	2
# Mettenberg          	2
# Grüne               	2
# Höhen               	2
# Contrast            	2
# versuchen           	2
# Grates              	2
# nahezu              	2
# Süden               	2
# Kleinen             	2
# südöstlich          	2
# seinen              	2
# Lauteraarhorn       	2
# andern              	2
# westwärts           	2
# dehnt               	2
# hintere             	2
# Wal-                	2
# User                	2
# Orakelsprüche       	2
# ihrer               	2
# Erkenntniss         	2
# dadurch             	2
# spricht             	2
# deinem              	2
# hemmt               	2
# Natur               	2
# Menschen            	2
# Land                	2
# dir                 	2
# Lauf                	2
# Ganzen              	2
# einzelnen           	2
# zuerst              	2
# heimathlichen       	2
# Thal                	2
# gross               	2
# grossartigsten      	2
# hellen              	2
# Bruder              	2
# Nur                 	2
# klein               	2
# einziger            	2
# v.                  	2
# kurz                	2
# verdeckt            	2
# beim                	2
# Nun                 	2
# malerischen         	2
# fröhlichem          	2
# Hurrah              	2
# Tiefe               	2
# Aletschhorn         	2
# u.                  	2
# Stern               	2
# gerne               	2
# darauf              	2
# Im                  	2
# Ausblick            	2
# weich               	2
# (                   	2
# Schritte            	2
# zwanzig             	2
# tiberlassen         	2
# Wasser              	2
# besteigen           	2
# erquickenden        	2
# langsam             	2
# freut               	2
# steht               	2
# Grindelwald-Viescherhorn	1
# lA                  	1
# iß                  	1
# Gerwer              	1
# wässerige           	1
# manchem             	1
# verdorben           	1
# durfte              	1
# hoffen              	1
# nachholen           	1
# Bettagszeit         	1
# meine               	1
# Gemeinde            	1
# fesselte            	1
# schaute             	1
# aufrichtig          	1
# gestanden           	1
# halb                	1
# vergnügt            	1
# Herbsttage          	1
# thunS'ist           	1
# Lyde                	1
# schick              	1
# di                  	1
# dry                 	1
# sass                	1
# Sonntag             	1
# Abend               	1
# Bettag              	1
# Gletscherbänkli     	1
# schickte            	1
# friedliche          	1
# unteren             	1
# Viescherkranze      	1
# Mettenberge         	1
# Bekannten           	1
# Duft                	1
# Seçtemberabends     	1
# unvergleichlichen   	1
# Fröhlich            	1
# ankommenden         	1
# Reisenden           	1
# Sorge               	1
# ausführend          	1
# junge               	1
# Pastor              	1
# seufzte             	1
# gefangen            	1
# springt             	1
# Tourist             	1
# Matte               	1
# herauf              	1
# Dr.                 	1
# London              	1
# Bekanntschaft       	1
# Vergnügen           	1
# ahnte               	1
# Bann                	1
# lösen               	1
# gegenseitiger       	1
# Begrüssung          	1
# fragte              	1
# schmählich          	1
# schmutzig           	1
# Ist                 	1
# Geleit              	1
# Erkennest           	1
# dich                	1
# unterweist          	1
# Seelenkraft         	1
# Gotteserkenntniss   	1
# nämlichen           	1
# findet              	1
# Religion            	1
# Liebe               	1
# göttlichen          	1
# Stifter             	1
# orientirt           	1
# genauere            	1
# Musterung           	1
# Natürlich           	1
# richtet             	1
# gesagt              	1
# verhüllen           	1
# Regionen            	1
# Cultur              	1
# wildes              	1
# Gewoge              	1
# stürmt              	1
# heran               	1
# vergönnt            	1
# Augenblicke         	1
# Abgrund             	1
# ermessen            	1
# trennt              	1
# Genaueres           	1
# unterscheiden       	1
# Daran               	1
# liegt               	1
# hinlänglich         	1
# bekannt             	1
# Gesammtbild         	1
# grossartig          	1
# fliehenden          	1
# erhöhen             	1
# Schaurige           	1
# Anblicks            	1
# 7000                	1
# darf                	1
# senkrecht           	1
# Fussen              	1
# Gletscherkessels    	1
# erlabt              	1
# trunkene            	1
# Kessel              	1
# einfassenden        	1
# Zunächst            	1
# Viescherwand        	1
# stehen              	1
# Zweifel             	1
# Schönheiten         	1
# steckenden          	1
# feine               	1
# Mettenberges        	1
# gehüllt             	1
# Nössihornber        	1
# Nebelrücken         	1
# strahlen            	1
# Sonnenlicht         	1
# wunderschöner       	1
# Gletscherspitzen    	1
# Wetter-             	1
# Mittel-             	1
# Rosenhorns          	1
# Felsenkopf          	1
# Berglistocks        	1
# thürmt              	1
# Schreckhorns        	1
# ebenbürtiger        	1
# Fernrohr            	1
# Stack               	1
# voriges             	1
# felsigen            	1
# Flanken             	1
# ungleich            	1
# schneefreier        	1
# Augustregen         	1
# Absichten           	1
# rein                	1
# weggewaschen        	1
# Riesen              	1
# immerhin            	1
# 10,000              	1
# hohe                	1
# GrünhornPfaffenstöckli	1
# bemerklich          	1
# Juni                	1
# d.                  	1
# J.                  	1
# Unerstiegenheit     	1
# abgerungen          	1
# Gerade              	1
# folgen              	1
# geringer            	1
# blendend            	1
# weissen             	1
# kecke               	1
# ob                  	1
# Differenz           	1
# 170                 	1
# rühren              	1
# Firnfeld            	1
# verhältnissmässig   	1
# Dreieck             	1
# heraushebt          	1
# Horn                	1
# Verhältniss         	1
# hohen               	1
# Basis               	1
# sagt                	1
# bisheriger          	1
# Meister             	1
# geringe             	1
# Vertiefung          	1
# welchen             	1
# durchaus            	1
# verdiene            	1
# Diesem              	1
# entlang             	1
# mustern             	1
# Spitzen             	1
# Einsenkungen        	1
# überzeugen          	1
# unzugänglich        	1
# Gemisch             	1
# abschüssigen        	1
# Gletscherhängen     	1
# beständiger         	1
# 11,000              	1
# Genug               	1
# sieht               	1
# Besuch              	1
# ladet               	1
# würdige             	1
# Culminations-       	1
# Schlusspunkt        	1
# darstellt           	1
# weist               	1
# gewöhnlich          	1
# gewählt             	1
# gegenüberliegenden  	1
# WaHiser             	1
# und-Firn            	1
# grösseren           	1
# Viescher-hora       	1
# Kopf                	1
# bischen             	1
# drücken             	1
# klar                	1
# Neue                	1
# regten              	1
# Wildheit            	1
# prachtvollen        	1
# Reviers             	1
# ruhen               	1
# Zeitenschoosse      	1
# Einzelnen           	1
# bedeutendste        	1
# Kreissegment        	1
# einerseits          	1
# auslaufenden        	1
# anderseits          	1
# Radien              	1
# eingeschlossen      	1
# N.                  	1
# S.                  	1
# laufend             	1
# stellt              	1
# Sierra              	1
# unerwarteter        	1
# Stattlichkeit       	1
# Oberhaupt           	1
# beugt               	1
# dagegen             	1
# monoton             	1
# Aehnlichkeit        	1
# Ganze               	1
# Effekt              	1
# Am                  	1
# meisten             	1
# rGrosse             	1
# Grünhorn            	1
# Steinmänniis        	1
# willen              	1
# Fellentterg         	1
# erachtet            	1
# Vize-Fellenberg     	1
# begrüssen           	1
# stösst              	1
# überall             	1
# unruhigen           	1
# Geistes             	1
# Dde                 	1
# schätzte            	1
# ungefähr            	1
# denen               	1
# Längs               	1
# eingedämmt          	1
# Trugberge           	1
# merkwürdige         	1
# Firnmulde           	1
# schwacher           	1
# Hochebene           	1
# colossalen          	1
# Reservoirs          	1
# Lötschenlücke       	1
# Breithorn           	1
# der'Jungfrau        	1
# vorbei              	1
# umschliessend       	1
# ausdehnt            	1
# Aletschgletscher    	1
# speist              	1
# Läge                	1
# 2                   	1
# St.                 	1
# Flächeninhalt       	1
# 10,000y             	1
# möchten             	1
# eidgenössischen     	1
# Miiitärdirection    	1
# Schiessübungen      	1
# gezogenem           	1
# Geschütz            	1
# Links               	1
# erscheinen          	1
# Grenadiere          	1
# Ehrfurcht           	1
# gebietend           	1
# nächste             	1
# Respekt             	1
# betrachtet          	1
# Firngehänge         	1
# mächtige            	1
# Aletschfirn         	1
# dominirende         	1
# Hauptkerl           	1
# volle               	1
# 150                 	1
# überragend          	1
# Bietsch-            	1
# Nest-               	1
# Comp                	1
# Hörner              	1
# Ferne               	1
# Balmhorn            	1
# Nachbarn            	1
# reicher             	1
# Wer                 	1
# zählet              	1
# V                   	1
# weitläufige         	1
# Nomenclatur         	1
# erlassen            	1
# Bildes              	1
# Grossartigkeit      	1
# Ernstes             	1
# erhöht              	1
# jeglicher           	1
# fehlt               	1
# Plätzchen           	1
# gletschergeblendete 	1
# ausruhen            	1
# starre              	1
# Gletscherwildniss   	1
# gesammten           	1
# fernen              	1
# Horizont            	1
# begrenzt            	1
# Montblanc           	1
# Nesthörner          	1
# schreckliche        	1
# Matterhorn          	1
# unmittelbar         	1
# nimmt               	1
# folgt               	1
# Tessiner            	1
# jeden               	1
# abschliesst         	1
# Diess               	1
# matten              	1
# Zügen               	1
# Augen               	1
# War                 	1
# Ersatz              	1
# heiterer            	1
# wolkenloser         	1
# Septemberhim-mel    	1
# Details             	1
# Schärfste           	1
# hervortreten        	1
# wunderbare          	1
# ungestörter         	1
# Fröhlichkeit        	1
# pfeifenden          	1
# geschützt           	1
# lagerten            	1
# ausgestreckt        	1
# leerten             	1
# Becher              	1
# perlenden           	1
# Weines              	1
# Ehren               	1
# angetreten          	1
# Einen               	1
# majestätischen      	1
# Rundblick           	1
# geschaut            	1
# abwärts             	1
# verfolgten          	1
# gleichen            	1
# eingeschlagen       	1
# Weber'Tasche        	1
# stecken             	1
# Lebenszweck         	1
# erfüllen            	1
# Stoff               	1
# Roman               	1
# Memoiren            	1
# frugalem            	1
# Mahle               	1
# beschwert           	1
# half                	1
# dazu                	1
# Schlummers          	1
# weckten             	1
# schlotternden       	1
# all                 	1
# Schreckhoin         	1
# prangte             	1
# Sichel              	1
# erhellte            	1
# matt                	1
# geisterhaft         	1
# de                  	1
# ®                   	1
# unsicherem          	1
# Lichte              	1
# silberne            	1
# Säbel               	1
# umsonst             	1
# gesucht             	1
# rief                	1
# neuem               	1
# Marsche             	1
# hell                	1
# erkennen            	1
# fünf                	1
# Minuten             	1
# bequem              	1
# Niemandes           	1
# Gefrühstückt        	1
# Temperatur          	1
# Luft                	1
# abmarschirten       	1
# behutsam            	1
# sicher              	1
# quälender           	1
# Va                  	1
# U.                  	1
# löschen             	1
# Trank               	1
# herrlichsten        	1
# Quellwassers        	1
# Verzeiht            	1
# erzähle             	1
# Schnittchen         	1
# Salami              	1
# Flaschen            	1
# frühstückten        	1
# Açutzov             	1
# ^                   	1
# vdaQ.               	1
# munter              	1
# los                 	1
# Jauchzen            	1
# Springen            	1
# dankbaren           	1
# Gefühls             	1
# begrüssten          	1
# aufgehenden         	1
# Viescberhorn        	1
# sehöneiVKranz       	1
# freudigem           	1
# Roth                	1
# übergoss            	1
# verklärte           	1
# Hell                	1
# schlägt             	1
# Gegrüsst            	1
# Morgenlicht         	1
# gegrüsst            	1
# Kaffee              	1
# Materie             	1
# verlangt            	1
# Erlangten           	1
# Herrlichkeiten      	1
# Gotteswelt          	1
# interessanten       	1
# Vergleiches         	1
# übrigen             	1
# weitem              	1
# Gesammteffectes     	1
# Blickes             	1
# muss                	1
# Fall                	1
# 19                  	1
# heiter              	1
# Schreekhorn         	1
# entschieden         	1
# sogar               	1
# weiten              	1
# Alpenpanoramas      	1
# Vorzug              	1
# allen               	1
# Kolossale           	1
# Vordergrunde        	1
# Viescherhorne       	1
# Nachbar             	1
# Schönen             	1
# vernahmen           	1
# Carl                	1
# Baedeker            	1
# Coblenz             	1
# geharrt             	1
# habe                	1
# Ankunft             	1
# langten             	1
# rechtzeitig         	1
# nunmehrigen         	1
# Ehrenmitgliede      	1
# Frl.                	1
# Brunner             	1
# Bern                	1
# authentische        	1
# Versicherung        	1
# muthig              	1
# Galenstock          	1
# Mach's              	1
# na                  	1
# u                   	1
# PS                  	1
# Tage                	1
# vollständiger       	1
# Windstille          	1
# erfreuen            	1

# %% [markdown]
# We can count the terms in our documents, and order them by rank. Try changing the statements to see what happens with different conditions.

# %%
terms = [token.text for token in doc]

# Remove stop words and punctuation
#terms = [token.text for token in doc if not token.is_stop and not token.is_punct] 

# Remove stop words, punctuation and retain only nouns
#terms = [token.text for token in doc if not token.is_stop and not token.is_punct and token.pos_ == 'NOUN']

ranked_terms = Counter(terms).most_common()

print(f"{'Term':<20}\t{'Count':<3}\n")
for term, count in ranked_terms:
    print(f"{term:<20}\t{count:<3}")
# Out:
# Term                	Count
#
# ,                   	518
# .                   	210
# und                 	199
# der                 	176
# die                 	150
# das                 	112
# ;                   	101
# wir                 	96
# uns                 	94
# zu                  	80
# in                  	77
# den                 	64
# sich                	61
# dem                 	60
# von                 	60
# nicht               	56
# ein                 	54
# des                 	50
# war                 	48
# „                   	44
# "                   	43
# mit                 	39
# auch                	36
# so                  	35
# ist                 	33
# 's                  	32
# auf                 	31
# aber                	29
# es                  	26
# vor                 	25
# als                 	25
# im                  	24
# nach                	24
# wurde               	24
# eine                	24
# an                  	23
# um                  	22
# über                	21
# noch                	21
# hatten              	20
#                     	19
# nur                 	19
# ich                 	19
# !                   	19
# dass                	19
# :                   	18
# er                  	18
# zum                 	18
# durch               	18
# aus                 	17
# doch                	17
# dann                	17
# einer               	17
# —                   	17
# am                  	16
# dieser              	16
# wieder              	16
# wie                 	15
# Viescherhorn        	15
# Uhr                 	15
# einem               	14
# da                  	14
# ganz                	14
# sie                 	14
# wird                	14
# M.                  	13
# Theil               	13
# bis                 	13
# Spitze              	13
# Der                 	12
# hatte               	12
# mehr                	12
# bald                	12
# waren               	12
# einen               	12
# dieses              	11
# sehr                	11
# ihm                 	11
# bei                 	11
# immer               	11
# für                 	11
# grossen             	10
# Das                 	10
# hier                	10
# sein                	10
# unter               	10
# vom                 	10
# ?                   	10
# Schnee              	10
# Grat                	10
# mir                 	9
# ihre                	9
# ihn                 	9
# Führer              	9
# oder                	9
# zur                 	9
# Mönchjoch           	9
# sichtbar            	9
# unser               	9
# wäre                	9
# fast                	8
# etwas               	8
# unserer             	8
# weg                 	8
# Fuss                	8
# nun                 	8
# seine               	8
# wenn                	8
# Grosse              	7
# schönen             	7
# Gletscher           	7
# Herr                	7
# haben               	7
# Mönch               	7
# selbst              	7
# Fels                	7
# Blick               	7
# Eismeer             	7
# ihr                 	7
# zieht               	7
# unsere              	7
# Namen               	7
# rechts              	7
# hin                 	7
# werden              	7
# denn                	7
# steilen             	7
# gerade              	7
# Nebel               	7
# viel                	6
# weil                	6
# was                 	6
# So                  	6
# Weg                 	6
# ohne                	6
# Nach                	6
# Und                 	6
# sind                	6
# anderen             	6
# grosse              	6
# dort                	6
# alle                	6
# Wir                 	6
# diese               	6
# Ewig-Schneefeld     	6
# Kette               	6
# Grünhörner          	6
# Seite               	6
# also                	6
# Felsen              	6
# Dach                	6
# zwei                	6
# wohl                	6
# ward                	6
# Wie                 	6
# Gipfel              	6
# zwischen            	6
# Grindelwald         	5
# können              	5
# Aber                	5
# eines               	5
# Auf                 	5
# einmal              	5
# dessen              	5
# machen              	5
# sei                 	5
# *                   	5
# Decken              	5
# Rubi                	5
# Inäbnit             	5
# Doch                	5
# hinter              	5
# erst                	5
# eben                	5
# wo                  	5
# weniger             	5
# steil               	5
# Um                  	5
# Schrunde            	5
# letzten             	5
# Bergli              	5
# man                 	5
# fanden              	5
# links               	5
# lange               	5
# Tag                 	5
# diesen              	5
# etwa                	5
# Die                 	5
# kaum                	5
# Dann                	5
# Kälte               	5
# Norden              	5
# schon               	5
# Ein                 	5
# hinaus              	5
# -                   	4
# Von                 	4
# Wetterhorn          	4
# Eiger               	4
# guten               	4
# ganze               	4
# frei                	4
# ihren               	4
# dahin               	4
# Weber               	4
# gar                 	4
# grösser             	4
# Doctor              	4
# wurden              	4
# gute                	4
# fort                	4
# Peter               	4
# ersten              	4
# Bärenegg            	4
# genommen            	4
# würde               	4
# vier                	4
# Kalli               	4
# Höhe                	4
# hinunter            	4
# Wetter              	4
# hindurch            	4
# Strahleck           	4
# unstreitig          	4
# besonders           	4
# weiteren            	4
# Blicke              	4
# erhebt              	4
# aufs                	4
# ging                	4
# Seil                	4
# deutlich            	4
# Spuren              	4
# kleinen             	4
# Flasche             	4
# Stunde              	4
# betraten            	4
# obersten            	4
# Zeit                	4
# erreichten          	4
# Trugberg            	4
# diesem              	4
# gleich              	4
# ebenfalls           	4
# Jungfrau            	4
# freilich            	4
# In                  	4
# ab                  	4
# Gemüth              	4
# Alpen               	4
# Ersteigung          	4
# bildet              	4
# seiner              	4
# sehen               	4
# Hand                	4
# gewesen             	4
# Herrn               	4
# gut                 	4
# recht               	4
# ruhig               	4
# hat                 	4
# endlich             	4
# jetzt               	4
# Grossen             	4
# ganzen              	4
# zerrissenen         	4
# diess               	4
# voran               	4
# damit               	4
# unseren             	4
# Vieschergrat        	4
# Walliser            	4
# gewaltigen          	4
# 1                   	4
# Geist               	4
# kalten              	4
# Grünhornkette       	4
# Eigerhöhle          	4
# Es                  	4
# Ich                 	3
# mich                	3
# unserem             	3
# hinüber             	3
# Jahre               	3
# könnte              	3
# Da                  	3
# keine               	3
# Sie                 	3
# gern                	3
# mag                 	3
# möchte              	3
# Grindelwaldner      	3
# Unsere              	3
# engagirt            	3
# glücklich           	3
# machte              	3
# worden              	3
# kam                 	3
# Träger              	3
# nächsten            	3
# dabei               	3
# einiger             	3
# abmarschirt         	3
# untere              	3
# einige              	3
# Grindelwalder       	3
# Vieschergletscher   	3
# Vieschergrates      	3
# daher               	3
# Joches              	3
# Freund              	3
# weiss               	3
# drei                	3
# hinsichtlich        	3
# Aussicht            	3
# Passhöhe            	3
# Grünhörnern         	3
# wenig               	3
# befestigt           	3
# darin               	3
# hervor              	3
# her                 	3
# Nacht               	3
# Nordwind            	3
# leider              	3
# seinem              	3
# Schneefeld          	3
# kühn                	3
# wilder              	3
# Anblick             	3
# erreichen           	3
# müssen              	3
# überschreiten       	3
# Thür                	3
# Haus                	3
# Laden               	3
# Gott                	3
# Jahr                	3
# quer                	3
# nahe                	3
# Sonne               	3
# o                   	3
# 4                   	3
# °                   	3
# Alles               	3
# freundlich          	3
# Füsse               	3
# neben               	3
# genug               	3
# geworden            	3
# herein              	3
# sahen               	3
# Mondes              	3
# lang                	3
# Man                 	3
# Nicht               	3
# pfiff               	3
# genossen            	3
# beiden              	3
# dar                 	3
# scharf              	3
# ansteigenden        	3
# obgleich            	3
# Schwierigkeiten     	3
# Gefahr              	3
# Eine                	3
# zog                 	3
# gegen               	3
# Bogen               	3
# direkt              	3
# weiter              	3
# Recht               	3
# rasch               	3
# zwar                	3
# vielen              	3
# möglich             	3
# Stück               	3
# 10                  	3
# Firnhang            	3
# Himmel              	3
# Auge                	3
# Umgebung            	3
# sagen               	3
# liess               	3
# lassen              	3
# mussten             	3
# alles               	3
# höchste             	3
# Gruppe              	3
# Steinmannli         	3
# kleines             	3
# Fläschchen          	3
# musste              	3
# Sommer              	3
# Bild                	3
# Viescherfirn        	3
# Alpenwelt           	3
# ihrem               	3
# du                  	3
# Partien             	3
# Augenblick          	3
# Besteigung          	3
# )                   	3
# kommt               	3
# E.                  	3
# Finsteraarhorn      	3
# 5                   	3
# Durst               	3
# Birne               	3
# Pfarrer             	2
# August              	2
# Jahres              	2
# Anderen             	2
# Freude              	2
# September           	2
# hinein              	2
# Seufzer             	2
# alten               	2
# milden              	2
# herrlichen          	2
# lag                 	2
# Bilde               	2
# schritten           	2
# Pläne               	2
# Ach                 	2
# bin                 	2
# gehabt              	2
# Noch                	2
# gekommen            	2
# freundlicher        	2
# Rath                	2
# mochte              	2
# darum               	2
# thut                	2
# Ja                  	2
# Proviant            	2
# Schreckhorn         	2
# tüchtige            	2
# Alle                	2
# empfehlen           	2
# Keiner              	2
# Als                 	2
# Baumann             	2
# Dienste             	2
# Hütte               	2
# nehmen              	2
# anzugreifen         	2
# eilen               	2
# Wohl                	2
# allem               	2
# Stunden             	2
# Eismeere            	2
# Mit                 	2
# Meyer               	2
# Folge               	2
# Eis                 	2
# gewandt             	2
# richtig             	2
# stark               	2
# überschreitend      	2
# Lawinenschnee       	2
# grünen              	2
# wanden              	2
# sonst               	2
# Kallitritt          	2
# Felsband            	2
# oberen              	2
# Ansteigen           	2
# 12                  	2
# Halt                	2
# betreten            	2
# leicht              	2
# z.B.                	2
# oft                 	2
# Fellenberg          	2
# Gletscherumgebung   	2
# Aufsteigen          	2
# schöner             	2
# Wand                	2
# Rechten             	2
# Kalkwand            	2
# Eigers              	2
# tiefer              	2
# vorwärts            	2
# weite               	2
# Leben               	2
# Mitten              	2
# Kamm                	2
# Kletterei           	2
# An                  	2
# Steine              	2
# Engländer           	2
# Führung             	2
# erhebend            	2
# heftiger            	2
# näher               	2
# 6                   	2
# stand               	2
# Ehre                	2
# weithin             	2
# Neigung             	2
# Rechts              	2
# massiv              	2
# geht                	2
# Reihe               	2
# wirklich            	2
# Charakter           	2
# Majestät            	2
# lässt               	2
# Punkte              	2
# Gletscherwelt       	2
# gelüstete           	2
# Bise                	2
# drüben              	2
# wenden              	2
# rüstig              	2
# Ewig-Schneefeldes   	2
# Gasthof             	2
# hart                	2
# Schweizer           	2
# genau               	2
# Herberge            	2
# Mönchs              	2
# Station             	2
# Viescherhorns       	2
# Drei                	2
# kein                	2
# Dachlatten          	2
# Arbeit              	2
# Führern             	2
# Vollendung          	2
# Rüstig              	2
# Werk                	2
# gelegt              	2
# darüber             	2
# konnten             	2
# legten              	2
# einander            	2
# bedeckt             	2
# Entfernung          	2
# konnte              	2
# thun                	2
# Wärme               	2
# keinen              	2
# Nachdem             	2
# brennenden          	2
# Weingeistmaschine   	2
# Bouillon            	2
# zeigte              	2
# dennoch             	2
# R.                  	2
# heftige             	2
# übrigens            	2
# nämlich             	2
# Hutte               	2
# resp                	2
# helfen              	2
# gewahr              	2
# heulte              	2
# bedenklich          	2
# Fugen               	2
# Sterne              	2
# hie                 	2
# jagte               	2
# wild                	2
# ihnen               	2
# bringen             	2
# wahrscheinlich      	2
# Heer                	2
# Schlaf              	2
# Ritsch              	2
# Ratsch              	2
# liegen              	2
# Bresche             	2
# angezogen           	2
# wann                	2
# abermals            	2
# Bald                	2
# Dämmerung           	2
# Sturm               	2
# entschlossen        	2
# abzuwarten          	2
# Strahlen            	2
# nöthigte            	2
# halber              	2
# Abends              	2
# nichts              	2
# während             	2
# Den                 	2
# Glieder             	2
# Punkt               	2
# Ungestüm            	2
# Linie               	2
# stellte             	2
# Thale               	2
# Nordseite           	2
# gesehen             	2
# Standpunkt          	2
# Hörn                	2
# breit               	2
# zunächst            	2
# Felsrippe           	2
# folgend             	2
# müsste              	2
# erreicht            	2
# trauten             	2
# vielleicht          	2
# dritte              	2
# solche              	2
# Rippe               	2
# zweiten             	2
# Endlich             	2
# bot                 	2
# liegenden           	2
# unten               	2
# schwierig           	2
# rückten             	2
# Auch                	2
# standen             	2
# Bergschrund         	2
# Couloir             	2
# Gneiss              	2
# Beschaffenheit      	2
# Ding                	2
# bedeutend           	2
# betragen            	2
# Mittagssonne        	2
# Spisspeter          	2
# Vorsicht            	2
# lachte              	2
# Umgebungen          	2
# Nähe                	2
# Nord                	2
# j                   	2
# finstere            	2
# Ziel                	2
# wollen              	2
# ja                  	2
# Rückzug             	2
# wollte              	2
# wollten             	2
# keiner              	2
# leichter            	2
# liegende            	2
# oberste             	2
# 4048                	2
# ü.                  	2
# Tannli              	2
# Almer               	2
# festgebunden        	2
# verschlossen        	2
# Tucket's            	2
# 1864                	2
# erstiegen           	2
# Ersteiger           	2
# Herren              	2
# daran               	2
# obere               	2
# Mettenberg          	2
# Grüne               	2
# Höhen               	2
# Contrast            	2
# versuchen           	2
# Grates              	2
# nahezu              	2
# Süden               	2
# Kleinen             	2
# südöstlich          	2
# seinen              	2
# Lauteraarhorn       	2
# andern              	2
# westwärts           	2
# dehnt               	2
# hintere             	2
# Wal-                	2
# User                	2
# Orakelsprüche       	2
# ihrer               	2
# Erkenntniss         	2
# dadurch             	2
# spricht             	2
# deinem              	2
# hemmt               	2
# Natur               	2
# Menschen            	2
# Land                	2
# dir                 	2
# Lauf                	2
# Ganzen              	2
# einzelnen           	2
# zuerst              	2
# heimathlichen       	2
# Thal                	2
# gross               	2
# grossartigsten      	2
# hellen              	2
# Bruder              	2
# Nur                 	2
# klein               	2
# einziger            	2
# v.                  	2
# kurz                	2
# verdeckt            	2
# beim                	2
# Nun                 	2
# malerischen         	2
# fröhlichem          	2
# Hurrah              	2
# Tiefe               	2
# Aletschhorn         	2
# u.                  	2
# Stern               	2
# gerne               	2
# darauf              	2
# Im                  	2
# Ausblick            	2
# weich               	2
# (                   	2
# Schritte            	2
# hohe                	1
# GrünhornPfaffenstöckli	1
# bemerklich          	1
# Juni                	1
# d.                  	1
# J.                  	1
# Unerstiegenheit     	1
# abgerungen          	1
# Gerade              	1
# folgen              	1
# geringer            	1
# blendend            	1
# weissen             	1
# kecke               	1
# ob                  	1
# Differenz           	1
# 170                 	1
# rühren              	1
# Firnfeld            	1
# verhältnissmässig   	1
# Dreieck             	1
# heraushebt          	1
# Horn                	1
# Verhältniss         	1
# hohen               	1
# Basis               	1
# sagt                	1
# bisheriger          	1
# Meister             	1
# geringe             	1
# Vertiefung          	1
# welchen             	1
# durchaus            	1
# verdiene            	1
# Diesem              	1
# entlang             	1
# mustern             	1
# Spitzen             	1
# Einsenkungen        	1
# überzeugen          	1
# unzugänglich        	1
# Gemisch             	1
# abschüssigen        	1
# Gletscherhängen     	1
# beständiger         	1
# 11,000              	1
# Genug               	1
# sieht               	1
# Besuch              	1
# ladet               	1
# würdige             	1
# Culminations-       	1
# Schlusspunkt        	1
# darstellt           	1
# weist               	1
# gewöhnlich          	1
# gewählt             	1
# gegenüberliegenden  	1
# WaHiser             	1
# und-Firn            	1
# grösseren           	1
# Viescher-hora       	1
# Kopf                	1
# bischen             	1
# drücken             	1
# klar                	1
# Neue                	1
# regten              	1
# Wildheit            	1
# prachtvollen        	1
# Reviers             	1
# ruhen               	1
# Zeitenschoosse      	1
# Einzelnen           	1
# bedeutendste        	1
# Kreissegment        	1
# einerseits          	1
# auslaufenden        	1
# anderseits          	1
# Radien              	1
# eingeschlossen      	1
# N.                  	1
# S.                  	1
# laufend             	1
# stellt              	1
# Sierra              	1
# unerwarteter        	1
# Stattlichkeit       	1
# Oberhaupt           	1
# beugt               	1
# dagegen             	1
# monoton             	1
# Aehnlichkeit        	1
# Ganze               	1
# Effekt              	1
# Am                  	1
# meisten             	1
# rGrosse             	1
# Grünhorn            	1
# Steinmänniis        	1
# willen              	1
# Fellentterg         	1
# erachtet            	1
# Vize-Fellenberg     	1
# begrüssen           	1
# stösst              	1
# überall             	1
# unruhigen           	1
# Geistes             	1
# Dde                 	1
# schätzte            	1
# ungefähr            	1
# denen               	1
# Längs               	1
# eingedämmt          	1
# Trugberge           	1
# merkwürdige         	1
# Firnmulde           	1
# schwacher           	1
# Hochebene           	1
# colossalen          	1
# Reservoirs          	1
# Lötschenlücke       	1
# Breithorn           	1
# der'Jungfrau        	1
# vorbei              	1
# umschliessend       	1
# ausdehnt            	1
# Aletschgletscher    	1
# speist              	1
# Läge                	1
# 2                   	1
# St.                 	1
# Flächeninhalt       	1
# 10,000y             	1
# möchten             	1
# eidgenössischen     	1
# Miiitärdirection    	1
# Schiessübungen      	1
# gezogenem           	1
# Geschütz            	1
# Links               	1
# erscheinen          	1
# Grenadiere          	1
# Ehrfurcht           	1
# gebietend           	1
# nächste             	1
# Respekt             	1
# betrachtet          	1
# Firngehänge         	1
# mächtige            	1
# Aletschfirn         	1
# dominirende         	1
# Hauptkerl           	1
# volle               	1
# 150                 	1
# überragend          	1
# Bietsch-            	1
# Nest-               	1
# muss                	1
# Fall                	1
# 19                  	1
# heiter              	1
# Schreekhorn         	1
# entschieden         	1
# sogar               	1
# weiten              	1
# Alpenpanoramas      	1
# Vorzug              	1
# allen               	1
# Kolossale           	1
# Vordergrunde        	1
# Viescherhorne       	1
# Nachbar             	1
# Schönen             	1
# vernahmen           	1
# Carl                	1
# Baedeker            	1
# Coblenz             	1
# geharrt             	1
# habe                	1
# Ankunft             	1
# langten             	1
# rechtzeitig         	1
# nunmehrigen         	1
# Ehrenmitgliede      	1
# Frl.                	1
# Brunner             	1
# Bern                	1
# authentische        	1
# Versicherung        	1
# muthig              	1
# Galenstock          	1
# Mach's              	1
# na                  	1
# u                   	1
# PS                  	1
# Tage                	1
# vollständiger       	1
# Windstille          	1
# erfreuen            	1

# %%
from os import walk
import random

path = 'C:\\Users\\rsp\\Dropbox\\geo871_corpora\\textAndBerg1000\\'
filenames = next(walk(path), (None, None, []))[2]
files = random.sample(filenames, 10)

for file in files:
    with open(path + file, 'r', encoding='utf-8') as file:
        text = text + file.read().replace('\n', ' ')

# %%
doc = nlp(text)

terms = [token.text for token in doc if not token.is_stop and not token.is_punct ]
ranked_terms = Counter(terms).most_common()

print(f"{'Term':<20}\t{'Count':<3}\n")
for term, count in ranked_terms:
    print(f"{term:<20}\t{count:<3}")
# Out:
# Term                	Count
#
# de                  	1953
# la                  	997
# le                  	887
# et                  	818
# l                   	811
# à                   	624
# d'                  	480
# par                 	435
# une                 	395
# les                 	393
# m                   	327
# glacier             	296
# un                  	296
# au                  	282
# est                 	260
# dans                	236
# sur                 	233
# ont                 	219
# que                 	199
# mètres              	193
# plus                	190
# deux                	173
# qui                 	165
# pour                	155
# Le                  	146
# été                 	146
# sommet              	137
# avec                	125
# +                   	122
# camp                	119
# il                  	116
# voie                	116
# se                  	115
# arête               	113
# 's                  	106
# équipe              	106
# face                	103
# s'                  	102
# son                 	96
# Weg                 	93
# base                	93
# trois               	92
# n                   	92
# Gipfel              	91
#                     	90
# La                  	90
# Felsen              	89
# Schnee              	87
# AU                  	87
# ce                  	86
# qu                  	84
# nous                	83
# M.                  	81
# cette               	81
# Führer              	80
# sont                	80
# neige               	78
# pas                 	78
# glaciers            	78
# atteint             	78
# L'                  	77
# ou                  	77
# fait                	77
# Gletscher           	76
# 1                   	76
# grimpeurs           	76
# ascension           	75
# Nord                	72
# 2                   	72
# Fuss                	68
# m.                  	68
# octobre             	67
# Sud                 	67
# Les                 	65
# même                	65
# mais                	63
# ne                  	62
# première            	62
# Höhe                	61
# y                   	61
# aux                 	61
# années              	61
# Une                 	61
# fast                	60
# Piz                 	60
# glace               	59
# quatre              	59
# Grat                	58
# 7                   	58
# leur                	58
# 3                   	57
# 5                   	57
# après               	57
# Val                 	57
# 4                   	56
# très                	56
# Unteraar            	56
# vers                	56
# p.                  	56
# ans                 	56
# 1907                	56
# année               	54
# expédition          	54
# sa                  	53
# Il                  	53
# jusqu               	53
# Stunden             	52
# 10                  	52
# hinauf              	52
# août                	52
# encore              	52
# entre               	52
# camps               	52
# Spitze              	50
# Ouest               	49
# ces                 	48
# 8                   	47
# variations          	47
# montagne            	47
# chef                	46
# Berge               	46
# Aussicht            	45
# 6                   	45
# Seite               	44
# steilen             	44
# était               	44
# dont                	44
# juin                	44
# rechts              	43
# 11                  	43
# liegt               	43
# sans                	43
# sous                	43
# steil               	42
# 12                  	42
# Seil                	42
# altitude            	42
# carte               	41
# environ             	41
# juillet             	41
# 15                  	41
# expéditions         	41
# Jungfrau            	40
# links               	40
# crue                	40
# temps               	40
# mai                 	40
# Japonais            	40
# Stunde              	39
# Au                  	39
# observations        	39
# cinq                	39
# Meter               	39
# Sonne               	38
# unten               	38
# peu                 	38
# ses                 	37
# Un                  	37
# septembre           	37
# tentative           	37
# schönen             	36
# Alpen               	36
# Stelle              	36
# près                	36
# on                  	36
# nouvelle            	36
# Boden               	36
# Silberhorn          	36
# lassen              	35
# comme               	35
# Deux                	35
# hinab               	35
# Ersteigung          	34
# J.                  	34
# Peak                	34
# 1906                	34
# Nacht               	33
# erreichen           	33
# sehen               	33
# SW                  	33
# sherpas             	33
# Eis                 	32
# hinunter            	32
# Alpes               	32
# où                  	32
# Glacier             	32
# jours               	32
# Est                 	32
# descente            	32
# Avers               	32
# Blick               	31
# Namen               	31
# Theil               	31
# °                   	31
# rasch               	31
# Richtung            	31
# nord                	31
# langue              	31
# Wetter              	30
# erreicht            	30
# 20                  	30
# ils                 	30
# fois                	30
# bien                	30
# 14                  	30
# être                	30
# six                 	30
# Herr                	29
# u.                  	29
# ainsi               	29
# tout                	29
# elle                	29
# A.                  	29
# alpin               	29
# autres              	29
# chutes              	29
# au-dessus           	29
# höchsten            	29
# 9                   	28
# tief                	28
# Nebel               	28
# grand               	28
# col                 	28
# C                   	28
# point               	28
# avait               	28
# normale             	28
# température         	28
# bildet              	27
# Auge                	27
# glaciaire           	27
# partie              	27
# Agassiz             	27
# donc                	27
# II                  	27
# via                 	27
# Pflanzen            	27
# schien              	26
# Stellen             	26
# steile              	26
# Minuten             	26
# Mont                	26
# I                   	26
# maximum             	26
# moins               	26
# eu                  	26
# eau                 	26
# style               	26
# Lauener             	26
# letzten             	25
# 25                  	25
# 18                  	25
# Wege                	25
# ziemlich            	25
# Stück               	25
# Tiefe               	25
# langsam             	25
# Cette               	25
# Genève              	25
# établi              	25
# bivouac             	25
# Monte               	25
# finden              	24
# Hütte               	24
# fanden              	24
# Arbeit              	24
# liegen              	24
# steigen             	24
# j                   	24
# höher               	24
# stehen              	24
# s.                  	24
# Wasser              	24
# extrémité           	24
# avoir               	24
# sud                 	24
# 30                  	24
# 28                  	24
# itinéraire          	24
# schön               	24
# Leiter              	24
# fand                	23
# 50                  	23
# Wand                	23
# Himmel              	23
# fin                 	23
# droite              	23
# région              	23
# aussi               	23
# puis                	23
# siècle              	23
# NE                  	23
# extension           	23
# nombre              	23
# avons               	23
# pendant             	23
# soit                	23
# 23                  	23
# 22                  	23
# tous                	23
# deuxième            	23
# 24                  	23
# conduite            	23
# haut                	23
# unsern              	23
# enneigement         	23
# guten               	22
# hervor              	22
# hinaus              	22
# ü.                  	22
# E.                  	22
# S.                  	22
# longueur            	22
# cf                  	22
# cours               	22
# jour                	22
# autre               	22
# celle               	22
# escalade            	22
# porteurs            	22
# Osten               	22
# Rosa                	22
# Kronstadt           	22
# unserem             	21
# Michel              	21
# Fels                	21
# Wald                	21
# Süden               	21
# Thal                	21
# w.                  	21
# steht               	21
# lieu                	21
# Sur                 	21
# seulement           	21
# depuis              	21
# mauvais             	21
# Alp                 	21
# Gebirge             	21
# Hermannstadt        	21
# 1905                	21
# Abend               	20
# alten               	20
# Mann                	20
# Freund              	20
# erhebt              	20
# betraten            	20
# kamen               	20
# nahe                	20
# zogen               	20
# Umgebung            	20
# pied                	20
# front               	20
# difficile           	20
# De                  	20
# trop                	20
# échelle             	20
# 16                  	20
# cause               	20
# Ce                  	20
# 17                  	20
# étaient             	20
# suivi               	20
# Trois               	20
# membres             	20
# placé               	20
# VII                 	20
# scheint             	20
# stiegen             	20
# theils              	20
# Cresta              	20
# Siebenbürgen        	20
# ai                  	20
# z.B.                	19
# sichtbar            	19
# erreichten          	19
# Mitte               	19
# bietet              	19
# St.                 	19
# paar                	19
# gauche              	19
# haute               	19
# probablement        	19
# quelques            	19
# 1871                	19
# Versuch             	19
# versant             	19
# 1981                	19
# C.                  	19
# période             	19
# côté                	19
# tableau             	19
# Nous                	19
# 13                  	19
# premier             	19
# Dans                	19
# longue              	19
# suisse              	19
# rocher              	19
# dernier             	19
# SE                  	19
# chute               	19
# dix                 	19
# gravi               	19
# Camp                	19
# bivouacs            	19
# Schlucht            	19
# di                  	18
# Labyrinth           	18
# Leben               	18
# lässt               	18
# gesehen             	18
# Firn                	18
# höchste             	18
# unseren             	18
# einzelnen           	18
# Besteigung          	18
# Juni                	18
# Fall                	18
# 19                  	18
# celui               	18
# ici                 	18
# semble              	18
# avant               	18
# IV                  	18
# mois                	18
# faire               	18
# avril               	18
# 27                  	18
# NW                  	18
# führt               	18
# einzelne            	18
# Sattel              	18
# Zermatt             	18
# Aufnahme            	18
# 1903                	18
# grünen              	17
# Halt                	17
# hindurch            	17
# weiss               	17
# deutlich            	17
# Fusse               	17
# empor               	17
# genau               	17
# Hand                	17
# Wind                	17
# ward                	17
# Hütten              	17
# Sommer              	17
# Luft                	17
# moraine             	17
# On                  	17
# peut                	17
# aujourd'hui         	17
# 1842                	17
# plusieurs           	17
# seul                	17
# névé                	17
# heures              	17
# hommes              	17
# route               	17
# Ils                 	17
# III                 	17
# Platz               	17
# gelangen            	17
# Gebiet              	17
# meist               	17
# See                 	17
# Bernina             	17
# 0                   	17
# frei                	16
# Dr.                 	16
# fort                	16
# bedeckt             	16
# sahen               	16
# hie                 	16
# Norden              	16
# Schwierigkeiten     	16
# sagen               	16
# Bild                	16
# Menschen            	16
# hohen               	16
# vorbei              	16
# gleichen            	16
# vallée              	16
# milieu              	16
# Lauteraar           	16
# toute               	16
# là                  	16
# vu                  	16
# effet               	16
# pu                  	16
# progression         	16
# tentatives          	16
# avalanches          	16
# Pilier              	16
# premiers            	16
# tenté               	16
# leader              	16
# Tal                 	16
# Regen               	16
# verlassen           	16
# Silberhorns         	16
# führen              	16
# Bischoff            	16
# dicht               	16
# Rothhorn            	16
# Abstieg             	16
# topographischen     	16
# variation           	16
# décrue              	16
# Arolla              	16
# August              	15
# Eiger               	15
# lag                 	15
# Viescherhorn        	15
# schwer              	15
# Peter               	15
# Träger              	15
# Mönch               	15
# nehmen              	15
# nächsten            	15
# genommen            	15
# Mal                 	15
# fest                	15
# standen             	15
# 40                  	15
# Natur               	15
# findet              	15
# Augenblick          	15
# Augen               	15
# Ufer                	15
# vue                 	15
# Abschwung           	15
# forme               	15
# comprenant          	15
# c                   	15
# tard                	15
# Après               	15
# non                 	15
# dû                  	15
# 1979                	15
# alors               	15
# névés               	15
# mille               	15
# 26                  	15
# 29                  	15
# équipes             	15
# Everest             	15
# Quatre              	15
# 21                  	15
# 1982                	15
# Tour                	15
# Gletschern          	15
# Weise               	15
# Mai                 	15
# höheren             	15
# angelangt           	15
# Aufstieg            	15
# estivale            	15
# Grindelwald         	14
# stark               	14
# obersten            	14
# weg                 	14
# ebenfalls           	14
# Ort                 	14
# Punkt               	14
# Gletschers          	14
# liess               	14
# führte              	14
# Fahne               	14
# obere               	14
# sieht               	14
# Finsteraarhorn      	14
# gewöhnlich          	14
# meisten             	14
# meinte              	14
# sommets             	14
# paroi               	14
# terrain             	14
# Grimsel             	14
# Mais                	14
# grande              	14
# Si                  	14
# K.                  	14
# mis                 	14
# déjà                	14
# 1840                	14
# VIII                	14
# rochers             	14
# principal           	14
# 1904                	14
# résultats           	14
# épaisseur           	14
# si                  	14
# dernière            	14
# Américains          	14
# participants        	14
# T.                  	14
# VI                  	14
# Bergen              	14
# mehrere             	14
# Bach                	14
# gelangten           	14
# Schatten            	14
# Berg                	14
# Landschaft          	14
# Touren              	14
# Schneehorn          	14
# Westen              	14
# Karpathen           	14
# rumänischen         	14
# halb                	13
# glücklich           	13
# Flasche             	13
# unseres             	13
# Kette               	13
# Mönchs              	13
# Führern             	13
# Schlaf              	13
# genossen            	13
# nahmen              	13
# scharf              	13
# direkt              	13
# 45                  	13
# erstiegen           	13
# Grenze              	13
# blieb               	13
# Schritte            	13
# cela                	13
# doute               	13
# place               	13
# partir              	13
# ouest               	13
# au-dessous          	13
# arrière             	13
# époque              	13
# chaque              	13
# Pour                	13
# avancées            	13
# ouvert              	13
# avancée             	13
# P.                  	13
# ligne               	13
# hauteur             	13
# succès              	13
# notre               	13
# 1983                	13
# données             	13
# huit                	13
# décembre            	13
# sherpa              	13
# réussi              	13
# hivernale           	13
# 1er                 	13
# suisses             	13
# Pas                 	13
# tempête             	13
# sept                	13
# Davos               	13
# Erde                	13
# Weiden              	13
# Winter              	13
# halten              	13
# geben               	13
# Gestein             	13
# treten              	13
# schwarzen           	13
# besteht             	13
# vorsichtig          	13
# oberhalb            	13
# Gneis               	13
# Stein               	13
# Dom                 	13
# Hang                	13
# écarts              	13
# 1902                	13
# September           	12
# hinein              	12
# Decken              	12
# Eismeer             	12
# betreten            	12
# zieht               	12
# Spuren              	12
# stand               	12
# freilich            	12
# Anblick             	12
# nämlich             	12
# Thale               	12
# zog                 	12
# breite              	12
# bot                 	12
# voran               	12
# Ziel                	12
# Grates              	12
# folgen              	12
# V                   	12
# abwärts             	12
# folgenden           	12
# weiten              	12
# Bern                	12
# groupe              	12
# long                	12
# indique             	12
# lui                 	12
# début               	12
# voir                	12
# pente               	12
# valeur              	12
# assez               	12
# 1847                	12
# 43                  	12
# conditions          	12
# G.                  	12
# mesures             	12
# hiver               	12
# date                	12
# difficulté          	12
# Gasherbrum          	12
# suivant             	12
# conduits            	12
# française           	12
# pluie               	12
# Felswand            	12
# höchst              	12
# langen              	12
# Wasserfall          	12
# Gegend              	12
# wären               	12
# bilden              	12
# tiefen              	12
# Schweiz             	12
# zuletzt             	12
# Vegetation          	12
# plötzlich           	12
# wilden              	12
# Sache               	12
# Bädeker             	12
# Juli                	12
# einzige             	12
# etc.                	12
# Thales              	12
# jenseits            	12
# Rimpfischhorn       	12
# Negoi               	12
# Bucsecs             	12
# Sinaia              	12
# allures             	12
# totale              	12
# ablation            	12
# nivomètre           	12
# X                   	12
# Freude              	11
# hinan               	11
# oberen              	11
# Passhöhe            	11
# schöner             	11
# aufs                	11
# Terrasse            	11
# Reihe               	11
# wilder              	11
# überschreiten       	11
# Schweizer           	11
# Länge               	11
# zumal               	11
# thun                	11
# bringen             	11
# Licht               	11
# Kälte               	11
# Lage                	11
# Fahrt               	11
# Vorsicht            	11
# Nähe                	11
# Höhen               	11
# kalten              	11
# Abgrund             	11
# senkrecht           	11
# hohe                	11
# weissen             	11
# entlang             	11
# verdeckt            	11
# Horizont            	11
# kurze               	11
# all                 	11
# état                	11
# médiane             	11
# 1.                  	11
# maximale            	11
# moraines            	11
# grandes             	11
# Rhône               	11
# XVIIIe              	11
# Aar                 	11
# neiges              	11
# également           	11
# situation           	11
# topographique       	11
# direction           	11
# situé               	11
# D                   	11
# rive                	11
# siècles             	11
# fossiles            	11
# 1900                	11
# 60                  	11
# nouveau             	11
# phénomène           	11
# petite              	11
# aval                	11
# fut                 	11
# H.                  	11
# 3.                  	11
# avaient             	11
# elles               	11
# aurait              	11
# nos                 	11
# IX                  	11
# pilier              	11
# 32                  	11
# L.                  	11
# B.                  	11
# Hôtel               	11
# oxygène             	11
# escaladé            	11
# moyenne             	11
# Sommet              	11
# japonaise           	11
# abord               	11
# Tentative           	11
# Allemands           	11
# Zgraggen            	11
# prächtige           	11
# letzte              	11
# Uebergang           	11
# Ueber               	11
# Plateau             	11
# Hr.                 	11
# Guggigletscher      	11
# Schneehorns         	11
# Erscheinung         	11
# Wurzeln             	11
# Pontresina          	11
# Bergtouren          	11
# Schutzhütte         	11
# 1907.               	11
# Collon              	11
# Pfarrer             	10
# Gemeinde            	10
# Inäbnit             	10
# Morgens             	10
# Schrunde            	10
# Blicke              	10
# näher               	10
# Schneefeld          	10
# hart                	10
# Station             	10
# Dach                	10
# o                   	10
# R.                  	10
# freundlich          	10
# bleiben             	10
# stellte             	10
# westlichen          	10
# Stufen              	10
# Firnhang            	10
# alte                	10
# trat                	10
# leichter            	10
# Herren              	10
# herum               	10
# 7000                	10
# Spitzen             	10
# klar                	10
# überall             	10
# erscheinen          	10
# mächtige            	10
# Matterhorn          	10
# unmittelbar         	10
# Marsch              	10
# längst              	10
# Ruhe                	10
# sicher              	10
# Roth                	10
# sogar               	10
# km                  	10
# surface             	10
# située              	10
# note                	10
# leurs               	10
# écoulement          	10
# plan                	10
# occasion            	10
# départ              	10
# 269                 	10
# ensemble            	10
# heure               	10
# quelque             	10
# Vue                 	10
# pp                  	10
# seule               	10
# supérieure          	10
# professeur          	10
# 38                  	10
# beaucoup            	10
# forte               	10
# 80                  	10
# 55                  	10
# série               	10
# celles              	10
# voies               	10
# siège               	10
# Autrichiens         	10
# Dr                  	10
# Anglais             	10
# douze               	10
# 6000                	10
# avalanche           	10
# 31                  	10
# cordes              	10
# Polonais            	10
# partant             	10
# zahlreiche          	10
# Reise               	10
# weisse              	10
# Pyramide            	10
# unserm              	10
# Ausrüstung          	10
# Lawinen             	10
# zahlreichen         	10
# Gelegenheit         	10
# Hirten              	10
# Welt                	10
# machten             	10
# vorher              	10
# trafen              	10
# Oberland            	10
# Leute               	10
# äusserst            	10
# traten              	10
# Schnee-             	10
# tritt               	10
# Anderegg            	10
# Nebenstufe          	10
# Eiswand             	10
# Kalk                	10
# Gletscherhorn       	10
# Bäume               	10
# Hochgebirge         	10
# Oberengadin         	10
# Hintergrund         	10
# Ski                 	10
# mêmes               	10
# Bassin              	10
# hinüber             	9
# herauf              	9
# gekommen            	9
# grösser             	9
# Proviant            	9
# überwunden          	9
# Baumann             	9
# neu                 	9
# sogenannte          	9
# Weide               	9
# Mönchjoch           	9
# tiefer              	9
# Gasthof             	9
# zeigte              	9
# dennoch             	9
# Herrn               	9
# Wein                	9
# bestand             	9
# ruhig               	9
# glaube              	9
# überragt            	9
# unterbrochen        	9
# Umweg               	9
# 2.                  	9
# überschritten       	9
# tragen              	9
# unmöglich           	9
# gewinnen            	9
# versuchen           	9
# 1000                	9
# gewaltigen          	9
# Land                	9
# Geist               	9
# 150                 	9
# vergessen           	9
# bequem              	9
# toutes              	9
# glaciaires          	9
# petit               	9
# oriental            	9
# sol                 	9
# font                	9
# trouve              	9
# lors                	9
# moment              	9
# environs            	9
# voit                	9
# Johann              	9
# visite              	9
# XIXe                	9
# ayant               	9
# moyen               	9
# actuelle            	9
# 49                  	9
# Elle                	9
# manière             	9
# laquelle            	9
# Cinq                	9
# fortement           	9
# précédentes         	9
# granite             	9
# troisième           	9
# bloc                	9
# donne               	9
# œuvre               	9
# rapport             	9
# cas                 	9
# mesure              	9
# sens                	9
# 1877                	9
# mars                	9
# 1843                	9
# F.                  	9
# niveau              	9
# atteignant          	9
# destruction         	9
# mort                	9
# aide                	9
# Pass                	9
# neuf                	9
# Première            	9
# atteindre           	9
# Italiens            	9
# fixes               	9
# faisant             	9
# massif              	9
# bleibt              	9
# Menge               	9
# deutsch             	9
# Begleiter           	9
# herab               	9
# Sprache             	9
# Erinnerung          	9
# galt                	9
# eigentlich          	9
# Frühstück           	9
# schauen             	9
# Graubünden          	9
# Schönheit           	9
# Lawine              	9
# Berges              	9
# Anzahl              	9
# beinahe             	9
# Ebene               	9
# Mühe                	9
# Expedition          	9
# Bahn                	9
# gehalten            	9
# bevor               	9
# gehört              	9
# Gewitter            	9
# Spalten             	9
# Berner              	9
# kennen              	9
# Wänden              	9
# engen               	9
# möglichst           	9
# Strählplatten       	9
# Tritte              	9
# Matthews            	9
# Grand               	9
# Formen              	9
# Schritt             	9
# Aufenthalt          	9
# fortwährend         	9
# Stufe               	9
# Art                 	9
# verschiedene        	9
# mitten              	9
# Zacken              	9
# begann              	9
# Karte               	9
# S.A.C.              	9
# Imseng              	9
# Bergspitzen         	9
# Königstein          	9
# Fuße                	9
# 1899                	9
# Kameraden           	9
# mußten              	9
# River               	9
# Manatee             	9
# Blatt               	9
# Koch                	9
# Scanfs              	9
# Mercanton           	9
# générale            	9
# somme               	9
# excès               	9
# pointements         	9
# Canton              	9
# pointement          	9
# herrlichen          	8
# Frau                	8
# Schreckhorn         	8
# bestiegen           	8
# vorwärts            	8
# Steine              	8
# Joch                	8
# nördlich            	8
# Punkte              	8
# Haus                	8
# Dutzend             	8
# Werk                	8
# 1865                	8
# wesentlich          	8
# zerrissenen         	8
# Gefahr              	8
# mächtigen           	8
# Rückweg             	8
# Wolf                	8
# liegende            	8
# schwarze            	8
# südlich             	8
# Partien             	8
# Bruder              	8
# Fernrohr            	8
# v.                  	8
# N.                  	8
# Nachbarn            	8
# nimmt               	8
# hundert             	8
# besteigen           	8
# l'on                	8
# rocheux             	8
# dire                	8
# pieds               	8
# C.Wolf              	8
# régions             	8
# importante          	8
# env                 	8
# médecin             	8
# dessin              	8
# mal                 	8
# Cappeler            	8
# jonction            	8
# bois                	8
# Suisse              	8
# arbres              	8
# 283                 	8
# indications         	8
# position            	8
# me                  	8
# reste               	8
# image               	8
# flanc               	8
# Suisses             	8
# considérable        	8
# Par                 	8
# Franz               	8
# Joseph              	8
# Hugi                	8
# exemple             	8
# chiffres            	8
# 1845                	8
# moderne             	8
# Neuchâtelois        	8
# 1854                	8
# 54                  	8
# étant               	8
# valeurs             	8
# 1980                	8
# longues             	8
# semaines            	8
# doit                	8
# 1844                	8
# Bourckhardt         	8
# Ces                 	8
# personnes           	8
# part                	8
# XVIe                	8
# vingt               	8
# Lausanne            	8
# élevé               	8
# Kangchenjunga       	8
# Broad               	8
# total               	8
# œdème               	8
# sera                	8
# solo                	8
# Pierre              	8
# Yougoslaves         	8
# Français            	8
# outre               	8
# actuellement        	8
# américaine          	8
# Népalais            	8
# danger              	8
# 7400                	8
# W.                  	8
# continué            	8
# gagné               	8
# action              	8
# degré               	8
# quand               	8
# 6500                	8
# fallu               	8
# Expédition          	8
# Yazghil             	8
# John                	8
# Bristen             	8
# Fremden             	8
# Name                	8
# anderer             	8
# diesmal             	8
# Frage               	8
# Wolken              	8
# schöne              	8
# Rasen               	8
# Blumen              	8
# heissen             	8
# wenigen             	8
# Gefährten           	8
# drunten             	8
# namentlich          	8
# könnten             	8
# schmalen            	8
# vollständig         	8
# könne               	8
# Rande               	8
# Rand                	8
# Vieh                	8
# mühsam              	8
# selten              	8
# Wengernalp          	8
# Plan                	8
# unternehmen         	8
# Nachmittags         	8
# brachen             	8
# Pfad                	8
# schönsten           	8
# Feuer               	8
# beschlossen         	8
# Tobel               	8
# starke              	8
# gebraucht           	8
# warten              	8
# ziehen              	8
# erhalten            	8
# Thäler              	8
# fällt               	8
# Fortsetzung         	8
# getrennt            	8
# suchen              	8
# bekannten           	8
# sogenannten         	8
# südlichen           	8
# linken              	8
# glacialis           	8
# dunkeln             	8
# Arten               	8
# Form                	8
# bringt              	8
# ungemein            	8
# Flechten            	8
# Oberhalbstein       	8
# folgende            	8
# westlich            	8
# Laterne             	8
# siebenbürgischen    	8
# Lillooet            	8
# Tower               	8
# Spalte              	8
# Achsel              	8
# F.A.                	8
# 1898                	8
# 1901                	8
# Modification        	8
# 0.5                 	8
# Wort                	7
# Engländer           	7
# drüben              	7
# geblieben           	7
# Bau                 	7
# quer                	7
# Möglichkeit         	7
# halbe               	7
# Mond                	7
# Schwierigkeit       	7
# Abends              	7
# warmen              	7
# liessen             	7
# Rücken              	7
# Bogen               	7
# liegenden           	7
# blauen              	7
# Wallis              	7
# glatten             	7
# reden               	7
# Partie              	7
# ragen               	7
# Gruppe              	7
# 1863                	7
# Verhältniss         	7
# Besuch              	7
# grösseren           	7
# nächste             	7
# gerne               	7
# fehlt               	7
# folgt               	7
# Ausblick            	7
# übrigen             	7
# langten             	7
# sources             	7
# Berne               	7
# endroit             	7
# mes                 	7
# recherche           	7
# Tous                	7
# faible              	7
# rocheuses           	7
# ni                  	7
# nombreux            	7
# c'est-à-dire        	7
# aucune              	7
# voyage              	7
# maintenant          	7
# Ainsi               	7
# torrent             	7
# trouvé              	7
# 70                  	7
# terminale           	7
# gravure             	7
# marche              	7
# recul               	7
# poussée             	7
# présente            	7
# mieux               	7
# onze                	7
# végétation          	7
# trouvait            	7
# avance              	7
# termine             	7
# Escher              	7
# Linth               	7
# presque             	7
# tôt                 	7
# belle               	7
# lobe                	7
# 1829                	7
# 1830                	7
# passé               	7
# annuelle            	7
# conduit             	7
# Zurich              	7
# inférieur           	7
# grandeur            	7
# branche             	7
# faite               	7
# 4.                  	7
# 1879                	7
# devant              	7
# étude               	7
# périodes            	7
# Pendant             	7
# objectifs           	7
# 39                  	7
# 36                  	7
# existe              	7
# serait              	7
# 100                 	7
# retour              	7
# XVIIe               	7
# certain             	7
# occidental          	7
# faut                	7
# K                   	7
# montagnes           	7
# équipement          	7
# morts               	7
# Ascension           	7
# Brakk               	7
# demi-tour           	7
# sommitale           	7
# prise               	7
# alpinistes          	7
# assaut              	7
# quitté              	7
# tandis              	7
# pris                	7
# 7700                	7
# établir             	7
# 7300                	7
# fr                  	7
# gravie              	7
# Voie                	7
# ascensions          	7
# rapide              	7
# V.                  	7
# eux                 	7
# abandonnée          	7
# Albert              	7
# vierge              	7
# 8000                	7
# accumulation        	7
# Sektion             	7
# brachte             	7
# Nachmittag          	7
# Heimat              	7
# Wesen               	7
# kurzer              	7
# Fenster             	7
# höhere              	7
# Kräfte              	7
# brach               	7
# Grund               	7
# Kante               	7
# entfernt            	7
# günstig             	7
# Steinen             	7
# heraus              	7
# sehe                	7
# Grün                	7
# sprechen            	7
# östlich             	7
# Gesteine            	7
# Gepäck              	7
# Platten             	7
# Fast                	7
# Quelle              	7
# Aufmerksamkeit      	7
# einzigen            	7
# Brücke              	7
# Moräne              	7
# Ausnahme            	7
# voll                	7
# Abwechslung         	7
# Gegenden            	7
# nennen              	7
# gelegen             	7
# breiten             	7
# herrlich            	7
# Touristen           	7
# Lauterbrunnen       	7
# jedenfalls          	7
# fing                	7
# Frühe               	7
# Rothen              	7
# Absturz             	7
# passirt             	7
# Kalkstein           	7
# Blöcken             	7
# gelangt             	7
# eigentliche         	7
# Aufgabe             	7
# reichen             	7
# 1856                	7
# erblickten          	7
# steiler             	7
# gleicher            	7
# steilem             	7
# Male                	7
# Antwort             	7
# Eismassen           	7
# suchten             	7
# J                   	7
# Weges               	7
# ähnlich             	7
# Pflanzenwuchs       	7
# fern                	7
# gilt                	7
# bekannte            	7
# Blüthen             	7
# wachsen             	7
# Hochgebirgs         	7
# Geröll              	7
# Freunde             	7
# Bergell             	7
# Marcio              	7
# Eingang             	7
# Duana               	7
# Bergwelt            	7
# Hause               	7
# Dent                	7
# Steigung            	7
# Zinal               	7
# Zelt                	7
# Bulleasee           	7
# bezw                	7
# Fuß                 	7
# rumänische          	7
# Ortschaft           	7
# Paul                	7
# Sirenia             	7
# périodiques         	7
# Forel               	7
# annuelles           	7
# séries              	7
# 1835                	7
# déficit             	7
# moyennes            	7
# 1895                	7
# Orny                	7
# minimum             	7
# Valeur              	7
# Années              	7
# Ferpècle            	7
# Grisons             	7
# hoffen              	6
# unteren             	6
# Wetterhorn          	6
# Bilde               	6
# schritten           	6
# empfehlen           	6
# versehen            	6
# Folge               	6
# alter               	6
# untere              	6
# kurzen              	6
# gewaltige           	6
# Fellenberg          	6
# Wanderer            	6
# Kletterei           	6
# Gebirgsstock        	6
# Neigung             	6
# Ewig-Schneefeld     	6
# Grünhörner          	6
# langer              	6
# trägt               	6
# wenden              	6
# lagen               	6
# Gott                	6
# gebunden            	6
# Heu                 	6
# kalter              	6
# helfen              	6
# wahrscheinlich      	6
# Ohr                 	6
# Sturm               	6
# vielmehr            	6
# folgend             	6
# diess               	6
# schönste            	6
# lauter              	6
# halben              	6
# beste               	6
# allzu               	6
# Beschaffenheit      	6
# bedeutend           	6
# Hitze               	6
# Umgebungen          	6
# nieder              	6
# 1864                	6
# Besteigungen        	6
# Bergstock           	6
# Gewalt              	6
# lagern              	6
# liebliche           	6
# Walliser            	6
# bieten              	6
# Raum                	6
# Kraft               	6
# gehüllt             	6
# rein                	6
# Meister             	6
# gegenüberliegenden  	6
# Links               	6
# volle               	6
# geschützt           	6
# anstrengend         	6
# gestern             	6
# interessanten       	6
# 06.1                	6
# 1774                	6
# origine             	6
# Finsteraar          	6
# recouvert           	6
# importance          	6
# source              	6
# sorte               	6
# ceux                	6
# distance            	6
# reculé              	6
# parties             	6
# 1751                	6
# Beschreibung        	6
# fond                	6
# probable            	6
# sols                	6
# 1890                	6
# permis              	6
# agit                	6
# commencement        	6
# ait                 	6
# fleuve              	6
# impossible          	6
# Wyttenbach          	6
# jusque              	6
# aroles              	6
# 130                 	6
# peut-être           	6
# horizontale         	6
# crevasses           	6
# aucun               	6
# avancé              	6
# précis              	6
# ex                  	6
# telle               	6
# Sidelhorn           	6
# raide               	6
# pentes              	6
# loin                	6
# Birmann             	6
# déplacement         	6
# sujet               	6
# 1839                	6
# collaborateurs      	6
# cet                 	6
# diverses            	6
# 07.1                	6
# Depuis              	6
# second              	6
# Hogard              	6
# 44                  	6
# 53                  	6
# 1880                	6
# immédiatement       	6
# 274                 	6
# groupes             	6
# avais               	6
# lequel              	6
# existence           	6
# 1838                	6
# intérêt             	6
# particulier         	6
# cabane              	6
# 1848                	6
# durant              	6
# descendre           	6
# 35                  	6
# 56                  	6
# 57                  	6
# Elles               	6
# observation         	6
# Collomb             	6
# connu               	6
# gros                	6
# parvenus            	6
# dépit               	6
# Népal               	6
# Hubert              	6
# Spire               	6
# nouveaux            	6
# étrangères          	6
# nouvelles           	6
# vaste               	6
# Ang                 	6
# montée              	6
# mortelle            	6
# Lhotse              	6
# Mme                 	6
# dangers             	6
# ailleurs            	6
# guides              	6
# ensuite             	6
# approche            	6
# culminant           	6
# suivie              	6
# guide               	6
# supérieur           	6
# 6400                	6
# 7100                	6
# établis             	6
# 2000                	6
# échoué              	6
# réussie             	6
# 200                 	6
# 7500                	6
# quinze              	6
# saison              	6
# degrés              	6
# 26.                 	6
# facteur             	6
# générales           	6
# Seiten              	6
# Dinge               	6
# jedes               	6
# Beobachtungen       	6
# 1860                	6
# herüber             	6
# öffnet              	6
# Altdorf             	6
# Flecken             	6
# Glück               	6
# geschehen           	6
# Wiesen              	6
# herunter            	6
# Häuser              	6
# Gras                	6
# Waldes              	6
# starken             	6
# mehreren            	6
# gelegenen           	6
# droben              	6
# schroffen           	6
# Milch               	6
# Eindruck            	6
# Gemsen              	6
# zeigen              	6
# glaubten            	6
# manchmal            	6
# glauben             	6
# Füssen              	6
# Orte                	6
# wählen              	6
# Gedanken            	6
# hauptsächlich       	6
# Sohle               	6
# Blau                	6
# braunen             	6
# Gesellschaft        	6
# Schutt              	6
# Föhn                	6
# gebaut              	6
# Professor           	6
# umgangen            	6
# Sicherheit          	6
# Genuss              	6
# bergab              	6
# Felswänden          	6
# hielten             	6
# Rede                	6
# Händen              	6
# stellenweise        	6
# Photos              	6
# dürfte              	6
# wissen              	6
# Talgrund            	6
# bei'm               	6
# sobald              	6
# Strecke             	6
# Breite              	6
# theilweise          	6
# kahlen              	6
# Schneeflecken       	6
# jungen              	6
# verschwunden        	6
# Wanderung           	6
# Zickzack            	6
# Ecke                	6
# angekommen          	6
# erklimmen           	6
# Schuhe              	6
# obwohl              	6
# fuhr                	6
# wiederum            	6
# festen              	6
# folgten             	6
# fiel                	6
# flachen             	6
# eilten              	6
# Seen                	6
# Stadt               	6
# unterdessen         	6
# vorüber             	6
# Gestalten           	6
# eigentlichen        	6
# Spur                	6
# trifft              	6
# fallen              	6
# alpina              	6
# Ranunculus          	6
# Klima               	6
# Kampf               	6
# dicken              	6
# glänzende           	6
# Berninaspitze       	6
# beobachtet          	6
# häufig              	6
# 1855                	6
# bezeichnet          	6
# nachher             	6
# Jahrbuch            	6
# Avner               	6
# aufzuweisen         	6
# Platta              	6
# Rhein               	6
# Cima                	6
# Thalseite           	6
# 3000                	6
# Ketten              	6
# Bercla              	6
# Mazzerspitz         	6
# wählten             	6
# Bäche               	6
# Madris              	6
# giebt               	6
# Verfügung           	6
# Gegensatz           	6
# 500                 	6
# Blanche             	6
# ersteigen           	6
# gefährlich          	6
# bemerkte            	6
# Ungarn              	6
# Siebenbürgens       	6
# Fogarascher         	6
# Sachsen             	6
# 600                 	6
# Schuler             	6
# Wagen               	6
# Kloster             	6
# indes               	6
# Stenille            	6
# mußte               	6
# 1894                	6
# Freck               	6
# ließ                	6
# Mountain            	6
# Meilen              	6
# Brian               	6
# Bonito              	6
# begaben             	6
# Davos-Platz         	6
# zirka               	6
# Kampagne            	6
# Esen                	6
# Berninahäusern      	6
# P.L.                	6
# Argand              	6
# mon                 	6
# 1826                	6
# phases              	6
# décades             	6
# dernières           	6
# 1893                	6
# 1897                	6
# certaine            	6
# Diablerets          	6
# poteaux             	6
# douteuse            	6
# levé                	6
# Nordouest           	6
# Jahres              	5
# Pläne               	5
# Grindelwaldner      	5
# tüchtige            	5
# Rubi                	5
# Dienste             	5
# Quartier            	5
# Ursache             	5
# zufrieden           	5
# Lawinenschnee       	5
# Ansteigen           	5
# Strahleck           	5
# letztere            	5
# unstreitig          	5
# schwingt            	5
# wilde               	5
# weite               	5
# Strecken            	5
# Kamm                	5
# Bergli              	5
# begleiten           	5
# Glanz               	5
# kühn                	5
# Panorama            	5
# Charakter           	5
# Gletscherwelt       	5
# gewaltiger          	5
# angebracht          	5
# Rückseite           	5
# gefällt             	5
# 1866                	5
# gelegt              	5
# lieben              	5
# Wärme               	5
# herein              	5
# drohte              	5
# Heer                	5
# Dämmerung           	5
# entschlossen        	5
# wobei               	5
# Lust                	5
# zudem               	5
# Linie               	5
# dar                 	5
# Nordseite           	5
# Standpunkt          	5
# breit               	5
# obgleich            	5
# schwierig           	5
# Nr.                 	5
# Schneedecke         	5
# Couloir             	5
# harte               	5
# kannte              	5
# kennt               	5
# senken              	5
# hören               	5
# gearbeitet          	5
# oberste             	5
# Auskunft            	5
# 1862                	5
# Ausläufer           	5
# besucht             	5
# hintere             	5
# hoher               	5
# Alpenwelt           	5
# vollen              	5
# Herz                	5
# Regionen            	5
# Augenblicke         	5
# trennt              	5
# grossartig          	5
# hellen              	5
# ...
# ultérieures         	1
# Bourg-St-Pierre-Hospice	1
# notent              	1
# livret              	1
# ad                  	1
# hoc                 	1
# aisé                	1
# saisissons          	1
# offre               	1
# remercier           	1
# publiquement        	1
# dévoués             	1
# intelligence        	1
# soin                	1
# apportent           	1
# remplir             	1
# fixeront            	1
# embrassent          	1
# laps                	1
# restreint           	1
# sûrement            	1
# sinon               	1
# interprétation      	1
# dissemblances       	1
# tâtonnements        	1
# forcé               	1
# changer             	1
# instant             	1
# détaillés           	1
# suffise             	1
# accusent            	1
# absolu              	1
# Dès                 	1
# relatif             	1
# persistera          	1
# prochaines          	1
# caractère           	1
# constant            	1
# économie            	1
# nivale              	1
# Notons              	1
# profondeur          	1
# 2230                	1
# 4.8                 	1
# perche-balise       	1
# Combe               	1
# Morts               	1
# surveillée          	1
# Francey             	1
# vont                	1
# Camille             	1
# Delessert           	1
# directeur           	1
# postal              	1
# appui               	1
# bienveillant        	1
# décelait            	1
# jour-là             	1
# 2.6                 	1
# 1.6                 	1
# continuées          	1
# Grâce               	1
# obligeance          	1
# Liechti             	1
# ingénieur-chef      	1
# Chemin              	1
# fer                 	1
# XXVIIe              	1
# livrer              	1
# intéressants        	1
# bonheur             	1
# acquis              	1
# corroborent         	1
# Malheureusement     	1
# présumer            	1
# trouverait          	1
# dépassé             	1
# 18.5                	1
# consigner           	1
# encombrant          	1
# déduisent           	1
# 5.5n                	1
# 1.5                 	1
# 3.5                 	1
# baie                	1
# obstruée            	1
# 2.5                 	1
# VIII—15             	1
# VIII—16             	1
# +2                  	1
# +3                  	1
# -4.5                	1
# -2.5                	1
# +1.5                	1
# descendent          	1
# Eigerjoch           	1
# totalise            	1
# 400                 	1
# amplification       	1
# propice             	1
# détaillée           	1
# celles-ci           	1
# sensibilité         	1
# deviennent          	1
# perceptibles        	1
# indiquer            	1
# payé                	1
# inconvénients       	1
# discussion          	1
# tassements          	1
# dus                 	1
# surcharge           	1
# déformer            	1
# grave               	1
# appuie              	1
# redoutable          	1
# concerne            	1
# détacher            	1
# altérer             	1
# signification       	1
# influent            	1
# inférences          	1
# espérions           	1
# tirer               	1
# irrégulier          	1
# risquent            	1
# injustifiées        	1
# dira                	1
# appréhensions       	1
# Conclusion          	1
# précède             	1
# conclure            	1
# faiblement          	1
# catégoriquement     	1
# qualificatif        	1
# emporter            	1
# décideraient        	1
# obser-              	1
# vations             	1
# regression          	1
# arrêtée             	1
# exagération         	1
# attendre            	1
# 1908.               	1
# XCVII               	1
# soins               	1
# personnel           	1
# forestier           	1
# transmises          	1
# Inspection          	1
# ajoutons            	1
# dues                	1
# obligeants          	1
# coopération         	1
# valaisannes         	1
# Fiesch              	1
# 0.6                 	1
# Lötschen            	1
# 1893—1896           	1
# 444                 	1
# Kaltwasser          	1
# Allalin             	1
# 1892—1894           	1
# Gorner              	1
# Zinal463            	1
# Zigiorenove         	1
# 1892—1896           	1
# Désert              	1
# 214                 	1
# Valsorey            	1
# Saleinaz            	1
# 1878—1896.          	1
# Montfort            	1
# lesquels            	1
# mesuré              	1
# 533                 	1
# Mischabel           	1
# 531                 	1
# 535                 	1
# Furgggletscher      	1
# fronts              	1
# Bies                	1
# Schalliberg         	1
# Arben               	1
# Hohwäng             	1
# occupaient          	1
# assigne             	1
# Apparition          	1
# 3516.               	1
# ment                	1
# apparaissait        	1
# précédents          	1
# 3621                	1
# étendues            	1
# homonyme            	1
# Za-de-Zan1          	1
# portion             	1
# abords              	1
# immédiats           	1
# amont               	1
# 3400                	1
# Bouquetin           	1
# septentrional       	1
# 3783                	1
# 3550                	1
# 3636                	1
# prolongement        	1
# Mottarotta          	1
# arkésine            	1
# prolongent          	1
# Roc                 	1
# 3350                	1
# 3570                	1
# Nordest             	1
# Pointe              	1
# Besso               	1
# 3682.               	1
# émerge              	1
# Tracuit             	1
# 3900                	1
# Nordnordest         	1
# perce               	1
# nordouest           	1
# Biesgletscher       	1
# 3549                	1
# occupe              	1
# recessus            	1
# Freiwänge           	1
# montraient          	1
# petits              	1
# Sudsudouest         	1
# Gabelhorngletscher  	1
# Actuellement        	1
# forment             	1
# Tête                	1
# mises               	1
# composés            	1
# Sudest              	1
# nordest             	1
# nouvellement        	1
# commencconstruire   	1
# venait              	1
# réunir              	1
# apporter            	1
# appoint             	1
# inclinées           	1
# existent            	1
# résumé              	1
# Evêque              	1
# désigné             	1
# séparation          	1
# touriste            	1
# habitué             	1
# affirmé             	1
# 1904.               	1
# riveraine           	1
# séparée             	1
# vivant              	1
# Bouquetins          	1
# 3097                	1
# latéral             	1
# Aujourd'hui         	1
# touche              	1
# 2170                	1
# refouler            	1
# associé             	1
# prépondérance       	1
# rejeter             	1
# barrant             	1
# issu                	1
# borde               	1
# Affluents           	1
# Nordnordouest       	1
# descend             	1
# projette            	1
# rejoindre           	1
# commencdifier       	1
# Varia               	1
# voyait              	1
# transverse          	1
# Quermoräne          	1
# uniquement          	1
# gabbros             	1
# gabbro-amphibolites 	1
# aplites             	1
# voisines            	1
# roches              	1
# complexe            	1
# retirant            	1
# lustrés             	1
# serpentine          	1
# Kleinere            	1
# Mitteilungen        	1

# %%
#output all dependencies so that we can reproduce the notebook (we only need this to set things up for Binder)
# %load_ext watermark
# %watermark --iversions

# %%
def tf(text):
    doc = nlp(text)
    n = len(doc)
    
    terms = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct ]
    tf = dict(Counter(terms))
    
    for term, count in tf.items():
        tf[term] = count/n
        
    return tf

# %%
import math
def df(texts):
    df = dict()
    ndocs = len(texts)
    for text in texts:
        print(text)
        doc = nlp(text)
        terms = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct ]
        tf = set(terms)
        for t in tf:
            if t in df:
                count = df[t]
                count = count + 1
            else:
                count = 1
            df[t] = count/ndocs
    for term, count in df.items():
        df[term] = math.log10(ndocs/(count + 1))

    return df

# %%
def tfidf(corpus):
    print(corpus)
    print(list(corpus.values()))
    idf = df(list(corpus.values()))
    results = {}
    for id, text in corpus.items():                
        t = tf(text)
        scores = {}
        for term in t:
            scores[term] = t[term]*idf[term]
        results[id] = scores
    return results

# %%
def simpleSearch(query, weights):
    q = nlp(query)
    
    #Iterate through each document and add its tf-idf score
    results = {}
    for id, scores in weights.items():
        score = 0
        for token in q:
            if token.lemma_ in scores:
                score = score + scores[token.lemma_]
        results[id] = score
    return results

# %%
tf("This is an experiment with words that happen more than once once words")
df(["This is an experiment with words that happen more than once once words","Words that once", "than experiment new other once"])
tfidf({1:"This is an experiment with words that happen more than once once words",2:"Words that once",3:"than experiment new other once"})

corpus = {1:"the cat sat on the mat",
          2:"the dog played with the cat",
          3:"the cat bit the dog",
          4:"the boy bit the dog",
          5:"the girl saw the boy far away"}
weights = tfidf(corpus)
results = simpleSearch('cat dog', weights)
print(results)
# Out:
# ['This', 'is', 'experiment', 'with', 'words', 'that', 'happen', 'more', 'than', 'once', 'once', 'words']
# {'This': 1, 'is': 1, 'experiment': 1, 'with': 1, 'words': 2, 'that': 1, 'happen': 1, 'more': 1, 'than': 1, 'once': 2}
# This is an experiment with words that happen more than once once words
# Words that once
# than experiment new other once
# {1: 'This is an experiment with words that happen more than once once words', 2: 'Words that once', 3: 'than experiment new other once'}
# ['This is an experiment with words that happen more than once once words', 'Words that once', 'than experiment new other once']
# This is an experiment with words that happen more than once once words
# Words that once
# than experiment new other once
# {'once': 0.30642502755068735, 'is': 0.3521825181113625, 'more': 0.3521825181113625, 'happen': 0.3521825181113625, 'with': 0.3521825181113625, 'that': 0.3174204118521506, 'words': 0.3521825181113625, 'than': 0.3174204118521506, 'This': 0.3521825181113625, 'experiment': 0.3174204118521506, 'Words': 0.3521825181113625, 'new': 0.3521825181113625, 'other': 0.3521825181113625}
# ['This', 'is', 'experiment', 'with', 'words', 'that', 'happen', 'more', 'than', 'once', 'once', 'words']
# {'This': 1, 'is': 1, 'experiment': 1, 'with': 1, 'words': 2, 'that': 1, 'happen': 1, 'more': 1, 'than': 1, 'once': 2}
# 0.07692307692307693 0.3521825181113625 This 0.02709096293164327
# 0.07692307692307693 0.3521825181113625 is 0.02709096293164327
# 0.07692307692307693 0.3174204118521506 experiment 0.02441695475785774
# 0.07692307692307693 0.3521825181113625 with 0.02709096293164327
# 0.15384615384615385 0.3521825181113625 words 0.05418192586328654
# 0.07692307692307693 0.3174204118521506 that 0.02441695475785774
# 0.07692307692307693 0.3521825181113625 happen 0.02709096293164327
# 0.07692307692307693 0.3521825181113625 more 0.02709096293164327
# 0.07692307692307693 0.3174204118521506 than 0.02441695475785774
# 0.15384615384615385 0.30642502755068735 once 0.04714231193087498
# ['Words', 'that', 'once']
# {'Words': 1, 'that': 1, 'once': 1}
# 0.3333333333333333 0.3521825181113625 Words 0.11739417270378749
# 0.3333333333333333 0.3174204118521506 that 0.10580680395071686
# 0.3333333333333333 0.30642502755068735 once 0.10214167585022911
# ['than', 'experiment', 'new', 'other', 'once']
# {'than': 1, 'experiment': 1, 'new': 1, 'other': 1, 'once': 1}
# 0.2 0.3174204118521506 than 0.06348408237043011
# 0.2 0.3174204118521506 experiment 0.06348408237043011
# 0.2 0.3521825181113625 new 0.0704365036222725
# 0.2 0.3521825181113625 other 0.0704365036222725
# 0.2 0.30642502755068735 once 0.06128500551013747
# {1: 'the cat sat on the mat', 2: 'the dog played with the cat', 3: 'the cat bit the dog', 4: 'the boy bit the dog', 5: 'the girl saw the boy far away'}
# ['the cat sat on the mat', 'the dog played with the cat', 'the cat bit the dog', 'the boy bit the dog', 'the girl saw the boy far away']
# the cat sat on the mat
# the dog played with the cat
# the cat bit the dog
# the boy bit the dog
# the girl saw the boy far away
# {'cat': 0.6027554189896136, 'mat': 0.619788758288394, 'the': 0.6020877870642773, 'on': 0.619788758288394, 'sat': 0.619788758288394, 'played': 0.619788758288394, 'with': 0.619788758288394, 'dog': 0.6027554189896136, 'bit': 0.6055483191737837, 'boy': 0.6055483191737837, 'far': 0.619788758288394, 'away': 0.619788758288394, 'girl': 0.619788758288394, 'saw': 0.619788758288394}
# ['the', 'cat', 'sat', 'on', 'the', 'mat']
# {'the': 2, 'cat': 1, 'sat': 1, 'on': 1, 'mat': 1}
# 0.3333333333333333 0.6020877870642773 the 0.20069592902142577
# 0.16666666666666666 0.6027554189896136 cat 0.10045923649826893
# 0.16666666666666666 0.619788758288394 sat 0.10329812638139899
# 0.16666666666666666 0.619788758288394 on 0.10329812638139899
# 0.16666666666666666 0.619788758288394 mat 0.10329812638139899
# ['the', 'dog', 'played', 'with', 'the', 'cat']
# {'the': 2, 'dog': 1, 'played': 1, 'with': 1, 'cat': 1}
# 0.3333333333333333 0.6020877870642773 the 0.20069592902142577
# 0.16666666666666666 0.6027554189896136 dog 0.10045923649826893
# 0.16666666666666666 0.619788758288394 played 0.10329812638139899
# 0.16666666666666666 0.619788758288394 with 0.10329812638139899
# 0.16666666666666666 0.6027554189896136 cat 0.10045923649826893
# ['the', 'cat', 'bit', 'the', 'dog']
# {'the': 2, 'cat': 1, 'bit': 1, 'dog': 1}
# 0.4 0.6020877870642773 the 0.24083511482571096
# 0.2 0.6027554189896136 cat 0.12055108379792273
# 0.2 0.6055483191737837 bit 0.12110966383475674
# 0.2 0.6027554189896136 dog 0.12055108379792273
# ['the', 'boy', 'bit', 'the', 'dog']
# {'the': 2, 'boy': 1, 'bit': 1, 'dog': 1}
# 0.4 0.6020877870642773 the 0.24083511482571096
# 0.2 0.6055483191737837 boy 0.12110966383475674
# 0.2 0.6055483191737837 bit 0.12110966383475674
# 0.2 0.6027554189896136 dog 0.12055108379792273
# ['the', 'girl', 'saw', 'the', 'boy', 'far', 'away']
# {'the': 2, 'girl': 1, 'saw': 1, 'boy': 1, 'far': 1, 'away': 1}
# 0.2857142857142857 0.6020877870642773 the 0.17202508201836494
# 0.14285714285714285 0.619788758288394 girl 0.08854125118405627
# 0.14285714285714285 0.619788758288394 saw 0.08854125118405627
# 0.14285714285714285 0.6055483191737837 boy 0.08650690273911195
# 0.14285714285714285 0.619788758288394 far 0.08854125118405627
# 0.14285714285714285 0.619788758288394 away 0.08854125118405627
# {1: 0.10045923649826893, 2: 0.20091847299653787, 3: 0.24110216759584546, 4: 0.12055108379792273, 5: 0}
