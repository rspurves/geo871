# %% [markdown]
# ## Introduction
#
# This notebook illustrates how we can use NER to search for placenames in a corpus, and enhance a gazetteer. It uses two datesets to illustrate the concepts.
#
# 1) [Geograph](https://geograph.org.uk)
# This site invites users to take pictures in the UK and add descriptions. It has almost 7 million pictures, and the data are licenced using a CC By-SA licence, making them available for research as long as we keep the names of the users, and allow others to have access to any data we might create.
#
# 2) [Ordnance Survey](https://ordnancesurvey.co.uk/) 50k gazetteer
# This gazetteer was published under a UK Open Government licence and contains all place name found on 1:50k maps in the UK. It is a legacy product (i.e. not used or updated any more), but it is suitable for our purposes.
#
# We are going to look for names found in the Geograph data that don't exist in the gazetteer. Since we know that many names occur multiple times, we will do this locally, to increase the chances that we really find new names.
#
# **The first block of our code reads in data and builds a simple spatial index for the gazetteer. We only need to do this once.**

# %%
import OSGridConverter #To convert from =SGB36 to WGS84
import pandas as pd #To use pandas for elegant data handling
import spacy #Our NLP tools
import matplotlib.pyplot as plt #To plot results

#Load a language model to do NLP
nlp = spacy.load("en_core_web_sm")

# %%
#First we read in the geograph data
geograph = pd.read_csv('./data/geograph_mini_corpus.csv', encoding='latin-1')
print(len(geograph))
geograph.head()
# Out:
# 138639
#         id          author                             title  \
# 0  2749148  M J Richardson       Great Blasket Island - 1960
# 1   635105      Bob Shires         White Beach Great Blasket
# 2   635109      Bob Shires  Remaining homes on Great Blasket
# 3   259349       Nigel Cox                   Coumeenoole Bay
# 4    16917      Pam Brophy                     Clogher Beach
#
#                                                 text        lon        lat
# 0  Looking northeast along the northwestern side ... -10.534101  52.097794
# 1  The only beach on Great Blasket as seen from t... -10.514872  52.107609
# 2  The remaining few habited homes of the abandon... -10.511764  52.104260
# 3  Viewed looking back from the Dunmore Head head... -10.463579  52.109322
# 4  The exact gpr for this beach is Q3153003375. T... -10.463338  52.157867

# %% [markdown]
# This block demonstrates the NLP results for a single Geograph document. We use the entities later as potential toponyms.

# %% [markdown]
# Here we **draw a sample of documents** from the Geograph data and perform NER on those data.
#
# The sample can either be random, or we can define a search term and extract all records containg that term.
#
# We can rerun this block to build a new sample. The size of this sample can also be changed.

# %%
list = {}
elements = set(pd.read_csv('./data/elements.txt', header=None)[0])
qualities = set(pd.read_csv('./data/qualities.txt', header=None)[0])
activities = set(pd.read_csv('./data/activities.txt', header=None)[0])

terms = elements.union(qualities).union(activities)
lemmas = ' '.join(str(e) for e in terms)


doc = nlp(lemmas)
terms = set()
for token in doc:
    terms.add(token.lemma_)
terms
# Out:
# {'abandon',
#  'abbey',
#  'abstract',
#  'air',
#  'aircraft',
#  'airshow',
#  'allotment',
#  'ancient',
#  'animal',
#  'anniversary',
#  'apple',
#  'aquarium',
#  'arch',
#  'architecture',
#  'arena',
#  'art',
#  'autumn',
#  'baby',
#  'badge',
#  'ball',
#  'balloon',
#  'band',
#  'bands',
#  'bank',
#  'bar',
#  'barbecue',
#  'bay',
#  'bbq',
#  'beach',
#  'beautiful',
#  'beauty',
#  'bedroom',
#  'beer',
#  'bell',
#  'bench',
#  'bicycle',
#  'big',
#  'bike',
#  'bird',
#  'birthday',
#  'black',
#  'blue',
#  'boat',
#  'bonfire',
#  'book',
#  'botanical',
#  'box',
#  'boy',
#  'brick',
#  'bridge',
#  'brown',
#  'building',
#  'bus',
#  'butterfly',
#  'cafe',
#  'cake',
#  'camping',
#  'campus',
#  'canal',
#  'candid',
#  'capital',
#  'car',
#  'carnival',
#  'carpark',
#  'castle',
#  'cat',
#  'cathedral',
#  'ceiling',
#  'celebration',
#  'cemetary',
#  'cemetery',
#  'centre',
#  'chapel',
#  'cheese',
#  'chimney',
#  'chocolate',
#  'christmas',
#  'christmasparty',
#  'church',
#  'churchyard',
#  'cinema',
#  'city',
#  'cityscape',
#  'climb',
#  'clock',
#  'cloud',
#  'club',
#  'coast',
#  'cold',
#  'college',
#  'color',
#  'colour',
#  'competition',
#  'concert',
#  'concrete',
#  'conference',
#  'construction',
#  'costume',
#  'country',
#  'countryside',
#  'court',
#  'cow',
#  'crane',
#  'cricket',
#  'cross',
#  'crowd',
#  'culture',
#  'cup',
#  'cupfinal',
#  'cute',
#  'cycle',
#  'cycling',
#  'dance',
#  'dancing',
#  'dark',
#  'dawn',
#  'day',
#  'dayout',
#  'dead',
#  'decay',
#  'demolition',
#  'demonstration',
#  'derelict',
#  'design',
#  'dinner',
#  'disco',
#  'dock',
#  'dog',
#  'door',
#  'drama',
#  'dress',
#  'drink',
#  'drive',
#  'drum',
#  'drunk',
#  'duck',
#  'ducks',
#  'dusk',
#  'easter',
#  'elephant',
#  'engine',
#  'estate',
#  'evening',
#  'event',
#  'exhibition',
#  'experimental',
#  'explore',
#  'eye',
#  'face',
#  'factory',
#  'fair',
#  'farm',
#  'fashion',
#  'fauna',
#  'fence',
#  'ferry',
#  'festival',
#  'field',
#  'fiesta',
#  'film',
#  'final',
#  'fire',
#  'firework',
#  'fish',
#  'flag',
#  'flat',
#  'flood',
#  'flora',
#  'flower',
#  'fog',
#  'folk',
#  'food',
#  'football',
#  'forest',
#  'fountain',
#  'friend',
#  'fringe',
#  'frost',
#  'fruit',
#  'fun',
#  'gallery',
#  'game',
#  'garage',
#  'garden',
#  'gate',
#  'gay',
#  'gig',
#  'girl',
#  'glass',
#  'gold',
#  'golf',
#  'gothic',
#  'graduation',
#  'graffiti',
#  'grafitti',
#  'grass',
#  'grave',
#  'gravestone',
#  'graveyard',
#  'great',
#  'green',
#  'grey',
#  'guy',
#  'hall',
#  'halloween',
#  'hand',
#  'happy',
#  'harbour',
#  'hat',
#  'heritage',
#  'hike',
#  'hill',
#  'hills',
#  'historic',
#  'history',
#  'holiday',
#  'home',
#  'honeymoon',
#  'horse',
#  'hospital',
#  'hostel',
#  'hot',
#  'hotel',
#  'house',
#  'ice',
#  'industrial',
#  'industry',
#  'insect',
#  'interior',
#  'international',
#  'island',
#  'jazz',
#  'kid',
#  'kitchen',
#  'lake',
#  'lamp',
#  'landscape',
#  'lane',
#  'leaf',
#  'leave',
#  'library',
#  'light',
#  'lighthouse',
#  'lighting',
#  'line',
#  'lion',
#  'livemusic',
#  'loch',
#  'lock',
#  'long',
#  'love',
#  'lunch',
#  'male',
#  'man',
#  'marathon',
#  'market',
#  'match',
#  'meal',
#  'medieval',
#  'medium',
#  'memorial',
#  'metal',
#  'metro',
#  'military',
#  'mill',
#  'mirror',
#  'mist',
#  'model',
#  'modern',
#  'monument',
#  'moon',
#  'morning',
#  'motion',
#  'motor',
#  'motorbike',
#  'motorcycle',
#  'motorsport',
#  'mountain',
#  'mud',
#  'mural',
#  'museum',
#  'music',
#  'musician',
#  'nature',
#  'new',
#  'newyear',
#  'newyearseve',
#  'night',
#  'nightclub',
#  'nightglow',
#  'office',
#  'old',
#  'open',
#  'orange',
#  'outdoor',
#  'outdoors',
#  'outside',
#  'paint',
#  'palace',
#  'panorama',
#  'parade',
#  'park',
#  'party',
#  'path',
#  'pavement',
#  'peace',
#  'people',
#  'performance',
#  'pier',
#  'pink',
#  'pirate',
#  'plane',
#  'plant',
#  'plants',
#  'platform',
#  'play',
#  'police',
#  'pond',
#  'pool',
#  'poster',
#  'power',
#  'pride',
#  'protest',
#  'pub',
#  'public',
#  'punk',
#  'purple',
#  'race',
#  'racing',
#  'rail',
#  'railroad',
#  'railway',
#  'rain',
#  'rainbow',
#  'random',
#  'raw',
#  'read',
#  'reception',
#  'red',
#  'reflection',
#  'religion',
#  'restaurant',
#  'retro',
#  'rise',
#  'river',
#  'road',
#  'robin',
#  'rock',
#  'roman',
#  'roof',
#  'room',
#  'royal',
#  'rugby',
#  'ruin',
#  'run',
#  'rural',
#  'rust',
#  'safe',
#  'sailing',
#  'sand',
#  'scenery',
#  'school',
#  'science',
#  'sculpture',
#  'sea',
#  'seafront',
#  'seaside',
#  'sexy',
#  'shadow',
#  'sheep',
#  'ship',
#  'shop',
#  'shopping',
#  'show',
#  'sign',
#  'silhouette',
#  'silver',
#  'singer',
#  'skate',
#  'skating',
#  'sky',
#  'skyline',
#  'skyscraper',
#  'slide',
#  'smile',
#  'smoke',
#  'snow',
#  'soccer',
#  'social',
#  'soul',
#  'spire',
#  'sport',
#  'spring',
#  'square',
#  'squirrel',
#  'stadium',
#  'stage',
#  'stainedglass',
#  'stair',
#  'star',
#  'station',
#  'statue',
#  'steam',
#  'steel',
#  'stencil',
#  'step',
#  'stone',
#  'store',
#  'storm',
#  'street',
#  'streetart',
#  'student',
#  'studio',
#  'summer',
#  'sun',
#  'sunlight',
#  'sunny',
#  'sunrise',
#  'sunset',
#  'sunshine',
#  'swan',
#  'swans',
#  'table',
#  'team',
#  'temple',
#  'terrace',
#  'texture',
#  'theatre',
#  'tile',
#  'tomb',
#  'tour',
#  'tourist',
#  'tower',
#  'town',
#  'toy',
#  'track',
#  'traffic',
#  'train',
#  'training',
#  'transport',
#  'travel',
#  'tree',
#  'trip',
#  'tunnel',
#  'underground',
#  'uni',
#  'university',
#  'urban',
#  'vacation',
#  'van',
#  'victorian',
#  'view',
#  'village',
#  'vintage',
#  'wakeboarde',
#  'walk',
#  'wall',
#  'war',
#  'water',
#  'waterfall',
#  'wave',
#  'way',
#  'weather',
#  'wedding',
#  'weekend',
#  'wet',
#  'wharf',
#  'wheel',
#  'white',
#  'wild',
#  'wildlife',
#  'window',
#  'windows',
#  'wine',
#  'winter',
#  'woman',
#  'wood',
#  'work',
#  'xmas',
#  'yellow',
#  'youth',
#  'yuck',
#  'zoo'}

# %%
m = 200
#sample = geograph.sample(n = m)
sample = geograph

# Create a postings list for our geograph documents
docs = nlp.pipe(sample.text,n_process=2, batch_size=100)

postings = dict()

for (idxRow, s1), (_, s2) in zip(sample.iterrows(), enumerate(docs)):
    id = s1.id
    for token in s2:
        lemma = token.lemma_
        if lemma in terms:

            if lemma in postings:
                tf = postings[lemma]
                if id in tf:
                    tf[id] = tf[id] + 1
                else:
                    tf[id] = 1
            else:
                tf = {id: 1}
                postings[lemma] = tf

# %%
postings
# Out:
# {'snow': {1203374: 1, 102744: 1},
#  'hill': {1203374: 1,
#   2775373: 1,
#   2448095: 1,
#   2687310: 1,
#   171444: 1,
#   553558: 1,
#   253969: 1,
#   163112: 1,
#   419094: 1,
#   1202223: 1,
#   842621: 1,
#   1811432: 1,
#   3229081: 1,
#   2102948: 1,
#   899000: 1,
#   793536: 1,
#   830891: 1,
#   1122298: 1,
#   1826936: 1,
#   1213712: 1,
#   812409: 1,
#   284432: 1,
#   1302840: 1,
#   102001: 1,
#   2068375: 1,
#   2451792: 1,
#   560002: 1},
#  'church': {3308050: 1,
#   2698850: 1,
#   1952219: 1,
#   588500: 1,
#   1071076: 1,
#   1089738: 1,
#   291236: 1,
#   812409: 1,
#   3094573: 1,
#   320666: 1,
#   838139: 1},
#  'rise': {3308050: 1, 1122298: 1},
#  'village': {3308050: 1,
#   3168093: 1,
#   2687310: 1,
#   1955371: 1,
#   1066741: 1,
#   588500: 1,
#   1163715: 1,
#   857590: 1,
#   1678386: 1,
#   1071076: 1,
#   3194993: 1,
#   186709: 1,
#   846475: 1,
#   651707: 1,
#   2868095: 1,
#   2935790: 1,
#   187805: 1,
#   291236: 1,
#   2990392: 1,
#   3063890: 1,
#   1213712: 1,
#   173362: 1,
#   812409: 1,
#   633057: 2,
#   500079: 1,
#   1132846: 1,
#   47331: 1,
#   924059: 1,
#   3094573: 2,
#   352648: 1,
#   253422: 1,
#   522988: 2,
#   1996844: 1,
#   102001: 1,
#   2451792: 1,
#   838139: 1},
#  'forest': {391703: 1,
#   1008541: 1,
#   3288041: 1,
#   353572: 2,
#   1180873: 1,
#   2695370: 1,
#   1185753: 1,
#   1145597: 1,
#   1941763: 1,
#   540855: 1,
#   1786123: 1},
#  'track': {391703: 1,
#   2698850: 1,
#   1837156: 1,
#   607570: 1,
#   2617832: 1,
#   681111: 1,
#   1826936: 1,
#   839767: 1,
#   400183: 1},
#  'tree': {3168093: 1,
#   2698850: 1,
#   1088325: 1,
#   2250937: 1,
#   2259916: 1,
#   1609418: 1,
#   151749: 1,
#   2414597: 1,
#   1581713: 1,
#   2927821: 1,
#   1837156: 1,
#   460693: 1,
#   345085: 1,
#   1883903: 1,
#   792386: 1,
#   71775: 2,
#   67939: 1,
#   2695370: 1,
#   3229081: 1,
#   1036613: 1,
#   3311041: 1,
#   410655: 1,
#   1185753: 1,
#   812409: 1,
#   1148170: 1,
#   244187: 2,
#   1009471: 1,
#   1319292: 1,
#   2627867: 1,
#   2329225: 1,
#   1927302: 1,
#   3048654: 1,
#   2523724: 1,
#   148129: 1,
#   2763630: 1,
#   445392: 1,
#   102744: 1,
#   2964367: 1,
#   869946: 2,
#   1952233: 1,
#   930166: 1,
#   560729: 1,
#   1979563: 1,
#   2698979: 1},
#  'graveyard': {3168093: 1},
#  'road': {2775373: 1,
#   2687310: 2,
#   423735: 1,
#   1955371: 1,
#   163566: 1,
#   2802884: 1,
#   2437083: 1,
#   695474: 1,
#   1581713: 1,
#   2927821: 1,
#   588500: 1,
#   1163715: 1,
#   1857800: 2,
#   902138: 1,
#   846475: 1,
#   2990392: 1,
#   1283611: 1,
#   2338518: 2,
#   3027333: 1,
#   2329225: 1,
#   2707307: 1,
#   540855: 1,
#   2763630: 2,
#   445392: 1,
#   522988: 1,
#   64330: 1,
#   1786123: 1,
#   2451792: 1,
#   2698979: 1},
#  'sign': {2775373: 1,
#   2802884: 1,
#   3027333: 1,
#   3094573: 1,
#   445392: 1,
#   522988: 2,
#   642745: 1},
#  'bridge': {1008541: 1,
#   2687310: 1,
#   2802884: 1,
#   695474: 1,
#   2338518: 1,
#   410036: 1,
#   352648: 1},
#  'long': {1008541: 1, 545891: 1},
#  'field': {2448095: 1,
#   163566: 1,
#   1180873: 1,
#   970610: 1,
#   899000: 1,
#   187805: 1,
#   1446327: 1,
#   2801118: 1,
#   64330: 1,
#   1979563: 1,
#   2569488: 1},
#  'farm': {2448095: 1,
#   2698850: 1,
#   163566: 1,
#   545891: 1,
#   1180786: 1,
#   2102948: 1,
#   899000: 1,
#   291236: 1,
#   1145475: 1,
#   2627867: 1,
#   2839472: 1},
#  'railway': {2687310: 1,
#   1948533: 1,
#   1446327: 1,
#   1319292: 1,
#   1132846: 1,
#   3048654: 1,
#   560002: 1},
#  'station': {2687310: 2, 2250937: 3, 2726050: 1, 1319292: 1, 3109291: 1},
#  'path': {2698850: 1,
#   2259916: 1,
#   2617832: 1,
#   1948533: 1,
#   3311041: 1,
#   2707307: 1,
#   1509478: 1,
#   644147: 2},
#  'tower': {2698850: 1, 2559910: 1, 838139: 1},
#  'show': {2698850: 1, 1581713: 1, 545891: 1, 1857800: 1, 842621: 1, 445392: 1},
#  'centre': {2698850: 1,
#   2848756: 1,
#   1163715: 1,
#   2808164: 1,
#   1125967: 1,
#   15728: 1,
#   320666: 1,
#   1509478: 1,
#   1996844: 1,
#   2068375: 1,
#   2451792: 1},
#  'modern': {1088325: 1},
#  'sculpture': {1088325: 1, 548504: 1},
#  'country': {423735: 1},
#  'town': {1952219: 1,
#   2848756: 1,
#   994126: 1,
#   1089738: 1,
#   1026143: 1,
#   2050582: 1,
#   1283611: 1,
#   1125967: 1,
#   599270: 1,
#   2755849: 1,
#   548504: 1,
#   320666: 1,
#   1992154: 1,
#   2191021: 1},
#  'factory': {1952219: 1},
#  'rock': {100917: 1},
#  'face': {100917: 1, 175994: 1},
#  'steam': {2250937: 1},
#  'gate': {2250937: 1},
#  'view': {2250937: 1,
#   3288041: 1,
#   1682503: 1,
#   345085: 1,
#   545891: 1,
#   1857800: 1,
#   1883903: 1,
#   1563859: 1,
#   2695370: 2,
#   2102948: 1,
#   410655: 1,
#   1089738: 2,
#   1026143: 1,
#   641999: 1,
#   3063890: 1,
#   1213712: 1,
#   1201050: 1,
#   2755849: 1,
#   3300942: 1,
#   1319292: 1,
#   753938: 2,
#   2839472: 1,
#   2329225: 1,
#   47331: 1,
#   540855: 1,
#   1509478: 1,
#   1786123: 1,
#   2068375: 1,
#   2191021: 1},
#  'building': {2250937: 1, 163566: 1, 1180786: 1, 3252905: 1, 633057: 1},
#  'public': {2250937: 1, 1581713: 1, 452192: 1, 560729: 1},
#  'car': {2259916: 1, 71775: 1},
#  'park': {2259916: 1},
#  'river': {2259916: 1, 186709: 1, 691480: 2, 2530860: 1},
#  'square': {142516: 1,
#   2102948: 1,
#   1826936: 1,
#   15728: 1,
#   633057: 1,
#   540855: 1,
#   253422: 1},
#  'open': {142516: 1, 353572: 1, 244187: 1, 3300942: 1, 1319292: 1},
#  'fence': {3288041: 1, 353572: 1, 1039250: 1},
#  'cross': {2726050: 1, 2802884: 1, 1163715: 1, 644147: 1},
#  'new': {2726050: 1, 1678386: 1, 1446327: 1, 1996844: 1},
#  'red': {163566: 2},
#  'wet': {2802884: 1},
#  'skyline': {163112: 1, 792386: 1},
#  'dead': {2437083: 1},
#  'lane': {2437083: 1, 1066741: 1, 566023: 1, 2801118: 1, 1148170: 1},
#  'pub': {1066741: 1},
#  'way': {175994: 1, 1180786: 1, 452192: 1, 102744: 1},
#  'walk': {2414597: 1, 1678386: 1, 452192: 1, 2763630: 1, 2964367: 1},
#  'office': {994126: 1},
#  'run': {1581713: 1,
#   899000: 1,
#   681111: 1,
#   2755849: 1,
#   1319292: 1,
#   2707307: 1,
#   2698979: 1},
#  'leave': {1581713: 1,
#   2927821: 1,
#   1558646: 1,
#   839767: 1,
#   410036: 1,
#   1509478: 1},
#  'stone': {460693: 1, 2102948: 1},
#  'line': {460693: 1,
#   1948533: 1,
#   2695370: 1,
#   3311041: 1,
#   1446327: 1,
#   1009471: 1,
#   1319292: 1,
#   930166: 1},
#  'house': {530702: 1,
#   2935790: 1,
#   1125967: 1,
#   2382712: 1,
#   173362: 1,
#   448813: 1},
#  'mill': {2336009: 1},
#  'lake': {1678386: 2},
#  'wood': {545891: 1, 452192: 1, 1302840: 1},
#  'art': {1071076: 1},
#  'exhibition': {1071076: 1},
#  'sea': {186709: 1, 1089738: 1, 540855: 1, 1723572: 1},
#  'vintage': {902138: 1},
#  'day': {71775: 1, 1089738: 1},
#  'morning': {67939: 1},
#  'clock': {2559910: 1},
#  'stage': {2695370: 1},
#  'cycle': {2695370: 1, 937965: 1},
#  'plant': {3229081: 1, 244187: 1},
#  'construction': {2102948: 1},
#  'mountain': {459938: 1, 1201050: 1, 706879: 1, 437230: 1},
#  'wall': {3252905: 1,
#   1089738: 1,
#   2801118: 2,
#   2755849: 1,
#   1039250: 1,
#   642745: 1},
#  'box': {3252905: 1},
#  'pier': {1089738: 1},
#  'summer': {1089738: 1},
#  'winter': {1089738: 1, 2763630: 1},
#  'hall': {2935790: 1},
#  'estate': {187805: 1, 1446327: 1, 1826936: 1},
#  'drive': {1026143: 1},
#  'old': {1283611: 1, 930166: 1},
#  'arena': {691480: 1},
#  'water': {1125967: 1},
#  'work': {1122298: 1},
#  'ruin': {2382712: 1, 1723572: 1},
#  'door': {599270: 1},
#  'industry': {599270: 1},
#  'medieval': {2755849: 1},
#  'street': {633057: 1, 320666: 1},
#  'terrace': {448813: 1},
#  'sunny': {3300942: 1, 2763630: 1},
#  'cold': {3300942: 1},
#  'frost': {3300942: 1},
#  'industrial': {548504: 1},
#  'yellow': {2627867: 1},
#  'great': {753938: 1},
#  'train': {1132846: 1},
#  'sheep': {437385: 1},
#  'home': {924059: 1},
#  'cricket': {924059: 1},
#  'green': {924059: 1, 540855: 1},
#  'game': {924059: 1},
#  'play': {924059: 1},
#  'allotment': {1039250: 1},
#  'flower': {540855: 1},
#  'traffic': {2763630: 1},
#  'holiday': {253422: 1},
#  'roof': {1302840: 1},
#  'ancient': {445392: 1},
#  'blue': {445392: 1, 102744: 1},
#  'people': {2964367: 1},
#  'school': {522988: 1, 1996844: 1},
#  'wildlife': {869946: 1},
#  'pond': {869946: 1},
#  'bird': {560729: 1},
#  'flood': {560002: 1},
#  'pool': {644147: 1},
#  'flat': {644147: 1},
#  'climb': {644147: 1},
#  'city': {642745: 1}}

# %% [markdown]
# This block of code does the comparisons. It iterates through all the Geograph documents and does the following:
#
# - For each document it returns all the toponyms in the gazetteer cell at that location
# - Compares each name found by the NER to the list of toponyms in the gazetteer cell, and
# - Annotates the names as either existing (found in the gazetteer) or new (new names)
#
# If we change the sample of names, or the resolution of the gazetteer, then the results of the following **comparison** should change.

# %%
#Now we are going to compare the gazetteer names with those we found

data = list()
#We iterate through all our results
for dict in results:
    #First we get the cell indices for the gazetteer
    x = dict.get("x")
    y = dict.get("y")
    i = int((x - minx)/cellSize)
    j = int((y - minx)/cellSize)
    try:
        #Now we find the names in that cell - n.B. we ignore for now the fact that Geograph cell could be at a boundary
        gazNames = gaz.at[i,j]
        #Deal with a cell having no values in the gazetteer
        if (isinstance(gazNames,set) == False): 
            #print(type(gazNames))
            gazNames = {"NoNamesFound"}
    except KeyError:
        gazNames = {"NoNamesFound"}
    #Get back the named entities for the text        
    ents = dict.get("entities")
    #Now we iterate through, and find out if each name is already in the local gazetteer
    for ent in ents:        
        if (ent.text in gazNames):
            data.append([dict.get("id"), "Existing", ent.text, ent.label_, x, y]) 
            #print("Found existing name:", ent.text, ent.label_)
        else:
            #print("Potential new name:" , ent.text, ent.label_)
            data.append([dict.get("id"), "New", ent.text, ent.label_, x, y]) 
#Store the results in a dataframe
df = pd.DataFrame(data, columns = ['id', 'status','name','type','x','y'])
df

# %%
#Split results into existing and candidate names for reporting
new = df.loc[df['status'] == 'New']
existing = df.loc[df['status'] == 'Existing']

# %% [markdown]
# We output the new names we found for the class 'PERSON'. You could calculate precision here by judging how many of these are really toponyms (since we assume implicitly that 'PERSON' names are actually toponyms).

# %%
#Let's look at one example NER class in the candidate names
names = new.loc[new['type'] == 'PERSON']

with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(names)

# %%
cn = len(set(new['name']))
ce = len(set(existing['name']))
print("Found", ce, "unique existing names and", cn, "unique new candidate names.")

# %%
#output all dependencies so that we can reproduce the notebook (we only need this to set things up for Binder)
#%load_ext watermark
#%watermark --iversions

# %% [markdown]
# We plot the locations of the new and existing names as simple scatter plots. A density plot would make more sense here to allow a real comparison, but this gives us a first overview.

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.scatter(new['x'], new['y'])
ax2.scatter(existing['x'], existing['y'])
