# %% [markdown]
# ## Introduction
#
# This notebook illustrates how we can use NER to search for placenames in a corpus, and enhance a gazetteer. It uses two datesets to illustrate the concepts.
#
# 1) [Geograph](https://geograph.org.uk)
# This site invites users to take pictures in the UK and add descriptions. It has almost 7 million pictures, and the data are licenced using a CC By-SA licence, making them available for research as long as we keep the names of the users, and allow others to have access to any data we might create.
#
# 2) [Ordnance Survey](https://ordnancesurvey.co.uk/) 50k gazetteer
# This gazetteer was published under a UK Open Government licence and contains all place name found on 1:50k maps in the UK. It is a legacy product (i.e. not used or updated any more), but it is suitable for our purposes.
#
# We are going to look for names found in the Geograph data that don't exist in the gazetteer. Since we know that many names occur multiple times, we will do this locally, to increase the chances that we really find new names.
#
# **The first block of our code reads in data and builds a simple spatial index for the gazetteer. We only need to do this once.**

# %%
import OSGridConverter #To convert from =SGB36 to WGS84
import pandas as pd #To use pandas for elegant data handling
import spacy #Our NLP tools
import matplotlib.pyplot as plt #To plot results

#Load a language model to do NLP
nlp = spacy.load("en_core_web_sm")

# %%
#First we read in the geograph data
geograph = pd.read_csv('./data/geograph_mini_corpus.csv', encoding='latin-1')
print(len(geograph))
geograph.head()
# Out:
# 138639
#         id          author                             title  \
# 0  2749148  M J Richardson       Great Blasket Island - 1960
# 1   635105      Bob Shires         White Beach Great Blasket
# 2   635109      Bob Shires  Remaining homes on Great Blasket
# 3   259349       Nigel Cox                   Coumeenoole Bay
# 4    16917      Pam Brophy                     Clogher Beach
#
#                                                 text        lon        lat
# 0  Looking northeast along the northwestern side ... -10.534101  52.097794
# 1  The only beach on Great Blasket as seen from t... -10.514872  52.107609
# 2  The remaining few habited homes of the abandon... -10.511764  52.104260
# 3  Viewed looking back from the Dunmore Head head... -10.463579  52.109322
# 4  The exact gpr for this beach is Q3153003375. T... -10.463338  52.157867

# %% [markdown]
# This block demonstrates the NLP results for a single Geograph document. We use the entities later as potential toponyms.

# %%
#First we demonstrate how the NLP works for a single example document
doc = nlp(geograph.text[11])
spacy.displacy.render(doc, style="ent")
doc_nouns = list(doc.noun_chunks)
print("nouns:",doc_nouns)
for ent in doc.ents:
      print("NER:", ent.text, ent.label_)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This field of sheep and line of trees is in the eastern half of the square. The picture was taken looking more or less
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . The square is all farming with a few residences along the minor road leading to the village of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dun Urlann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# nouns: [This field, sheep, line, trees, the eastern half, the square, The picture, more or less ENE, The square, a few residences, the minor road, the village, Dun Urlann]
# NER: ENE ORG
# NER: Dun Urlann ORG

# %% [markdown]
# Now we load the gazetteer data and create a simple spatial index.

# %%
#Read in the Ordnance Survey gazetteer
os_50k = pd.read_csv('./data/50kgaz2012.txt',sep=':', encoding='utf8', header=None)
os_50k.head()
# Out:
#    0       1                                2     3   4     5   6     7   \
# 0   1  TQ6004                1066 Country Walk  TQ60  50  49.0   0  16.7
# 1   2  TQ7715                1066 Country Walk  TQ60  50  54.7   0  31.5
# 2   3  TQ7610   1066 Country Walk Bexhill Link  TQ60  50  52.0   0  30.5
# 3   4  TQ8315  1066 Country Walk Hastings Link  TQ80  50  54.5   0  36.6
# 4   5  NB5464                       A' Beirghe  NB46  58  30.0   6  12.9
#
#        8       9  10  11      12                    13 14           15 16  \
# 0  104500  560500  E  ES  E Susx           East Sussex  X  20-SEP-2011  I
# 1  115500  577500  E  ES  E Susx           East Sussex  X  20-SEP-2011  I
# 2  110500  576500  E  ES  E Susx           East Sussex  X  20-SEP-2011  I
# 3  115500  583500  E  ES  E Susx           East Sussex  X  20-SEP-2011  I
# 4  964500  154500  W  WI   N Eil  Na h-Eileanan an Iar  X  21-JAN-2003  U
#
#     17  18  19
# 0  199   0   0
# 1  199   0   0
# 2  199   0   0
# 3  199   0   0
# 4    8   0   0

# %%
#We need to create locations for each place name in decimal degrees using the data we loaded
#os_50k[20] = os_50k[4] + os_50k[5]/60
#os_50k[21] = os_50k[6] + os_50k[7]/60
#os_50k.loc[os_50k[10] == 'W', 21] = -1 * os_50k.loc[os_50k[10] == 'W', 21]

#Tidy up the gazetteer by dropping columns we won't use afterwards
os_trimmed = os_50k.drop([0,1,3,4,5,6,7,10,11,12,14,15,17,18,19], axis = 1)
os_trimmed.head()
#os_trimmed.columns = ['name','y','x','county','type','lat','lon']

os_trimmed.columns = ['name','y','x','county','type']
os_trimmed.head()

#Plot the gazetteer locations as a sanity check
#os_trimmed.plot.scatter(x = 'x', y = 'y')
print('The gazetteer has a total of', len(os_trimmed), 'entries.')
# Out:
# The gazetteer has a total of 258487 entries.

# %%
#We build a simple index using rectangular grid cells
#Each cell contains all placenames from the gazetteer for that cell and can be used to do a lookup
#cellSize determines the resolution in metres

cellSize = 10000
minx = os_trimmed['x'].min()
maxx = os_trimmed['x'].max()
miny = os_trimmed['y'].min()
maxy = os_trimmed['y'].max()

w = maxx - minx
h = maxy - miny

nc = int(w/cellSize) + 1
nr = int(h/cellSize) + 1

gaz = pd.DataFrame(index=range(nc),columns=range(nr))

#Now we populate the index with names
for index, row in os_trimmed.iterrows():
    i = int((row['x'] - minx)/cellSize)
    j = int((row['y'] - minx)/cellSize)
    name = row['name']
    
    if pd.isnull(gaz.at[i,j]):
        gaz.at[i,j] = {name}
    else:
        names = gaz.at[i,j]
        names.add(name)
        gaz.at[i,j] = names

# %% [markdown]
# Here we **draw a sample of documents** from the Geograph data and perform NER on those data.
#
# The sample can either be random, or we can define a search term and extract all records containg that term.
#
# We can rerun this block to build a new sample. The size of this sample can also be changed.

# %%
# Create a sample of Geograph documents and run the NER pipeline
random = False

if random == True:
    m = 200
    sample = geograph.sample(n = m)
else:
    # Create a sample related to a word
    sample = geograph[geograph['text'].str.contains('mountain')]

docs = list(nlp.pipe(sample.text,n_process=2, batch_size=100))

#Now we store the NER results with the original geograph document ids, text and coordinates
results = list()
for (idxRow, s1), (_, s2) in zip(sample.iterrows(), enumerate(docs)):
    try:
        g = OSGridConverter.latlong2grid (s1.lat, s1.lon, tag = 'WGS84')
        dict = {
            "id": s1.id,
            "x": g.E,
            "y": g.N,
            "entities": s2.ents,
            "text": s1.text   
        }
        results.append(dict)
    except ValueError:
        print("Problem with a document", s1.text)
        #Ignore documents we couldn't parse for some reason
        
results
# Out:
# [{'id': 1433792,
#   'x': -177082,
#   'y': 284686,
#   'entities': (Tiorabhain,),
#   'text': 'View of Marthain mountain from Tiorabhain.'},
#  {'id': 16676,
#   'x': -176779,
#   'y': 278272,
#   'entities': (320 degrees,),
#   'text': 'The coastal road is flanked by the cliffs on the one hand and hilly and mountainous terrain in the other. This view takes a bearing of 320 degrees.'},
#  {'id': 220144,
#   'x': -175828,
#   'y': 282689,
#   'entities': (Ventry, Dun Chaoin, about 185, Cruach Mharthain, 403),
#   'text': 'This is the narrow back road from Ventry to Dun Chaoin. Here the road is ascending to its highest point at about 185m high.  The mountain on the right is Cruach Mharthain (403m)  '},
#  {'id': 1980326,
#   'x': -175442,
#   'y': 282375,
#   'entities': (Dun Chaoin,),
#   'text': 'Looking south from the mountain road between Ventry and Dun Chaoin.'},
#  {'id': 220023,
#   'x': -175320,
#   'y': 282748,
#   'entities': (the Dingle Peninsula, Cruach Mharthain),
#   'text': 'Fuchsias line many of the hedgerows on the Dingle Peninsula.  The trackway leads to pasture land.  The mountain Cruach Mharthain lies behind to the right.  '},
#  {'id': 220050,
#   'x': -173912,
#   'y': 283939,
#   'entities': (Smerwick Harbour, Baile),
#   'text': 'The stream winds its way down from the mountains in the west (in the background) and eventually flows into Smerwick Harbour by Baile an Reannaigh in the east.'},
#  {'id': 220017,
#   'x': -173654,
#   'y': 284623,
#   'entities': (Brandon,),
#   'text': 'The ruin of the chapel is surrounded by gravestones.  The ground is very uneven.  The Brandon group mountains are in the distance.  '},
#  {'id': 220159,
#   'x': -171502,
#   'y': 282353,
#   'entities': (Eagle, Ireland, British),
#   'text': 'A view from Mam an Oraigh across fields and scattered dwellings to Eagle mountain which is the most westerly mountain in Ireland and hence the British Isles - apparently!'},
#  {'id': 220260,
#   'x': -168313,
#   'y': 285890,
#   'entities': (Milltown,),
#   'text': 'Ballysitteragh mountain looms over the valley where the Milltown river flows.  It was good weather for the grass to dry out.  '},
#  {'id': 219278,
#   'x': -165856,
#   'y': 290014,
#   'entities': (Brandon, Baile, Cosan, Naomh),
#   'text': "The route to the summit of Brandon mountain from An Baile Breac follows the Cosan na Naomh (Pilgrim's way) and at the base of the mountain by the car parking area there is this not insubstantial shrine.  "},
#  {'id': 2391019,
#   'x': -162636,
#   'y': 293863,
#   'entities': (746, Masatiompan),
#   'text': 'Rock outcrop called Piaras Mór (746m) on S side of Masatiompan mountain.'},
#  {'id': 484664,
#   'x': -163364,
#   'y': 283666,
#   'entities': (the Connor Pass, Dingle),
#   'text': "View to the south-east from the Connor Pass road to the north-east of the small town of Dingle. The mountains on the horizon are Macgillycuddy's Reeks."},
#  {'id': 913078,
#   'x': -162665,
#   'y': 283356,
#   'entities': (Connor Pass,),
#   'text': 'Along this stretch the Dingle way skirts around the southern base of the mountains and eventually runs beside the buildings which can be seen in the centre and distance.  The building at the top left of the photograph stands beside the R560 which heads up to Connor Pass.'},
#  {'id': 259744,
#   'x': -161998,
#   'y': 285566,
#   'entities': (),
#   'text': 'The steep northern side of the mountain on the right compared with the gentler southern side on the left.'},
#  {'id': 259753,
#   'x': -160490,
#   'y': 285541,
#   'entities': (Castlegregory, Tralee, over 400 metres, Slievanea),
#   'text': 'The road from Castlegregory and Tralee comes up the side of the hill to the left before dropping down over the summit of the pass to descend to Dingle to the right. The pass is over 400 metres above sea level. Slievanea is the distant mountain. '},
#  {'id': 3312383,
#   'x': -159749,
#   'y': 285926,
#   'entities': (Brandon Bay,),
#   'text': 'The track is a zig-zag down the mountainside. In the far distance is Brandon Bay.'},
#  {'id': 580636,
#   'x': -162304,
#   'y': 260193,
#   'entities': (Glencar,),
#   'text': 'By the mountain road to Glencar.'},
#  {'id': 846133,
#   'x': -158328,
#   'y': 294340,
#   'entities': (Brandon Bay,),
#   'text': 'On a mountain track looking towards Brandon Bay'},
#  {'id': 219111,
#   'x': -157142,
#   'y': 296738,
#   'entities': (251, Cnoc Breanainn, Brandon, 952, Mas, Masatiompan, 763),
#   'text': 'A cairn on the summit of An Buaicin which reaches a height of 251m.  In the background is Cnoc Breanainn (Brandon mountain 952m just left of centre) and Mas an Tiompain (Masatiompan 763m on right)'},
#  {'id': 219611,
#   'x': -157300,
#   'y': 293630,
#   'entities': (Owenafeanna, Brandon, Brandon, Brandon),
#   'text': 'The Owenafeanna river flows from the Brandon mountain range into Brandon bay at the village of Brandon.  '},
#  {'id': 918241,
#   'x': -135152,
#   'y': 484993,
#   'entities': (Croaghaun,),
#   'text': 'A glacial tarn located in the side of Croaghaun mountain. The main armchair part of the corrie is located 1 square to the north of here.'},
#  {'id': 219607,
#   'x': -157100,
#   'y': 293614,
#   'entities': (Owenafeanna, Brandon, Brandon),
#   'text': 'The Owenafeanna river flows from the Brandon mountain range into Brandon bay at the village of Brandon'},
#  {'id': 219588,
#   'x': -154634,
#   'y': 291798,
#   'entities': (Fermoyle, Brandon),
#   'text': 'Flat dune land behind Fermoyle strand. The Brandon mountain range in the distance. '},
#  {'id': 845224,
#   'x': -154009,
#   'y': 286008,
#   'entities': (Slievenagower, Beenbo),
#   'text': 'Crossing open mountainside towards Slievenagower and Beenbo.'},
#  {'id': 484604,
#   'x': -152618,
#   'y': 291831,
#   'entities': (Brandon Strand,),
#   'text': 'Brandon Mountain viewed from Brandon Strand a beautiful beach with a wonderful mountain backdrop.'},
#  {'id': 315582,
#   'x': -151594,
#   'y': 292048,
#   'entities': (Brandon, Strand),
#   'text': 'looking towards Brandon mountain from halfway along the Strand'},
#  {'id': 845218,
#   'x': -152141,
#   'y': 285722,
#   'entities': (Garivagh River, Lough Anascaul),
#   'text': 'Junction of mountain stream with Garivagh River near Lough Anascaul.'},
#  {'id': 1932270,
#   'x': -156972,
#   'y': 241562,
#   'entities': (Coomnahorna,),
#   'text': 'Sharp bend on mountain road in Coomnahorna with nearby drainage channels.'},
#  {'id': 1981758,
#   'x': -150670,
#   'y': 291780,
#   'entities': (),
#   'text': 'Lush pasture located between the sea to the north and the Slieve Mish mountains to the south.'},
#  {'id': 1854966,
#   'x': -126613,
#   'y': 500036,
#   'entities': (the east coast, Belmullet, Achill Island),
#   'text': 'A shingle headland on the east coast of the Belmullet peninsula. The mountains of Achill Island can be dimly seen in the distance.'},
#  {'id': 285648,
#   'x': -155856,
#   'y': 223654,
#   'entities': (Cornwall,),
#   'text': 'Copper mine ruins. Miners were imported from Cornwall to help win the copper for someone or other.  Strange to see such familiar buildings in a mountainous setting.'},
#  {'id': 1397619,
#   'x': -129723,
#   'y': 442160,
#   'entities': (Mweelrea Mountains, County Mayo, Benchoona, Connemara),
#   'text': 'Mweelrea Mountains in County Mayo in the distance to the left; whilst to the right are the Benchoona group of mountains in Connemara.'},
#  {'id': 1880030,
#   'x': -120614,
#   'y': 512899,
#   'entities': (Belmullet/Béal, County Mayo),
#   'text': 'Buildings on the outskirts of Belmullet/Béal an Mhuirthead. The triple water tower in [[F7033]] is very conspicuous. The mountains of County Mayo in the distance.'},
#  {'id': 1948606,
#   'x': -148258,
#   'y': 263759,
#   'entities': (),
#   'text': 'A flock of mountain sheep curiously investigating an interloping stranger.'},
#  {'id': 55129,
#   'x': -127947,
#   'y': 441737,
#   'entities': (Mweel Rea,),
#   'text': 'Looking east from the beach towards the Mweel Rea mountains'},
#  {'id': 15803,
#   'x': -145620,
#   'y': 279171,
#   'entities': (the Ring of Kerry,),
#   'text': 'This lovely beach on the Dingle peninsula is in the western half of the grid square running diagonally from north to south across it. The mountains and hills in the picture are of the Ring of Kerry.'},
#  {'id': 1221163,
#   'x': -145542,
#   'y': 273196,
#   'entities': (Dingle Bay, Inch Strand, Slieve Mish),
#   'text': 'Looking north-east to the tower at the end of the long sand spit in Dingle Bay. Across the water is the even longer sand spit of Inch Strand (attached to the north shore) and the Slieve Mish mountains.'},
#  {'id': 1394359,
#   'x': -123214,
#   'y': 463245,
#   'entities': (two, Granuaile, Castle, Mayo),
#   'text': "Harbour at Fawnglass on the east side of the island. The two rival ferries are both at the jetty. Granuaile's Castle can be seen to the right. Carrowmore Hill [[L7880]] is on the mainland on the opposite shore with the mountains of Mayo beyond."},
#  {'id': 1394353,
#   'x': -123186,
#   'y': 462860,
#   'entities': (Mayo, Connemara),
#   'text': 'Cove at the south-eastern tip of the island. The mountains of south Mayo and Connemara can be seen in the distance.'},
#  {'id': 964964,
#   'x': -125831,
#   'y': 435480,
#   'entities': (),
#   'text': "The view from the visitors' centre where a mountain stream has been formed into an artificial lake."},
#  {'id': 1007835,
#   'x': -144792,
#   'y': 257614,
#   'entities': (One, Iveragh),
#   'text': 'One of the few roads through the mountains of Iveragh.'},
#  {'id': 3329973,
#   'x': -144198,
#   'y': 258172,
#   'entities': (the Iveragh Peninsula, about 300 metres, The Coomaclarig River),
#   'text': 'This un-named road crosses the saddle of the mountains in the centre of the Iveragh Peninsula at about 300 metres. The Coomaclarig River is in the valley below.'},
#  {'id': 456827,
#   'x': -146490,
#   'y': 232240,
#   'entities': (),
#   'text': 'The mountains of Kerry are just visible in the far distance.'},
#  {'id': 965004,
#   'x': -123906,
#   'y': 435035,
#   'entities': (Kylemore Abbey, Doughruach),
#   'text': 'The mountain consists of peat moorland interspersed with lots of granite rock outcrops.  In the background we look down towards Kylemore Abbey and Doughruach.'},
#  {'id': 12881,
#   'x': -146094,
#   'y': 224860,
#   'entities': (),
#   'text': 'Lifeboat in harbour/port. Note cross on mountain in background.'},
#  {'id': 774876,
#   'x': -139584,
#   'y': 274291,
#   'entities': (Lough Yganavan, Macgillycuddy's Reeks),
#   'text': "There are many donkeys or horses to be seen in fields around here.  Beyond can just be seen Lough Yganavan with the mountains of Macgillycuddy's Reeks beyond."},
#  {'id': 1623306,
#   'x': -121610,
#   'y': 436239,
#   'entities': (Kylemore Abbey,),
#   'text': 'The Kylemore Abbey chapel spire is barely visible at the top of the trees at the base of the mountain in the background.'},
#  {'id': 200643,
#   'x': -121461,
#   'y': 435150,
#   'entities': (Maolan, Benbrack, Knockbrack),
#   'text': 'Located beside one of several slit quarries in the lower slopes of Benbaun (Binn Bhan or Maolan; left). The mountains on the horizon are Benbrack (Binn Bhreac) and the ridge onto Knockbrack (Cnoc Breac)'},
#  {'id': 1879163,
#   'x': -114279,
#   'y': 497987,
#   'entities': (Tullaghan Bay, Achill Island),
#   'text': 'Cottage (possibly abandoned) on the edge of marshland at the northern end of Tullaghan Bay. The mountains of Achill Island in the distance.'},
#  {'id': 1425647,
#   'x': -122287,
#   'y': 423717,
#   'entities': (evening,),
#   'text': 'An evening view of the river which is impounded above a small weir. The distant mountain peak is Benlettery [[L7749]].'},
#  {'id': 1403720,
#   'x': -118796,
#   'y': 455070,
#   'entities': (Clew Bay,),
#   'text': 'Scattered farms and cottages on the low land to the south of Clew Bay. The mountains are on the far side of the bay.'},
#  {'id': 899663,
#   'x': -122979,
#   'y': 414392,
#   'entities': (),
#   'text': 'Looking out across the fields towards the pier sea and mountains beyond.'},
#  {'id': 192216,
#   'x': -119869,
#   'y': 442059,
#   'entities': (Killary Bay Little,
#    Killary Harbour,
#    Ireland,
#    Killary Harbour,
#    Rosroe,
#    Mweel Rea,
#    the Ice Age),
#   'text': "The bungalow is at GR762644 and is viewed from the beach car park. Killary Bay Little is clearly visible but Killary Harbour (Ireland's fjord) is not. Killary Harbour itself lies beyond the low peninsula of Rosroe which is visible but doesn't really separate from the mountain backdrop. The flanks of Mweel Rea have been steepened and planed flat (truncated) by glacial ice during the Ice Age."},
#  {'id': 1448511,
#   'x': -122017,
#   'y': 405953,
#   'entities': (morning,),
#   'text': "A view northwards up the bay with distant houses and buildings close to the causeway. The morning's low cloud and drizzle can be seen blowing away into the mountains where it belongs."},
#  {'id': 15041,
#   'x': -142168,
#   'y': 211453,
#   'entities': (),
#   'text': 'The south side of the mountain is viewed from south  of the picnic area. '},
#  {'id': 658604,
#   'x': -132803,
#   'y': 297729,
#   'entities': (Rahoneen, Banna Strand, Sliabh Mis),
#   'text': 'A view south across the wetlands of Rahoneen townland from the track from Banna Strand. The Sliabh Mis mountains of the Dingle peninsula can be seen in the distance.'},
#  {'id': 1397660,
#   'x': -117313,
#   'y': 438612,
#   'entities': (Lough Fee, Illaunroe, Garraun),
#   'text': 'Rhododendron covers this little island in Lough Fee. The tip of the Illaunroe peninsula can be seen to the right. The mountains of the Garraun group can be seen  across the lough.'},
#  {'id': 1403741,
#   'x': -114755,
#   'y': 459044,
#   'entities': (Carrowmore Strand, Turlin Strand, Clew Bay),
#   'text': 'Seen from the eastern end of Carrowmore Strand. Turlin Strand lies beyond the mouth of the river which is a significant obstacle. The mountains in the distance are on the north side of Clew Bay.'},
#  {'id': 1397662,
#   'x': -116856,
#   'y': 438312,
#   'entities': (Connemara,),
#   'text': 'Looking east along the rhododendron-clad shores. The mountains of Connemara in the background.'},
#  {'id': 450749,
#   'x': -135237,
#   'y': 262407,
#   'entities': (Lough Acoose, the Kerry Way, Lough Beg),
#   'text': 'View towards the southern head of Lough Acoose (Loch an Chuais) with the coastal range of mountains behind from the Kerry Way; the outlet river to Lough Beg is just visible (left). The fence marks the division between boulder-strewn moorland (right) and a narrow band of improved sheep pasture (left) lying to the west of the Kerry Way'},
#  {'id': 724757,
#   'x': -134900,
#   'y': 265126,
#   'entities': (Breanlee, Lough Nanoon),
#   'text': 'Looking back on the field structures of Breanlee (with the smoking chimney). A backpacker struggles to climb the mountain side just east of Lough Nanoon.'},
#  {'id': 1851763,
#   'x': -108285,
#   'y': 505728,
#   'entities': (Carrowmore Lake, Nephin Beg),
#   'text': 'The heather-clad shores of Carrowmore Lake. The northern end of the Nephin Beg range of mountains can be seen in the distance.'},
#  {'id': 332005,
#   'x': -133488,
#   'y': 262866,
#   'entities': (Lough Iochtair, three),
#   'text': 'Lough Iochtair is the lowest lake of three in Coomloughra Glen and is surrounded by a high ring of mountains known as the Coomloughra Horseshoe.'},
#  {'id': 967447,
#   'x': -114163,
#   'y': 436363,
#   'entities': (),
#   'text': 'The wet summer has produced many rapidly flowing mountain streams such as this one adjacent to the forest road.'},
#  {'id': 1297681,
#   'x': -107035,
#   'y': 498326,
#   'entities': (Achill Island,),
#   'text': 'This area had just been worked to some extent.  The mountains of Achill Island can be seen in the hazy distance.'},
#  {'id': 967431,
#   'x': -113724,
#   'y': 435249,
#   'entities': (One, Maumturk, Maumturks),
#   'text': 'One of many rivers flowing west from the Maumturk mountains that eventually flow into Lough Inagh.  The square is part forestry and part open moorland rising towards the Maumturks.'},
#  {'id': 331988,
#   'x': -132496,
#   'y': 261475,
#   'entities': (Caher, Carrauntoohil, Ireland),
#   'text': 'The walk up over Caher makes an excellent ridge walk to gain Carrauntoohil the highest mountain in Ireland.'},
#  {'id': 199736,
#   'x': -111792,
#   'y': 442381,
#   'entities': (Ben Bury, Oughty Craggy, Mweel Rea),
#   'text': 'The mixed woodland at the northern head of the lough hides the hamlet of Delphi. Ben Bury (or Oughty Craggy) of the Mweel Rea mountains climbs on the left and one of the Sheeffry hills on the right'},
#  {'id': 199718,
#   'x': -111792,
#   'y': 442381,
#   'entities': (Fin Lough, Owennagloch, Mweel Rea),
#   'text': 'Fin Lough is a small fishing lough by the hamlet of Delphi. In the background are the plantations of the valley of Owennagloch and an unnamed 379 m outlier peak of the Mweel Rea mountains'},
#  {'id': 1853250,
#   'x': -105456,
#   'y': 499972,
#   'entities': (R313, Belmullet, Bangor Erris, Nephin Beg),
#   'text': 'On the R313 from Belmullet as it enters the village of Bangor Erris. The mountains at the northern end of the Nephin Beg range rise beyond the village.'},
#  {'id': 271537,
#   'x': -136125,
#   'y': 216389,
#   'entities': (Glanroon, 317),
#   'text': 'Glanroon Townland. Very rough hillside and bog running up to the 317 m summit of Caher-mountain.'},
#  {'id': 113636,
#   'x': -131164,
#   'y': 261767,
#   'entities': (Ireland, 1039, a grand sunny day),
#   'text': "A clear view of Ireland's highest mountain (1039m) from the southwest approach. (The Kenmare Walking Festival organisers had arranged such a grand sunny day!)"},
#  {'id': 895831,
#   'x': -131066,
#   'y': 261004,
#   'entities': (Carrantouhill Mountain, Ireland, 400, 723),
#   'text': 'A narrow gorge in the hill leading up to Carrantouhill Mountain (the highest mountain in Ireland) - a long hard climb rising from 400m to 723m.'},
#  {'id': 777818,
#   'x': -130226,
#   'y': 262273,
#   'entities': (Gaddagh River,),
#   'text': 'On our way down towards Gaddagh River we saw a number of mountain goats going about their business.  This is the best attempt at getting a photo.  Interesting graffiti on the rock on the skyline as well.'},
#  {'id': 199770,
#   'x': -111892,
#   'y': 429308,
#   'entities': (the east bank, R344, Bencorr, Binn Chorr, Bencorrbeg),
#   'text': 'View from an inlet on the east bank where the R344 runs beside the lough. The mountains in the distance are Bencorr (Binn Chorr; left) and Bencorrbeg (Binn an Choire Bhig; right)'},
#  {'id': 777754,
#   'x': -129633,
#   'y': 262264,
#   'entities': (One, two, Loughs, Gaddagh River, Carrauntoohil, Reeks),
#   'text': 'One of two Loughs on the higher reaches of Gaddagh River on the northern approach to Carrauntoohil.  Behind are the eastern mountains of the Reeks.  The foreground moorland is in this square.'},
#  {'id': 1752809,
#   'x': -133294,
#   'y': 226662,
#   'entities': (Ardigole Bay,),
#   'text': 'A view of the inland stretch of Ardigole Bay and the mountains beyond.'},
#  {'id': 1249423,
#   'x': -113980,
#   'y': 401984,
#   'entities': (Connemara,),
#   'text': 'From the road through An Cnoc (Knock) there are views north across Cuan Chaisín (Casheen Bay) towards the mountains of central Connemara.'},
#  {'id': 777728,
#   'x': -128653,
#   'y': 264618,
#   'entities': (Carrauntoohil,),
#   'text': 'From a car park at an access point to Carrauntoohil (not the usual tourist car park).  This view looks north-west across farmland with Knockbrack the mountain on the left.'},
#  {'id': 317799,
#   'x': -125965,
#   'y': 285587,
#   'entities': (Tralee, Tralee, Crusline),
#   'text': 'The road winds back down towards Tralee; in the centre of my picture. The Stacks Mountains can be seen beyond Tralee and off to the right handside of the picture. Although they are "mountains" in the lowest sense as Crusline at 355m is hardly very high!'},
#  {'id': 302068,
#   'x': -126048,
#   'y': 284588,
#   'entities': (),
#   'text': 'A minor road climbs to just over 320m at the eastern end of the Slieve Mish range and affords a fine view towards the high mountains of Kerry to the south.'},
#  {'id': 2445614,
#   'x': -127956,
#   'y': 261008,
#   'entities': (Munro, Macgillycuddys Reeks, 6, over 3000),
#   'text': 'Looking towards Cnoc na Peiste a Munro in the Macgillycuddys Reeks range of mountains from further west along the high level ridge of 6 tops of over 3000 feet.r'},
#  {'id': 1605988,
#   'x': -128618,
#   'y': 252540,
#   'entities': (Sneem, Knocklomena),
#   'text': 'This view is from R568 between Sneem and Molls Gap.  I believe the mountain in the background is Knocklomena.'},
#  {'id': 2445624,
#   'x': -127377,
#   'y': 261443,
#   'entities': (3000ft top, Macgillycuddys Reeks),
#   'text': 'The curiously named Big Gun - a 3000ft top in the Macgillycuddys Reeks range of mountains - taken from the airy ridge to its north.'},
#  {'id': 1848303,
#   'x': -132105,
#   'y': 216329,
#   'entities': (Derrycluvaine, Rosskerig),
#   'text': 'A misty view of farm shed at Derrycluvaine with Rosskerig mountain behind.'},
#  {'id': 1848475,
#   'x': -131998,
#   'y': 216522,
#   'entities': (Rosskerrig,),
#   'text': 'Outbuildings at Derrycluvane farm high on the hillside between Seefin and Rosskerrig mountains.'},
#  {'id': 967910,
#   'x': -104472,
#   'y': 456551,
#   'entities': (St. Patrick's, 441AD, the 40 days, Croagh Patrick, 764 metres),
#   'text': "This is the supposed site of St. Patrick's bed.  He ascended the mountain in 441AD and spent the 40 days of lent fasting on the summit.  The highest point of Croagh Patrick (764 metres) is in the background."},
#  {'id': 1687395,
#   'x': -104461,
#   'y': 456561,
#   'entities': (Croagh Patrick, Each year thousands, 2500ft above),
#   'text': 'This is what the view looks like on the top of Croagh Patrick. Each year thousands of people go up the mountain which is 2500ft above sea level.'},
#  {'id': 1940670,
#   'x': -125328,
#   'y': 260055,
#   'entities': (Black Valley, Cummeenduff Glen, Broaghnabinnia),
#   'text': 'The road descends into Black Valley and Cummeenduff Glen. The mountain in the distance is Broaghnabinnia.'},
#  {'id': 1834293,
#   'x': -129937,
#   'y': 216251,
#   'entities': (Rosskerrig, Rosskerrig),
#   'text': 'A glimpse of the upland heath between Rosskerrig and Rosskerrig mountain with a few fields scratched out of the bare land.'},
#  {'id': 1773515,
#   'x': -104060,
#   'y': 456074,
#   'entities': (twenty thousand, Sunday),
#   'text': 'They do say over twenty thousand people climb this holy mountain on Pilgrim Sunday and I can well believe it!!  The Civil Defence wearing the red helmets.'},
#  {'id': 1433821,
#   'x': -109186,
#   'y': 406923,
#   'entities': (Inis Loiscthe,),
#   'text': 'A derelict boat at the high-tide mark is accompanied by a very plentiful supply of drifted seaweed. The view to the north takes in the tidal channel which separates the small Inis Loiscthe and a distant promontory. The mountain in the background is Cnoc Mordain which makes a distinct coastal ridge [[L8637]].'},
#  {'id': 967993,
#   'x': -101887,
#   'y': 455356,
#   'entities': (the Owenwee River,),
#   'text': 'The stream flows from the mountain behind us towards the Owenwee River in the next square south.'},
#  {'id': 967988,
#   'x': -101877,
#   'y': 455355,
#   'entities': (Crott Mountain, Croagh Patrick, Owenwee River),
#   'text': 'The stream flows off Crott Mountain (an outlier of Croagh Patrick in the cloud behind) and flows into the Owenwee River behind us.  This square is wholly mountain moorland.'},
#  {'id': 1309380,
#   'x': -121333,
#   'y': 268790,
#   'entities': (),
#   'text': 'Looking towards the cloud covered mountains.'},
#  {'id': 1914762,
#   'x': -124530,
#   'y': 237369,
#   'entities': (Baurearagh Valley, Glengarriff, Kenmare),
#   'text': 'A nice grassy shelf with views of Baurearagh Valley farmsteads and the mountain road linking Glengarriff and Kenmare.'},
#  {'id': 1432246,
#   'x': -106811,
#   'y': 403472,
#   'entities': (One,),
#   'text': 'One of the highly characteristic lanes that reach out towards the shore in this area. Here we have a prospect of the mountains over the top of a group of nearby inter-tidal islets to the north.'},
#  {'id': 968025,
#   'x': -100456,
#   'y': 457518,
#   'entities': (),
#   'text': 'Most of the middle part of L9381 is seen from here.  The prominent house is in the next square north.  This square is rocky mountainside then moorland pasture.'},
#  {'id': 1099370,
#   'x': -122434,
#   'y': 246895,
#   'entities': (Kenmare, Killaha, Barraduff),
#   'text': 'A view from near Kenmare over fields by the Kenmare River towards the mountains of Killaha and Barraduff.'},
#  {'id': 16059,
#   'x': -122865,
#   'y': 238036,
#   'entities': (first, second),
#   'text': 'The first of these tunnels and mountainside to the left of it is in another grid square. The second tunnel and land to the right is in this grid square.'},
#  {'id': 2425200,
#   'x': -100758,
#   'y': 432823,
#   'entities': (Upper Mask Bay,),
#   'text': 'Looking towards the head of the valley above Upper Mask Bay. The mountain at the end is Bunnacunneen [[L9357]].'},
#  {'id': 2425186,
#   'x': -100473,
#   'y': 432749,
#   'entities': (Upper Mask Bay, Lugnabrick),
#   'text': 'Top end of the valley above Upper Mask Bay. The mountain opposite is Lugnabrick [[L9655]].'},
#  {'id': 1588660,
#   'x': -102419,
#   'y': 410678,
#   'entities': (Maumturk,),
#   'text': 'Looking northwards over the small loch towards the Maumturk mountains. Sheep are grazing the blanket bog beyond the edge of the village.'},
#  {'id': 776879,
#   'x': -118311,
#   'y': 257552,
#   'entities': (Kenmare, Killarney),
#   'text': 'An old route through the mountains from Kenmare to Killarney.  Now easy to follow as part of the Kerry Way but still quite remote.'},
#  {'id': 1373296,
#   'x': -116207,
#   'y': 275267,
#   'entities': (Scart,),
#   'text': "Looking over rough grazing from the verge of the N22 south of Scart. This is a fast road with few places to pull off safely. On the skyline on this very hot and hazy day is the panorama of the Macgillycuddy's Reeks mountains."},
#  {'id': 1404778,
#   'x': -98010,
#   'y': 443769,
#   'entities': (),
#   'text': 'Looking down the Derrycraff valley from the mountain road between Westport and Tourmakeady.'},
#  {'id': 2412318,
#   'x': -98404,
#   'y': 433067,
#   'entities': (Toorloggagh, Upper Mask Bay, Bunnacunneen, 575 metres, Ben Beg),
#   'text': 'Country road at Toorloggagh at the head of Upper Mask Bay. The mountain ahead is Bunnacunneen (575 metres) [[L9357]] with the slopes of Ben Beg to the right.'},
#  {'id': 777150,
#   'x': -114967,
#   'y': 261722,
#   'entities': (Shehy, Torc),
#   'text': 'Looking west across the lake towards Shehy moutnain (right) and Torc mountain (left)'},
#  {'id': 2244862,
#   'x': -114864,
#   'y': 256894,
#   'entities': (Mangerton,),
#   'text': 'Secondary summit 1Km west of Mangerton mountain'},
#  {'id': 2443090,
#   'x': -94253,
#   'y': 450583,
#   'entities': (),
#   'text': 'The mountain road between Westport and Tourmakeady. The Partry mountains lie beyond.'},
#  {'id': 1913799,
#   'x': -114071,
#   'y': 237309,
#   'entities': (One,),
#   'text': 'One of many little hill top loughs on these showery mountains'},
#  {'id': 524446,
#   'x': -109059,
#   'y': 255306,
#   'entities': (),
#   'text': 'A downhill mountain biker on the final stage of the descent.'},
#  {'id': 524451,
#   'x': -109059,
#   'y': 255306,
#   'entities': (),
#   'text': 'A mountain biker heads for the finish line.'},
#  {'id': 2427380,
#   'x': -88368,
#   'y': 443817,
#   'entities': (Tourmakeady Mountain, Steep Bends, the Glensaul River),
#   'text': 'A hairpin bend on the steep descent of the west side of Tourmakeady Mountain. The informal "Steep Bends" sign appears to be related to a cycle race. The lower slopes of the mountain are well forested. The stream flows down to join the Glensaul River in the Tourmakeady Glen.'},
#  {'id': 1537384,
#   'x': -82166,
#   'y': 482363,
#   'entities': (second, 808),
#   'text': 'Nephin is the second highest mountain in County Mayo at 808m.'},
#  {'id': 1192568,
#   'x': -106612,
#   'y': 239911,
#   'entities': (Shehy, West Cork),
#   'text': 'The Shehy mountain range in West Cork is full of little ponds such as this one.'},
#  {'id': 507531,
#   'x': -106162,
#   'y': 240478,
#   'entities': (West, West, South, Coomroe),
#   'text': 'This walk is to the West of the West most car park. The views are of the mountainside South of Coomroe.'},
#  {'id': 1255057,
#   'x': -83968,
#   'y': 416283,
#   'entities': (Lough Corrib, Connemara),
#   'text': 'The golf course sits between Lough Corrib to the east and the Connemara mountains to the north.'},
#  {'id': 1248128,
#   'x': -101981,
#   'y': 238120,
#   'entities': (the Shehy Mountains, North West Cork),
#   'text': 'This is a landmark mountain in the Shehy Mountains of North West Cork.'},
#  {'id': 1844253,
#   'x': -84691,
#   'y': 344922,
#   'entities': (),
#   'text': 'Extensive forestry around the mountain is supplemented with an excellent network of forest tracks.'},
#  {'id': 1844231,
#   'x': -84541,
#   'y': 344306,
#   'entities': (),
#   'text': 'On the edge of moorland and mountain forestry territory.'},
#  {'id': 806947,
#   'x': -69392,
#   'y': 478217,
#   'entities': (Lough Cullin Co, Mayo, Nephin),
#   'text': 'Lough Cullin Co Mayo with the Nephin mountain range in the distance.'},
#  {'id': 2550918,
#   'x': -66794,
#   'y': 501184,
#   'entities': (the River Moy,),
#   'text': 'The mountains on the horizon are located east of the River Moy.'},
#  {'id': 854129,
#   'x': -77537,
#   'y': 379930,
#   'entities': (),
#   'text': 'A burren limestone mountain block is on the horizon to the west.'},
#  {'id': 112852,
#   'x': -68410,
#   'y': 372323,
#   'entities': (the Turlough Mountains,),
#   'text': 'Looking northeast looking onto the shoulder of the south summit of the Turlough Mountains. Taken from the adjcent square in order to capture the grand scale of this mountain.'},
#  {'id': 2833425,
#   'x': -75868,
#   'y': 253132,
#   'entities': (Macroom, The Burren Wind Farm),
#   'text': 'Some fields observed from the Macroom road.  The Burren Wind Farm can be seen on Burren mountain in the distance.'},
#  {'id': 65153,
#   'x': -63081,
#   'y': 375898,
#   'entities': (September 2005,),
#   'text': 'The tree is still alive (September 2005). The background is formed by the eastern clope of the Burren mountains.'},
#  {'id': 1611272,
#   'x': -51915,
#   'y': 486840,
#   'entities': (Mayo, Ireland),
#   'text': 'Beautiful natural lake set in the Ox mountains close to the Sligo/Mayo border in Ireland'},
#  {'id': 1393035,
#   'x': -46566,
#   'y': 495523,
#   'entities': (the Ox Mountains, Sruffaungarve),
#   'text': 'The lonely mountain road from Dromore West to Tobercurry over the Ox Mountains passes this attractive lough. The bridge crosses the Sruffaungarve just before it enters the lough.'},
#  {'id': 3051719,
#   'x': -60048,
#   'y': 333216,
#   'entities': (Site,
#    14 - Bunratty House,
#    Mountain Laurel,
#    Pennyvlvania,
#    Wisconsin,
#    Kylemore Abbey,
#    County),
#   'text': "Location is along a pedestrian walkway at southwest corner of grazing area southwest of Site #14 - Bunratty House. View is to west. This shrub is very similar to Mountain Laurel that I've seen in the mountains of southwestern Pennyvlvania and in the woods of northern Wisconsin. I'm also wondering if it is similar to the Rhododendron that I've seen at Kylemore Abbey in County Galway."},
#  {'id': 1852307,
#   'x': -42130,
#   'y': 506498,
#   'entities': (Benbulbin, Sligo Bay),
#   'text': 'The mountain on the horizon is Benbulbin [[G6946]] which dominates the eastern end of Sligo Bay.'},
#  {'id': 1973400,
#   'x': -30558,
#   'y': 546445,
#   'entities': (),
#   'text': 'A stone face seems to look out amongst the rocky outcrops above the cliffs or have I been out in the mountains too long.'},
#  {'id': 1973335,
#   'x': -30225,
#   'y': 547271,
#   'entities': (Pilgrims, Eastern),
#   'text': "The Pilgrims' Path climbs the slopes on the Eastern side of the mountain and is the safest though least interesting route to the summit."},
#  {'id': 2540077,
#   'x': -26435,
#   'y': 520283,
#   'entities': (Sliabh Liag,),
#   'text': 'Erosion features in Carboniferous limestone formation in the inter-tidal zone. On the horizon the distant mountains of Sliabh Liag can be seen.'},
#  {'id': 1157343,
#   'x': -21835,
#   'y': 558687,
#   'entities': (Maghera, Port),
#   'text': 'View to left after getting over the top of the mountainside road at Maghera. I proceeded on this road turning to west to get to Port.'},
#  {'id': 1352939,
#   'x': -22351,
#   'y': 548345,
#   'entities': (),
#   'text': 'This is the shoulder of the mountain looking towards the highest point. In the foreground is a memorial stone [[1352939]]'},
#  {'id': 1160098,
#   'x': -20529,
#   'y': 562657,
#   'entities': (Loughros Peninsula,
#    the Loughros Beg Bay,
#    Slievetooey Mountains,
#    Mahera,
#    Port),
#   'text': 'View is from the end of the main road on Loughros Peninsula looking SW across the Loughros Beg Bay at the Slievetooey Mountains west of Mahera. The abandoned fishing village of Port is located on the far side of these mountains.'},
#  {'id': 1160073,
#   'x': -20014,
#   'y': 562452,
#   'entities': (the Loughros Peninsula,
#    Loughros Beg Bay,
#    Slievetooey Mountains,
#    Maghera,
#    Port),
#   'text': 'View is from the Loughros Peninsula looking across Loughros Beg Bay at the Slievetooey Mountains west of Maghera. The abandoned fishing village of Port is on the backside of these mountains.'},
#  {'id': 1403860,
#   'x': -19700,
#   'y': 560485,
#   'entities': (Maum,),
#   'text': 'With Maum mountain behind.'},
#  {'id': 241263,
#   'x': -24313,
#   'y': 503540,
#   'entities': (About 80,),
#   'text': 'This fantastic site is surrounded by mountain ranges and was probably chosen as a cemetery. About 80 small tombs were here before the magnificent massive stone structure appeared.'},
#  {'id': 1157340,
#   'x': -18645,
#   'y': 560475,
#   'entities': (Loughros Beg Bay, Maghera),
#   'text': 'The mountain slopes downward to Loughros Beg Bay and the beach at Maghera. Caves in the mountainside are said to be accessible only at low tide.'},
#  {'id': 1161330,
#   'x': -17190,
#   'y': 565357,
#   'entities': (Loughros More Bay, Maghera),
#   'text': 'This strand is off Loughros More Bay. The mountains south of the road to Maghera are shown in the background.'},
#  {'id': 1160205,
#   'x': -17030,
#   'y': 561251,
#   'entities': (Loughroa Beg Bay, Maghera),
#   'text': 'Behind the buildings are Loughroa Beg Bay and the road to Maghera at the base of the mountains.'},
#  {'id': 1161325,
#   'x': -16538,
#   'y': 566045,
#   'entities': (Maghera,),
#   'text': 'Loughros More Bay and the mountains south of the road to Maghera are in the background.'},
#  {'id': 495296,
#   'x': -21282,
#   'y': 513134,
#   'entities': (Benbulben, Ireland, Ireland, Table Mountain),
#   'text': "Benbulben is Ireland's most distinctive mountain and known in some parts as Ireland's version of Table Mountain. http://www.panoramio.com/user/574636"},
#  {'id': 724689,
#   'x': -21118,
#   'y': 514819,
#   'entities': (Keelty, Ben Bulben),
#   'text': 'The track from Keelty going up Ben Bulben. Clouds lifting to show the steep crags of the mountain.'},
#  {'id': 2553703,
#   'x': -16163,
#   'y': 539161,
#   'entities': (Donegal Town,),
#   'text': 'Rough pasture looking towards Donegal Town and the mountains.'},
#  {'id': 1149393,
#   'x': -16864,
#   'y': 517784,
#   'entities': (Cliffony,),
#   'text': 'Fields and mountains seen from road travelling south from Cliffony to Benwisken and Gleniff Horseshoe Drive.'},
#  {'id': 1053381,
#   'x': -12463,
#   'y': 560939,
#   'entities': (Irish, Irish, Fionn McCumhaill, Owenea),
#   'text': 'Irish folklore states that this stone was thrown by an Irish folk hero called Fionn McCumhaill from a nearby mountain to land in the adjacent Owenea river.'},
#  {'id': 1165427,
#   'x': -16366,
#   'y': 515720,
#   'entities': (),
#   'text': 'Truskmore is at the left and the Cliffs of Annacoona are at the right. A bridge at the bottom of the road descending to the base of these mountains crosses the stream fed by the waterfall.'},
#  {'id': 980431,
#   'x': -16242,
#   'y': 505405,
#   'entities': (R286, Keelogyboy Mountain),
#   'text': 'Seen from a spectacular viewpoint at a layby on the R286. The mountain on the skyline to the right is Keelogyboy Mountain [[G7638]].'},
#  {'id': 1157715,
#   'x': -11309,
#   'y': 559382,
#   'entities': (Maghera,),
#   'text': 'The mountains shown are located to the SW along the road to Maghera.'},
#  {'id': 1154505,
#   'x': -15160,
#   'y': 517135,
#   'entities': (),
#   'text': 'Eventually the road winds around the mountains right at the base.'},
#  {'id': 1149192,
#   'x': -14938,
#   'y': 517730,
#   'entities': (),
#   'text': 'View of mountains (Cliffs of Annacoona) at the beginning of the drive in a clockwise direction.'},
#  {'id': 1702864,
#   'x': -10673,
#   'y': 554502,
#   'entities': (Maol Masóg,),
#   'text': 'High open ground at the foot of Maol Masóg mountain.'},
#  {'id': 1038355,
#   'x': -13589,
#   'y': 513395,
#   'entities': (Cope,
#    Sligo Harbour,
#    Discovery Series,
#    Approx,
#    275 metres,
#    902 feet),
#   'text': "Cope's mountain can be seen on the left with Sligo Harbour (As named on the Discovery Series map No.16) in the distance. Elevation Approx. 275 metres. (902 feet)"},
#  {'id': 1132452,
#   'x': -4304,
#   'y': 553624,
#   'entities': (Binbane,),
#   'text': 'Binbane mountain is dusted with snow here.'},
#  {'id': 2871432,
#   'x': -3431,
#   'y': 557853,
#   'entities': (Shallogan Beg,),
#   'text': 'With Shallogan Beg mountain beyond.'},
#  {'id': 552713,
#   'x': -28157,
#   'y': 276450,
#   'entities': (),
#   'text': 'This is the early mist moving off the mountain.'},
#  {'id': 799392,
#   'x': -7260,
#   'y': 506277,
#   'entities': (Manorhamilton, Leean),
#   'text': 'Off the R286 Dromahair to Manorhamilton road. Various rocky outcrops can be seen to the east of Leean mountain.'},
#  {'id': 1057793,
#   'x': -2611,
#   'y': 557188,
#   'entities': (Owenroe, Carnaween),
#   'text': 'The Owenroe river flows down from Carnaween mountain'},
#  {'id': 1058023,
#   'x': -1993,
#   'y': 553606,
#   'entities': (Binbane,),
#   'text': 'Binbane is the name of the mountain (453m)'},
#  {'id': 3265490,
#   'x': -1926,
#   'y': 552195,
#   'entities': (Bilbane,),
#   'text': 'The mountain in the background is Bilbane.'},
#  {'id': 2765170,
#   'x': -1663,
#   'y': 555028,
#   'entities': (),
#   'text': 'Climbing Binbane (Binn Bán) looking east at Caraween mountain.'},
#  {'id': 1139713,
#   'x': 2988,
#   'y': 592131,
#   'entities': (Winter, Cronalaght, 280 metres, 919 feet),
#   'text': 'Winter storm damage to wind generator at Cronalaght mountain wind farm. Elevation 280 metres (919 feet)'},
#  {'id': 1031522,
#   'x': -22696,
#   'y': 290734,
#   'entities': (Blackrock River,),
#   'text': 'Old mountain trackway giving access to peat cutting site high above the Blackrock River valley. Galtymore summit in background.'},
#  {'id': 856685,
#   'x': 1252,
#   'y': 551719,
#   'entities': (Bluestack,),
#   'text': 'In the low hills south of the Bluestack mountains.'},
#  {'id': 1630946,
#   'x': -4233,
#   'y': 485894,
#   'entities': (the Arigna Valley, Geevagh),
#   'text': 'The mountain road winds its way high above the Arigna Valley (otherwise known as "the Glen") before crossing the ridge and dropping down to Geevagh.'},
#  {'id': 856526,
#   'x': 1987,
#   'y': 554773,
#   'entities': (the Blue Stack Way, Donegal),
#   'text': 'Part of the walking trail known as the Blue Stack Way. This is the part that crosses the lower western side of the mountain range and can be accessed from Donegal town.'},
#  {'id': 844890,
#   'x': 3038,
#   'y': 549455,
#   'entities': (Bluestack,),
#   'text': 'Bluestack mountains in the distance'},
#  {'id': 2214475,
#   'x': -18735,
#   'y': 294606,
#   'entities': (Cush, the Galty Mountains),
#   'text': 'Crags and peat hags close to summit of Cush (639m) mountain in the Galty Mountains.'},
#  {'id': 431325,
#   'x': 7295,
#   'y': 587287,
#   'entities': (),
#   'text': 'Derryveagh mountains in distance'},
#  {'id': 2462547,
#   'x': 8318,
#   'y': 589030,
#   'entities': (Mount Errigal,),
#   'text': 'The mountain in the distance is Mount Errigal'},
#  {'id': 2312846,
#   'x': -16720,
#   'y': 291885,
#   'entities': (Galtee, about 6 metres),
#   'text': "This natural cairn is a very popular focal point for hikers.   Usually the place to stop for a rest/lunch when walking to/from Greenane or Farbreaga - two peaks on the Galtee mountain range.   Plenty of nooks and crannies there to shelter from the wind and rain.  It's about 6 metres high at it's highest point."},
#  {'id': 798051,
#   'x': 109,
#   'y': 486720,
#   'entities': (Lough Allen,),
#   'text': 'A visitor attraction on the mountain above Lough Allen. Best seen in the morning when the light would be more favourable.'},
#  {'id': 1189910,
#   'x': 8998,
#   'y': 586628,
#   'entities': (The Poison Glen, first),
#   'text': 'As seen looking northeast from walled churchyard of derelict church. The Poison Glen is behind the first mountainside shown in the photo beyond the trees.'},
#  {'id': 501846,
#   'x': 8555,
#   'y': 579740,
#   'entities': (),
#   'text': 'The mist is still on the mountain tops'},
#  {'id': 833538,
#   'x': -16126,
#   'y': 292378,
#   'entities': (518, Lough Muskry),
#   'text': 'Unnamed mountain lake (518m) above Lough Muskry viewed from gulley leading to summit ridge.'},
#  {'id': 833506,
#   'x': -15799,
#   'y': 294623,
#   'entities': (Lough Muskry,),
#   'text': 'Hikers on mountain track to Lough Muskry.'},
#  {'id': 1052805,
#   'x': 9595,
#   'y': 588546,
#   'entities': (Errigal, the south east),
#   'text': "The northern approach to Errigal. The last part of the ascent is up a rocky scree slope. There is a faint path running up the crest of the ridge which veers to the right in a couple of spots before reaching the summit. This route is far more rewarding than ascending via the 'Tourist Path' on the south east side of the mountain."},
#  {'id': 1913882,
#   'x': 7273,
#   'y': 552178,
#   'entities': (),
#   'text': 'Sruell mountain rising to the north.'},
#  {'id': 1913797,
#   'x': 7080,
#   'y': 549702,
#   'entities': (),
#   'text': 'Clear views over the town and bay with county Sligo mountains beyond.'},
#  {'id': 1424491,
#   'x': 11279,
#   'y': 587095,
#   'entities': (R251, Errigal, Donegal),
#   'text': 'The R251 road beneath Errigal mountain in Donegal.'},
#  {'id': 369275,
#   'x': 7788,
#   'y': 546233,
#   'entities': (Millennium, Blue Stack),
#   'text': 'The monument was erected for the Millennium to show some of the local history in pictures inside the structure. The Blue Stack mountains are in the distance. '},
#  {'id': 1516507,
#   'x': -13493,
#   'y': 294310,
#   'entities': (Sturrakeen,),
#   'text': 'Heathland and forest with Sturrakeen mountain in the distance.'},
#  {'id': 3143988,
#   'x': 10229,
#   'y': 563807,
#   'entities': (R253,),
#   'text': 'View of the mountain from the side of the R253.'},
#  {'id': 3219870,
#   'x': 9879,
#   'y': 540638,
#   'entities': (),
#   'text': 'This is the mountain road to Castlederg in Co Tyrone.'},
#  {'id': 1052765,
#   'x': 14369,
#   'y': 589361,
#   'entities': (),
#   'text': 'Errigal is the mountain in the centre distance.'},
#  {'id': 1907093,
#   'x': 11628,
#   'y': 552327,
#   'entities': (Loch Eske,),
#   'text': 'On the easterly side of Loch Eske looking north towards the mountains.'},
#  {'id': 565949,
#   'x': 12872,
#   'y': 557457,
#   'entities': (Blue Stacks,),
#   'text': 'Wonderful rocky scenery on a high level round of the Blue Stacks mountains'},
#  {'id': 1089825,
#   'x': 10880,
#   'y': 503764,
#   'entities': (Loughross,),
#   'text': 'Looking northwards; the mountainside at Loughross is in the distance'},
#  {'id': 408555,
#   'x': 15152,
#   'y': 551231,
#   'entities': (Lowerymore, Barnes, Blue Stack, Donegal, Lough Eske, 451),
#   'text': 'The Lowerymore river flows through the Barnes gap after rising in the Blue Stack mountains in Donegal. It flows into Lough Eske. In the background is Barnesmore 451m. '},
#  {'id': 51550,
#   'x': 19323,
#   'y': 588060,
#   'entities': (Lough, Gleann Bheatha, Glenveath Castle),
#   'text': 'This is the view southwest across Lough Gleann Bheatha you have from the lookout point on the mountains behind Glenveath Castle'},
#  {'id': 730883,
#   'x': -6689,
#   'y': 278466,
#   'entities': (The Vee in the Knockmealdown Mountains,),
#   'text': 'Bridge carrying  the R668 over a mountain stream close to The Vee in the Knockmealdown Mountains.'},
#  {'id': 216241,
#   'x': -5333,
#   'y': 278898,
#   'entities': (the Knockmealdown Mountains, two, Cahir, the River Tar),
#   'text': 'Picture taken from the Knockmealdown Mountains. The wide vale between the two mountain ranges contains the town of Cahir and the River Tar (itself a tributary of the River Suir).'},
#  {'id': 1586730,
#   'x': 13552,
#   'y': 485827,
#   'entities': (Ulster (, Ultachs, the early 1500s, July 2005),
#   'text': 'The inscription reads "To commemorate the settlers from Ulster (the Ultachs) who came here to live on the mountainside in the early 1500s." Dated July 2005'},
#  {'id': 1367883,
#   'x': 22694,
#   'y': 562523,
#   'entities': (Meenagrave, Altnapaste),
#   'text': 'Looking south-west across Meenagrave townland towards Altnapaste mountain.'},
#  {'id': 1367891,
#   'x': 23366,
#   'y': 562968,
#   'entities': (),
#   'text': 'An attractive primary school situated on a hill over-looking the River Finn valley and with a direct view of the mountains to the south-west.'},
#  {'id': 2038191,
#   'x': 20380,
#   'y': 494606,
#   'entities': (),
#   'text': 'Photo of the mountain on the way towards the cairn.'},
#  {'id': 1090726,
#   'x': 11337,
#   'y': 347303,
#   'entities': (The Devils Bit, Devil, The Rock of Cashel),
#   'text': 'This area is dominated by the mountains in the distance known locally as The Devils Bit the missing bit being hurled by the Devil and is now believed to be The Rock of Cashel.'},
#  {'id': 1453614,
#   'x': 25886,
#   'y': 496946,
#   'entities': (Benaughlin, Trien),
#   'text': 'View of the mountainside between Benaughlin and Trien'},
#  {'id': 287099,
#   'x': 35680,
#   'y': 602931,
#   'entities': (Fanad, Fanad, Mulroy Bay, Knockalla, Inishowen, Lough),
#   'text': 'This is the area called between the waters on the Fanad peninsula. Fanad is a peninsula between Lough Swilly and Mulroy Bay and between the waters is a peninsula within that peninsula (look at the map!.) On the right background are the Knockalla mountains and on the left are the Inishowen mountains which are actually on the other side of Lough Swilly'},
#  {'id': 1254017,
#   'x': 17109,
#   'y': 370937,
#   'entities': (Slieve Bloom,),
#   'text': 'This attractive village is the western gateway to the Slieve Bloom mountains.  This is an unnamed stream channelled through the village green.'},
#  {'id': 1254067,
#   'x': 21217,
#   'y': 369728,
#   'entities': (Slieve Bloom,),
#   'text': 'The R440 climbs into the Slieve Bloom mountains along the north side of the valley.  In this square is climbs higher into the forested area.'},
#  {'id': 390154,
#   'x': 36208,
#   'y': 544802,
#   'entities': (Bin,),
#   'text': 'Bin mountain is in the distance.'},
#  {'id': 233266,
#   'x': 16701,
#   'y': 280461,
#   'entities': (Glenanore, Knockanaffrin),
#   'text': 'A narrow mountain road serving farms in Glenanore under 755m high Knockanaffrin.'},
#  {'id': 798928,
#   'x': 43458,
#   'y': 608279,
#   'entities': (Inishowen,),
#   'text': 'View of Lough Swilly and Inishowen mountains'},
#  {'id': 2340421,
#   'x': 19376,
#   'y': 274924,
#   'entities': (Coumalocha Lakes,),
#   'text': 'A seemingly new roadway scarring the mountainside above Coumalocha Lakes.'},
#  {'id': 865842,
#   'x': 45258,
#   'y': 600728,
#   'entities': (An Oige Youth Hostel,
#    Bunnaton,
#    Bunnington,
#    Shadows,
#    Knockalla Mountain),
#   'text': 'This is a view of what used to be An Oige Youth Hostel in Bunnaton (also sometimes known as Bunnington) Glenvar.  Prior to it being a youth hostel it was also a Coastguard Station. The hostel is now holiday accommodation and run by the Hewitt Family.  The expanse of water is Lough Swilly - the Lake of Shadows) and the mountains in the background is Knockalla Mountain.'},
#  {'id': 2438516,
#   'x': 69500,
#   'y': 870190,
#   'entities': (South Uist's,),
#   'text': "South Uist's mountain chain on the horizon"},
#  {'id': 118427,
#   'x': 42704,
#   'y': 527967,
#   'entities': (),
#   'text': 'There is a windmill farm on the distant mountain'},
#  {'id': 1823118,
#   'x': 24265,
#   'y': 288524,
#   'entities': (),
#   'text': 'The barn sits in poor quality pasture north of the N24.  The mountain behind is Slievenamon in [[S2930]]'},
#  {'id': 1823120,
#   'x': 24617,
#   'y': 288525,
#   'entities': (),
#   'text': 'Good quality pasture north of the N24.  The mountain behind is Slievenamon in [[S2930]]'},
#  {'id': 326115,
#   'x': 43861,
#   'y': 516815,
#   'entities': (Brougher,),
#   'text': 'Looking north-east towards Brougher mountain.'},
#  {'id': 326125,
#   'x': 44012,
#   'y': 517405,
#   'entities': (Brougher,),
#   'text': 'Looking towards Brougher mountain.'},
#  {'id': 326012,
# ...
#   'entities': (Utilikilt,),
#   'text': 'The figure is wearing an Utilikilt - great for walking in. The mountain behind is An Laogh.'},
#  {'id': 1110143,
#   'x': 211980,
#   'y': 825400,
#   'entities': (the Great Glen, second, day),
#   'text': 'The highest mountain north of the Great Glen seen from the second highest on day of spectacular cloud inversion with just 5 peaks making it through from our vantage point - 2008 going out in style!'},
#  {'id': 2446660,
#   'x': 207689,
#   'y': 726830,
#   'entities': (Oban,),
#   'text': 'The road (on the right) is the main route to Oban; the main rail line heads parallel but sits higher on the mountain.'},
#  {'id': 2472400,
#   'x': 213720,
#   'y': 858580,
#   'entities': (),
#   'text': "Loch a' Chroisg means the loch of the crossing. Presumably crossing between the mountains on either side."},
#  {'id': 1270285,
#   'x': 216199,
#   'y': 911910,
#   'entities': (Stac Pollaidh,),
#   'text': 'The mountain of Cul Mor from the western end of Stac Pollaidh'},
#  {'id': 1130356,
#   'x': 212319,
#   'y': 825640,
#   'entities': (),
#   'text': "Pretty impressive mountain scenery and you can have it all to yourself if you're there at the right time."},
#  {'id': 3021140,
#   'x': 214040,
#   'y': 862250,
#   'entities': (Fisherfield,),
#   'text': 'Looking towards the remote mountains of Fisherfield.'},
#  {'id': 229272,
#   'x': 209900,
#   'y': 768700,
#   'entities': (Lundavra,),
#   'text': 'Showing the road to Lundavra.  The mountain shrouded in cloud is Meall a Chaorainn.'},
#  {'id': 2497315,
#   'x': 209500,
#   'y': 758600,
#   'entities': (Glencoe,),
#   'text': 'With the Glencoe mountains in the background.'},
#  {'id': 1915407,
#   'x': 211339,
#   'y': 795660,
#   'entities': (Loch Arkaig,),
#   'text': 'Looking out across a fairly featureless bit of moorland from the slopes of a rarely climbed mountain north of Loch Arkaig.'},
#  {'id': 827313,
#   'x': 217339,
#   'y': 911620,
#   'entities': (Cul Mor, cairns),
#   'text': 'On the eastern ridge of Cul Mor.  Why do people feel the need to build useless cairns?  These serve no purpose and put needless human intrusion into the mountains. I passed and there are fewer now.'},
#  {'id': 2211129,
#   'x': 214839,
#   'y': 856020,
#   'entities': (Inver,),
#   'text': 'The boarded walkway goes towards the mountaineering hut at Inver.'},
#  {'id': 2514335,
#   'x': 215040,
#   'y': 860260,
#   'entities': (Creagan nan Laogh, Graham, Teallach),
#   'text': "A view over bog and moorland on the south-west side of Creagan nan Laogh to the Graham of Meall a' Chaorainn. An Teallach is the mountain range to the right of Meall a' Chaorainn"},
#  {'id': 1459258,
#   'x': 212970,
#   'y': 813880,
#   'entities': (Early April,),
#   'text': 'Early April and snow still on the mountains.'},
#  {'id': 2187621,
#   'x': 209380,
#   'y': 728180,
#   'entities': (),
#   'text': 'Low cloud over the loch - not sure if it was a true cloud inversion as the air on the mountainside was frigid rather than mild.'},
#  {'id': 2280931,
#   'x': 214099,
#   'y': 831060,
#   'entities': (Loch Mullardoch,),
#   'text': "A most convenient 'lift' from the dam to the Seldom Inn giving access to the mountains north of Loch Mullardoch."},
#  {'id': 2420452,
#   'x': 213910,
#   'y': 826700,
#   'entities': (Tom, Chòinich),
#   'text': "Seen from Stob a' Choire Dhomhain. Tom a' Chòinich is the mountain beyond."},
#  {'id': 1406522,
#   'x': 209709,
#   'y': 733490,
#   'entities': (),
#   'text': 'With the rest of the mountain in the cloud.'},
#  {'id': 2420488,
#   'x': 213930,
#   'y': 826710,
#   'entities': (Coire Domhnuill, Sgùrr, Lapaich),
#   'text': 'Seen from Stob Coire Domhnuill. Sgùrr na Lapaich is the distant mountain.'},
#  {'id': 505485,
#   'x': 210469,
#   'y': 749260,
#   'entities': (nan Gobhar, Beinn Fhionnlaidh marks),
#   'text': "The shallow col between Meall nan Gobhar and the main massif of Beinn Fhionnlaidh marks a change from grassy slopes to fairly steep rough hillside which must be climbed to gain the mountain's ridge. The summit can be seen ahead."},
#  {'id': 2732953,
#   'x': 215590,
#   'y': 862110,
#   'entities': (Fionn Bheinn, Achnasheen),
#   'text': 'This is a far more pleasant and interesting approach to Fionn Bheinn than ascending this mountain directly from Achnasheen.'},
#  {'id': 1246290,
#   'x': 217860,
#   'y': 910960,
#   'entities': (Cul Mor, Creag nan Calman),
#   'text': 'The return leg from an excellent walk up Cul Mor and Creag nan Calman. Cul Mor offers wonderful views into the Assynt wilderness and is a relatively easy mountain to climb.'},
#  {'id': 1976182,
#   'x': 210850,
#   'y': 756180,
#   'entities': (),
#   'text': 'The last light of the evening was bouncing of the mountains'},
#  {'id': 1676493,
#   'x': 213310,
#   'y': 810080,
#   'entities': (Loch Cluanie, Glen Shiel),
#   'text': 'With a view of Loch Cluanie and the Glen Shiel mountains to welcome you.'},
#  {'id': 2514327,
#   'x': 215720,
#   'y': 859230,
#   'entities': (Sìne,
#    Achnasheen,
#    nan Laogh,
#    Achnasheen,
#    the River Bran,
#    Sgurr a Mhuilinn/Meall),
#   'text': 'The Allt Achadh na Sìne follows a remarkably straight course as it descends towards Achnasheen below Creagan nan Laogh; Achnasheen is the small settlement at the right side of the image beside the River Bran. Peaks of the Sgurr a\x92 Mhuilinn/Meall nan Uan group are the prominent skyline mountains.'},
#  {'id': 3074272,
#   'x': 213759,
#   'y': 812050,
#   'entities': (Loch Cluanie, the South Glen Shiel),
#   'text': 'Loch Cluanie far below backed by the mountains of the South Glen Shiel ridge.'},
#  {'id': 764023,
#   'x': 211199,
#   'y': 751800,
#   'entities': (Glen Coe,),
#   'text': 'Looking across the split top of Sgor na h-Ulaidh to the Glen Coe mountains.'},
#  {'id': 2474521,
#   'x': 218379,
#   'y': 909610,
#   'entities': (Cul Mor,),
#   'text': 'The grassy slopes on the east side of Cul Mor from the start of the path leading to the mountain. The summit is visible in the middle distance.'},
#  {'id': 458238,
#   'x': 220739,
#   'y': 959380,
#   'entities': (Loch Aisir Mòr, Foinaven, Arkle),
#   'text': 'In the middle distance is Loch Aisir Mòr; behind are the distinctive mountains Foinaven and Arkle.'},
#  {'id': 213586,
#   'x': 216799,
#   'y': 872200,
#   'entities': (Loch Fannaich,),
#   'text': "This ancient path leads through the mountains from Loch a'Bhraoin to Loch Fannaich."},
#  {'id': 626656,
#   'x': 212840,
#   'y': 778590,
#   'entities': (Ben Nevis,),
#   'text': 'Looking south-east across the canal to a cloud-covered Ben Nevis. The water pipeline down the mountainside provides hydroelectricity for the aluminium works to the right.'},
#  {'id': 2973036,
#   'x': 210939,
#   'y': 731710,
#   'entities': (the Allt Mhoille, Cruachan, the Cruachan Reservoir),
#   'text': 'These intakes abstract water from the headwaters of the Allt Mhoille. The water is conveyed by many miles of tunnels under the Cruachan mountains into the Cruachan Reservoir.'},
#  {'id': 2478762,
#   'x': 219860,
#   'y': 929180,
#   'entities': (),
#   'text': "Looking at the connecting ridge to the mountain's northern summit."},
#  {'id': 1377530,
#   'x': 211740,
#   'y': 745590,
#   'entities': (Loch Etive, Ben Cruachan),
#   'text': 'The final bit of the river as it enters Loch Etive. Ben Cruachan is the mountain in the distance.'},
#  {'id': 2302467,
#   'x': 207809,
#   'y': 657200,
#   'entities': (),
#   'text': 'The Sleeping Warrior can be seen if you look along the silhouette of the mountain ridge.'},
#  {'id': 178025,
#   'x': 212099,
#   'y': 748800,
#   'entities': (Glen Etive,),
#   'text': 'Looking south-east over the forest to the mountains on the east side of Glen Etive'},
#  {'id': 94248,
#   'x': 212200,
#   'y': 750800,
#   'entities': (Meall a' Bhuiridh,
#    Stob Coir',
#    Scotsman,
#    Glas Bheinn Mhòr,
#    Glen Etive),
#   'text': 'Looking south-east past the summit of Meall a\' Bhuiridh ("mountain of the howling") to Stob Coir\' an Albannaich ("peak of the corrie of the Scotsman") and Glas Bheinn Mhòr ("big green mountain") on the other side of Glen Etive.  The date on the photograph is a mistake.'},
#  {'id': 492086,
#   'x': 215940,
#   'y': 834170,
#   'entities': (Riabhachan,),
#   'text': 'The white stones on the slopes give the mountain its name. Beyond lies the mighty An Riabhachan.'},
#  {'id': 632968,
#   'x': 212080,
#   'y': 741790,
#   'entities': (Ben Starav, west flank, 50ft high),
#   'text': "Ben Starav is a granite mountain being eroded away by streams like this on its west flank. Here the water flows over a 'sill' creating a waterfall over 50ft high."},
#  {'id': 756257,
#   'x': 217930,
#   'y': 870500,
#   'entities': (one,),
#   'text': 'From the bealach a climb up this shallow coire will give a reasonable route to the col north of the mountain. The line of cliffs high up may give pause for thought; the grassy bit in the centre of the picture or one a bit to the left are probably the best choices.'},
#  {'id': 624936,
#   'x': 212939,
#   'y': 756460,
#   'entities': (afternoon, Glen Coe),
#   'text': 'A rare sunny afternoon in Glen Coe. The mountain behind is Aonach Dubh'},
#  {'id': 2445997,
#   'x': 213380,
#   'y': 761310,
#   'entities': (),
#   'text': 'Grasslands populate the area between the road and loch while a majestic mountain overlooks the scene from the north.'},
#  {'id': 1108379,
#   'x': 216150,
#   'y': 820250,
#   'entities': (Carn Glas Iochdarach,
#    Affric Munros of,
#    Carn Eighe,
#    Mam Sodhail),
#   'text': 'Looking north from the minor summit of Carn Glas Iochdarach to the big Affric Munros of Carn Eighe and Mam Sodhail - the highest mountains north of the great glen.'},
#  {'id': 629565,
#   'x': 218579,
#   'y': 872940,
#   'entities': (Sgurr nan,),
#   'text': 'Taken from across the col connecting the mountain with Sgurr nan Clach Geala.'},
#  {'id': 2973018,
#   'x': 212569,
#   'y': 731470,
#   'entities': (about four weeks, Argyll),
#   'text': 'Looking up a very dry mountain stream after about four weeks without significant rainfall in Argyll.'},
#  {'id': 2420174,
#   'x': 216810,
#   'y': 823060,
#   'entities': (Loch Affric, 887300),
#   'text': 'Looking over native woodland to Loch Affric and the mountain rising behind. Taken virtually at the same spot as [[887300]] but under very different conditions; a heat wave was in progress.'},
#  {'id': 451940,
#   'x': 223379,
#   'y': 966290,
#   'entities': (Sandwood Bay,),
#   'text': 'This mountain stream descends in a series of small waterfalls to the beach at the northern end of Sandwood Bay. Walkers bound for Cape Wrath have to traverse the stream.'},
#  {'id': 67481,
#   'x': 191300,
#   'y': 225200,
#   'entities': (Plumstone,),
#   'text': 'Photo taken from Plumstone mountain. The Preseli Hills can just be seen in the distance.'},
#  {'id': 3191616,
#   'x': 213770,
#   'y': 745820,
#   'entities': (Allt Mheuran, the River Etive, Beinn Trilleachan),
#   'text': 'The Allt Mheuran drains into the River Etive.  Beinn Trilleachan is the mountain in the background.'},
#  {'id': 826419,
#   'x': 221410,
#   'y': 913330,
#   'entities': (),
#   'text': 'Most of this shore is made up of blocks of shattered quartzite - not comfortable to walk on.  It is this quartzite which gives the white appearance to many of the mountain tops around here.'},
#  {'id': 3191749,
#   'x': 213970,
#   'y': 742290,
#   'entities': (Bealachan Lochain Ghaineamhaich,),
#   'text': 'Looking back towards the mountain from the slope below Bealachan Lochain Ghaineamhaich.'},
#  {'id': 1817947,
#   'x': 215079,
#   'y': 765490,
#   'entities': (),
#   'text': 'A beautifully sculpted rock mountain in the Mamores'},
#  {'id': 1651718,
#   'x': 222720,
#   'y': 933820,
#   'entities': (),
#   'text': 'Quinag is the mountain in the distance'},
#  {'id': 891724,
#   'x': 213739,
#   'y': 727670,
#   'entities': (Kilchurn Castle, Ben Lui),
#   'text': 'A view from the towerhouse of Kilchurn Castle. The prominent mountain is Ben Lui.'},
#  {'id': 25200,
#   'x': 214500,
#   'y': 744500,
#   'entities': (),
#   'text': 'Looking from the waterfall SW along the river to the mountains beyond.'},
#  {'id': 2421252,
#   'x': 218619,
#   'y': 833340,
#   'entities': (Carn Eige,),
#   'text': 'Taken from the southern slopes where the steeper stony ground of higher up has given way to moderately sloping moss. Carn Eige is the distant mountain in the centre.'},
#  {'id': 1035341,
#   'x': 220339,
#   'y': 871790,
#   'entities': (),
#   'text': 'With the cairn perched close to the east face of the mountain.'},
#  {'id': 510523,
#   'x': 216240,
#   'y': 776230,
#   'entities': (2007, World Championship),
#   'text': 'Part of 2007 World Championship mountain bike cross country trail'},
#  {'id': 2871462,
#   'x': 215140,
#   'y': 749640,
#   'entities': (The Lairig Gartain, two),
#   'text': 'The Lairig Gartain pass separates the two mountains'},
#  {'id': 2421217,
#   'x': 219139,
#   'y': 834700,
#   'entities': (Carn nan Gobhar,),
#   'text': 'Looking across the northern slopes of Carn nan Gobhar to the mountain.'},
#  {'id': 1535644,
#   'x': 223280,
#   'y': 927330,
#   'entities': (),
#   'text': 'Looking over the A894 and the rough moorland beyond to the mountain.'},
#  {'id': 820967,
#   'x': 224579,
#   'y': 954210,
#   'entities': (Drystane, Loch Inchard, Arcuil),
#   'text': 'Drystane dykes and ruined gables are relics of former crofts on this slope towards Loch Inchard. The distant mountain is the western buttress of Arcuil (Arkle).'},
#  {'id': 49673,
#   'x': 217500,
#   'y': 794500,
#   'entities': (681,),
#   'text': 'Here are some highland sheep on a subsidiary  summit (681m - no name is given) of the mountain in the next square.'},
#  {'id': 1342812,
#   'x': 216500,
#   'y': 771500,
#   'entities': (UK, Fort William, Scotland),
#   'text': 'The highest mountain in the UK located by Fort William in the Highlands of Scotland.'},
#  {'id': 267394,
#   'x': 215500,
#   'y': 744500,
#   'entities': (Stob Dearg,),
#   'text': 'Stob Dearg is mountain centre top.'},
#  {'id': 270207,
#   'x': 216500,
#   'y': 766500,
#   'entities': (Allt Coire, Binnein Mor),
#   'text': 'Taken from Sgurr a Mhaim overlooking Allt Coire a Mhail. Centre flattish mountain being Binnein Mor.'},
#  {'id': 1237895,
#   'x': 220060,
#   'y': 846870,
#   'entities': (),
#   'text': 'Beginning the descent down the shoulder of the mountain.'},
#  {'id': 2491227,
#   'x': 216830,
#   'y': 772210,
#   'entities': (CIC,),
#   'text': 'A look back down on the CIC mountaineering hut way below.'},
#  {'id': 2302831,
#   'x': 224460,
#   'y': 933510,
#   'entities': (),
#   'text': 'Loch and mountains. Pictured from a boat'},
#  {'id': 820938,
#   'x': 225439,
#   'y': 952130,
#   'entities': (Arcuil,),
#   'text': 'The more elevated viewpoint on the new bridge provides a much more satisfying view than was previously possible. The mountain in the distance is Arcuil (Arkle).'},
#  {'id': 1593926,
#   'x': 216419,
#   'y': 743650,
#   'entities': (Glas Bheinn Mhòr, east ridge),
#   'text': "Looking over the steep-sided col which separates the mountain from Glas Bheinn Mhòr. Taken from the tip of the latter's east ridge."},
#  {'id': 755019,
#   'x': 216529,
#   'y': 743620,
#   'entities': (Glas Bheinn Mhor,
#    Coir,
#    Albannaich,
#    Munro,
#    the north west ridge),
#   'text': "Taken from the top of the climb from the col which links the mountain to Glas Bheinn Mhor. The dip directly ahead is the head of Coir' an Albannaich; the easiest approach to the Munro's summit is to take a curving route around the head of the coire to land on the north west ridge."},
#  {'id': 1901888,
#   'x': 218863,
#   'y': 796634,
#   'entities': (),
#   'text': 'The mountain in the cloud is Meall a Choire Ghlais.'},
#  {'id': 1101280,
#   'x': 218119,
#   'y': 776380,
#   'entities': (),
#   'text': 'The gondolas are an easy way for the less fit to experience something of the mountains.'},
#  {'id': 1811883,
#   'x': 217799,
#   'y': 768380,
#   'entities': (),
#   'text': 'Cottage owned by a mountaineering club and used as remote accommodation by club members and guests. Access by rope bridge shown by a person crossing.'},
#  {'id': 699018,
#   'x': 218400,
#   'y': 775410,
#   'entities': (),
#   'text': 'The mist was rolling in up the mountain'},
#  {'id': 3162205,
#   'x': 217110,
#   'y': 744260,
#   'entities': (Stob Coir, Tarsuinn),
#   'text': 'Looking back up towards the summit from the descent to the col between Stob Coir an Albannaich and Meall Tarsuinn.  A couple of walkers are climbing the distinctive spur of the mountain.'},
#  ...]

# %% [markdown]
# This block of code does the comparisons. It iterates through all the Geograph documents and does the following:
#
# - For each document it returns all the toponyms in the gazetteer cell at that location
# - Compares each name found by the NER to the list of toponyms in the gazetteer cell, and
# - Annotates the names as either existing (found in the gazetteer) or new (new names)
#
# If we change the sample of names, or the resolution of the gazetteer, then the results of the following **comparison** should change.

# %%
#Now we are going to compare the gazetteer names with those we found

data = list()
#We iterate through all our results
for dict in results:
    #First we get the cell indices for the gazetteer
    x = dict.get("x")
    y = dict.get("y")
    i = int((x - minx)/cellSize)
    j = int((y - minx)/cellSize)
    try:
        #Now we find the names in that cell - n.B. we ignore for now the fact that Geograph cell could be at a boundary
        gazNames = gaz.at[i,j]
        #Deal with a cell having no values in the gazetteer
        if (isinstance(gazNames,set) == False): 
            #print(type(gazNames))
            gazNames = {"NoNamesFound"}
    except KeyError:
        gazNames = {"NoNamesFound"}
    #Get back the named entities for the text        
    ents = dict.get("entities")
    #Now we iterate through, and find out if each name is already in the local gazetteer
    for ent in ents:        
        if (ent.text in gazNames):
            data.append([dict.get("id"), "Existing", ent.text, ent.label_, x, y]) 
            #print("Found existing name:", ent.text, ent.label_)
        else:
            #print("Potential new name:" , ent.text, ent.label_)
            data.append([dict.get("id"), "New", ent.text, ent.label_, x, y]) 
#Store the results in a dataframe
df = pd.DataFrame(data, columns = ['id', 'status','name','type','x','y'])
df
# Out:
#            id status                      name         type       x       y
# 0     1433792    New                Tiorabhain          GPE -177082  284686
# 1       16676    New               320 degrees     QUANTITY -176779  278272
# 2      220144    New                    Ventry          GPE -175828  282689
# 3      220144    New                Dun Chaoin          ORG -175828  282689
# 4      220144    New                 about 185     CARDINAL -175828  282689
# ...       ...    ...                       ...          ...     ...     ...
# 4963  2701887    New                       one     CARDINAL  580179  283970
# 4964   517571    New         'The Black Route'  WORK_OF_ART  581229  283450
# 4965   517571    New   Thetford Forest Suffolk          ORG  581229  283450
# 4966   517571    New                info board          ORG  581229  283450
# 4967   516285    New  High Lodge Forest Centre          ORG  582600  284320
#
# [4968 rows x 6 columns]

# %%
#Split results into existing and candidate names for reporting
new = df.loc[df['status'] == 'New']
existing = df.loc[df['status'] == 'Existing']

# %% [markdown]
# We output the new names we found for the class 'PERSON'. You could calculate precision here by judging how many of these are really toponyms (since we assume implicitly that 'PERSON' names are actually toponyms).

# %%
#Let's look at one example NER class in the candidate names
names = new.loc[new['type'] == 'PERSON']

with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(names)
# Out:
#            id status                                  name    type       x  \
# 10     220050    New                      Smerwick Harbour  PERSON -173912
# 19     219278    New                                 Cosan  PERSON -165856
# 20     219278    New                                 Naomh  PERSON -165856
# 22    2391019    New                           Masatiompan  PERSON -162636
# 25     913078    New                           Connor Pass  PERSON -162665
# 34     219111    New                        Cnoc Breanainn  PERSON -157142
# 37     219111    New                                   Mas  PERSON -157142
# 38     219111    New                           Masatiompan  PERSON -157142
# 48     219588    New                              Fermoyle  PERSON -154634
# 62    1397619    New                    Mweelrea Mountains  PERSON -129723
# 71    1221163    New                           Inch Strand  PERSON -145542
# 84     965004    New                        Kylemore Abbey  PERSON -123906
# 86     774876    New                        Lough Yganavan  PERSON -139584
# 90     200643    New                              Benbrack  PERSON -121461
# 91     200643    New                            Knockbrack  PERSON -121461
# 97     192216    New                       Killary Harbour  PERSON -119869
# 99     192216    New                       Killary Harbour  PERSON -119869
# 3925  774520
# 3926  774520
# 3927  345000
# 3933  758490
# 3934  758490
# 3936  215580
# 3938  784400
# 3948  362500
# 3959  366900
# 3966  362820
# 3980  516240
# 3982  516240
# 3988  781550
# 3994  355800
# 3997  512100
# 3999  522500
# 4000  522500
# 4001  355389
# 4002  355389
# 4008  835450
# 4010  835450
# 4015  340000
# 4025  334620
# 4026  334620
# 4032  508500
# 4048  505110
# 4061  505090
# 4064  774390
# 4076  505050
# 4088  225620
# 4089  510330
# 4095  510000
# 4127  508150
# 4128  508150
# 4140  836480
# 4146  774240
# 4151  778500
# 4153  786310
# 4159  776210
# 4167  522720
# 4170  777700
# 4171  791930
# 4172  791930
# 4182  530200
# 4192  510860
# 4199  522800
# 4200  522800
# 4204  232380
# 4208  191450
# 4216  343140
# 4222  784451
# 4223  466780
# 4226  505860
# 4231  229840
# 4238  349600
# 4245  504060
# 4248  523960
# 4249  634370
# 4250  634370
# 4255  634410
# 4257  507510
# 4260  235050
# 4274  226570
# 4275  325080
# 4277  529600
# 4293  501540
# 4300  772450
# 4301  474880
# 4310  856800
# 4324  235020
# 4340  513760
# 4358  230530
# 4373  312540
# 4377  532310
# 4384  212210
# 4389  527400
# 4394  504990
# 4397  227810
# 4399  227810
# 4406  321300
# 4411  502040
# 4418  214060
# 4428  520740
# 4429  520740
# 4436  514900
# 4437  514900
# 4449  190530
# 4457  788220
# 4458  788220
# 4471  512210
# 4476  625160
# 4480  510520
# 4484  511800
# 4493  527290
# 4495  513450
# 4500  188780
# 4503  188780
# 4523  509700
# 4531  502950
# 4547  305239
# 4551  384090
# 4553  384090
# 4570  498860
# 4573  515300
# 4580  201840
# 4581  201840
# 4587  516320
# 4589  470920
# 4590  470920
# 4605  301470
# 4606  321630
# 4615  616540
# 4622  617520
# 4634  219290
# 4638  416340
# 4656  821210
# 4658  301600
# 4661  679400
# 4666  320670
# 4670  300690
# 4672  812500
# 4675  526410
# 4679  501730
# 4690  474700
# 4706  472340
# 4717  786280
# 4720  476840
# 4725  241240
# 4733  169430
# 4739  484900
# 4742  366600
# 4752  520770
# 4766  492500
# 4768  470760
# 4771   80370
# 4779  534150
# 4784  535580
# 4791  536700
# 4805  418900
# 4824  619750
# 4832  410140
# 4838  239750
# 4845  407590
# 4853  425220
# 4860  362930
# 4864  384020
# 4873  382340
# 4877  385820
# 4878  445370
# 4895  512700
# 4898  512700
# 4901  512700
# 4910  318230
# 4920  499560
# 4925  141460
# 4935  113470
# 4959  134270

# %%
cn = len(set(new['name']))
ce = len(set(existing['name']))
print("Found", ce, "unique existing names and", cn, "unique new candidate names.")
# Out:
# Found 652 unique existing names and 2663 unique new candidate names.

# %%
#output all dependencies so that we can reproduce the notebook (we only need this to set things up for Binder)
#%load_ext watermark
#%watermark --iversions

# %% [markdown]
# We plot the locations of the new and existing names as simple scatter plots. A density plot would make more sense here to allow a real comparison, but this gives us a first overview.

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.scatter(new['x'], new['y'])
ax2.scatter(existing['x'], existing['y'])
